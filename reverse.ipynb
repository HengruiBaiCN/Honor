# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as tgrad
import numpy as np
import os
import time

import utils

import networks

import matplotlib.pyplot as plt

import importlib

# %%
os.environ['KMP_DUPLICATE_LIB_OK']='True'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(torch.cuda.is_available())
# torch.set_default_tensor_type(torch.DoubleTensor)
print(device)

if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# True
# cuda

# %% [markdown]
# # Data Sampling
# Here in our case, the system is European Call Option PDE and the physical information about the system consists of Boundary Value conditions, final Value conditions and the PDE itself.

# %%
K = 40
r = 0.05
sigma = 0.25
T = 1
S_range = [0, 130]
t_range = [0, T]
gs = lambda x: np.fmax(x-K, 0)

# %% [markdown]
# # Build Neural Network

# %%
fnn = networks.FeedforwardNeuralNetwork(2, 50, 1, 3)
fnn.cuda()
# Out:
# FeedforwardNeuralNetwork(
#   (layers): ModuleList(
#     (0): Linear(in_features=2, out_features=50, bias=True)
#     (1-2): 2 x Linear(in_features=50, out_features=50, bias=True)
#   )
#   (output): Linear(in_features=50, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
import torchimize
# parallel levenberg-marquardt for several optimization problems at multiple costs
# from torchimize.functions import lsq_lma_parallel
# coeffs_list = lsq_lma_parallel(
#                     p = initials_batch,
#                     function = multi_cost_fun_batch,
#                     jac_function = multi_jac_fun_batch,
#                     args = (other_args,),
#                     wvec = torch.ones(5, device='cuda', dtype=initials_batch.dtype),
#                     ftol = 1e-8,
#                     ptol = 1e-8,
#                     gtol = 1e-8,
#                     meth = 'marq',
#                     max_iter = 40,
#                 )

n_epochs = 60000
lossFunction = nn.MSELoss()

from torchimize.functions import lsq_lma
# coeffs_list = lsq_lma(fnn.parameters(), function=lossFunction)
optimizer = optim.Adam(fnn.parameters(), lr=0.00002)

samples = {"pde": 50000, "bc":5000, "fc":5000}

# %% [markdown]
# # Modelling
#
# - For each iteration in the training loop, we are sampling data for the three physical conditions of the PDE.
# - Then we are calculating the loss three times on the same model, accumulating them into a combined objective function to be minimised for the Neural Network.
# - The first loss is the differential equation loss. Here we are trying to minimise the PDE by calculating gradients and forming the PDE itself.
# - The remaining losses are calculated for boundary value and initial value conditions for the PDE.
# - Mean Squared Error loss function `nn.MSELoss()` is chosen as the criterion to be minimised and
# - Adam optimizer `nn.optim.Adam(lr=3e-5)` with a learning rate of 0.00003 is chosen for performing the weight updates.

# %%
loss_hist = []
start_time = time.time()

for epoch in range(n_epochs):
    
    bc_st_train, bc_v_train, n_st_train, n_v_train = \
    utils.trainingData(K, 
                       r, 
                       sigma, 
                       T, 
                       S_range[-1], 
                       S_range, 
                       t_range, 
                       gs, 
                       samples['bc'], 
                       samples['fc'], 
                       samples['pde'], 
                       RNG_key=123)
    # save training data points to tensor and send to device
    n_st_train = torch.from_numpy(n_st_train).float().requires_grad_().to(device)
    n_v_train = torch.from_numpy(n_v_train).float().to(device)
    
    bc_st_train = torch.from_numpy(bc_st_train).float().to(device)
    bc_v_train = torch.from_numpy(bc_v_train).float().to(device)
    
    
    # PDE Round
    y1_hat = fnn(n_st_train)
    grads = tgrad.grad(y1_hat, n_st_train, grad_outputs=torch.ones(y1_hat.shape).cuda(), retain_graph=True, create_graph=True, only_inputs=True)[0]
    # print(grads)
    dVdt, dVdS = grads[:, 0].view(-1, 1), grads[:, 1].view(-1, 1)
    grads2nd = tgrad.grad(dVdS, n_st_train, grad_outputs=torch.ones(dVdS.shape).cuda(), create_graph=True, only_inputs=True)[0]
    # print(grads2nd)
    d2VdS2 = grads2nd[:, 1].view(-1, 1)
    S1 = n_st_train[:, 1].view(-1, 1)
    pde_loss = lossFunction(-dVdt, 0.5*((sigma*S1)**2)*d2VdS2 + r*S1*dVdS - r*y1_hat)
    
    
    # conditions Round
    y21_hat = fnn(bc_st_train)
    bc_loss = lossFunction(bc_v_train, y21_hat)
    
    
    # Backpropagation and Update
    optimizer.zero_grad()
    combined_loss = pde_loss.mean() + bc_loss.mean()
    combined_loss.backward()
    optimizer.step()
    
    loss_hist.append(combined_loss.item())
    if epoch % 500 == 0:
        print(f'{epoch}/{n_epochs} PDE Loss: {pde_loss.item():.5f}, BC Loss: {bc_loss.item():.5f}, total loss: {combined_loss.item():5f}, minimum loss: {min(loss_hist):.5f}')

end_time = time.time()
print('run time:', end_time - start_time)
# Out:
# 0/60000 PDE Loss: 0.00019, BC Loss: 3671.54297, total loss: 3671.543213, minimum loss: 3671.54321
# 500/60000 PDE Loss: 0.00040, BC Loss: 2511.03955, total loss: 2511.040039, minimum loss: 2511.04004
# 1000/60000 PDE Loss: 0.00317, BC Loss: 1207.01245, total loss: 1207.015625, minimum loss: 1207.01562
# 1500/60000 PDE Loss: 0.00633, BC Loss: 244.75986, total loss: 244.766190, minimum loss: 244.76619
# 2000/60000 PDE Loss: 0.00430, BC Loss: 79.33062, total loss: 79.334923, minimum loss: 79.33492
# 2500/60000 PDE Loss: 0.03467, BC Loss: 73.96288, total loss: 73.997551, minimum loss: 73.99755
# 3000/60000 PDE Loss: 0.12812, BC Loss: 71.25127, total loss: 71.379395, minimum loss: 71.37939
# 3500/60000 PDE Loss: 0.32444, BC Loss: 68.03030, total loss: 68.354744, minimum loss: 68.35474
# 4000/60000 PDE Loss: 0.68642, BC Loss: 64.16986, total loss: 64.856285, minimum loss: 64.85629
# 4500/60000 PDE Loss: 1.49864, BC Loss: 58.49059, total loss: 59.989227, minimum loss: 59.98923
# 5000/60000 PDE Loss: 3.01815, BC Loss: 51.76934, total loss: 54.787483, minimum loss: 54.78748
# 5500/60000 PDE Loss: 3.99042, BC Loss: 46.28996, total loss: 50.280380, minimum loss: 50.28038
# 6000/60000 PDE Loss: 4.74058, BC Loss: 40.90026, total loss: 45.640842, minimum loss: 45.64084
# 6500/60000 PDE Loss: 5.01300, BC Loss: 35.73155, total loss: 40.744553, minimum loss: 40.74455
# 7000/60000 PDE Loss: 4.73387, BC Loss: 30.73586, total loss: 35.469734, minimum loss: 35.46973
# 7500/60000 PDE Loss: 4.10095, BC Loss: 25.78408, total loss: 29.885036, minimum loss: 29.88504
# 8000/60000 PDE Loss: 3.34444, BC Loss: 20.91229, total loss: 24.256737, minimum loss: 24.25674
# 8500/60000 PDE Loss: 2.62873, BC Loss: 16.31411, total loss: 18.942842, minimum loss: 18.94284
# 9000/60000 PDE Loss: 2.04324, BC Loss: 12.29021, total loss: 14.333448, minimum loss: 14.33345
# 9500/60000 PDE Loss: 1.63187, BC Loss: 9.05091, total loss: 10.682775, minimum loss: 10.68277
# 10000/60000 PDE Loss: 1.36232, BC Loss: 6.68334, total loss: 8.045665, minimum loss: 8.04566
# 10500/60000 PDE Loss: 1.16546, BC Loss: 5.02380, total loss: 6.189265, minimum loss: 6.18927
# 11000/60000 PDE Loss: 0.97981, BC Loss: 3.81803, total loss: 4.797842, minimum loss: 4.79784
# 11500/60000 PDE Loss: 0.78862, BC Loss: 2.89720, total loss: 3.685819, minimum loss: 3.68582
# 12000/60000 PDE Loss: 0.61299, BC Loss: 2.14264, total loss: 2.755629, minimum loss: 2.75563
# 12500/60000 PDE Loss: 0.45578, BC Loss: 1.50318, total loss: 1.958951, minimum loss: 1.95895
# 13000/60000 PDE Loss: 0.33467, BC Loss: 0.92956, total loss: 1.264230, minimum loss: 1.26423
# 13500/60000 PDE Loss: 0.38314, BC Loss: 0.40028, total loss: 0.783416, minimum loss: 0.78305
# 14000/60000 PDE Loss: 0.59506, BC Loss: 0.20248, total loss: 0.797537, minimum loss: 0.77588
# 14500/60000 PDE Loss: 0.47334, BC Loss: 0.12960, total loss: 0.602941, minimum loss: 0.60294
# 15000/60000 PDE Loss: 0.38223, BC Loss: 0.07564, total loss: 0.457870, minimum loss: 0.45787
# 15500/60000 PDE Loss: 0.31413, BC Loss: 0.04087, total loss: 0.355004, minimum loss: 0.35500
# 16000/60000 PDE Loss: 0.25860, BC Loss: 0.02183, total loss: 0.280437, minimum loss: 0.28044
# 16500/60000 PDE Loss: 0.21194, BC Loss: 0.01193, total loss: 0.223865, minimum loss: 0.22386
# 17000/60000 PDE Loss: 0.17329, BC Loss: 0.01050, total loss: 0.183788, minimum loss: 0.18062
# 17500/60000 PDE Loss: 0.14078, BC Loss: 0.00382, total loss: 0.144606, minimum loss: 0.14461
# 18000/60000 PDE Loss: 0.11346, BC Loss: 0.00201, total loss: 0.115466, minimum loss: 0.11547
# 18500/60000 PDE Loss: 0.09140, BC Loss: 0.00112, total loss: 0.092523, minimum loss: 0.09252
# 19000/60000 PDE Loss: 0.07331, BC Loss: 0.00083, total loss: 0.074136, minimum loss: 0.07399
# 19500/60000 PDE Loss: 0.05896, BC Loss: 0.00042, total loss: 0.059377, minimum loss: 0.05938
# 20000/60000 PDE Loss: 0.04686, BC Loss: 0.00028, total loss: 0.047136, minimum loss: 0.04714
# 20500/60000 PDE Loss: 0.03766, BC Loss: 0.00020, total loss: 0.037857, minimum loss: 0.03786
# 21000/60000 PDE Loss: 0.02986, BC Loss: 0.00035, total loss: 0.030210, minimum loss: 0.03010
# 21500/60000 PDE Loss: 0.02381, BC Loss: 0.00013, total loss: 0.023936, minimum loss: 0.02394
# 22000/60000 PDE Loss: 0.01908, BC Loss: 0.00014, total loss: 0.019224, minimum loss: 0.01922
# 22500/60000 PDE Loss: 0.01535, BC Loss: 0.00011, total loss: 0.015452, minimum loss: 0.01545
# 23000/60000 PDE Loss: 0.01229, BC Loss: 0.00011, total loss: 0.012400, minimum loss: 0.01240
# 23500/60000 PDE Loss: 0.00984, BC Loss: 0.00133, total loss: 0.011174, minimum loss: 0.00999
# 24000/60000 PDE Loss: 0.00806, BC Loss: 0.00009, total loss: 0.008158, minimum loss: 0.00816
# 24500/60000 PDE Loss: 0.00673, BC Loss: 0.00009, total loss: 0.006816, minimum loss: 0.00682
# 25000/60000 PDE Loss: 0.00559, BC Loss: 0.00008, total loss: 0.005672, minimum loss: 0.00567
# 25500/60000 PDE Loss: 0.00466, BC Loss: 0.00007, total loss: 0.004732, minimum loss: 0.00473
# 26000/60000 PDE Loss: 0.00374, BC Loss: 0.00007, total loss: 0.003810, minimum loss: 0.00381
# 26500/60000 PDE Loss: 0.00309, BC Loss: 0.00006, total loss: 0.003150, minimum loss: 0.00315
# 27000/60000 PDE Loss: 0.00248, BC Loss: 0.00005, total loss: 0.002531, minimum loss: 0.00253
# 27500/60000 PDE Loss: 0.00209, BC Loss: 0.00005, total loss: 0.002135, minimum loss: 0.00213
# 28000/60000 PDE Loss: 0.00177, BC Loss: 0.00005, total loss: 0.001819, minimum loss: 0.00182
# 28500/60000 PDE Loss: 0.00144, BC Loss: 0.00004, total loss: 0.001477, minimum loss: 0.00148
# 29000/60000 PDE Loss: 0.00150, BC Loss: 0.00004, total loss: 0.001542, minimum loss: 0.00145
# 29500/60000 PDE Loss: 0.00126, BC Loss: 0.00004, total loss: 0.001291, minimum loss: 0.00129
# 30000/60000 PDE Loss: 0.00104, BC Loss: 0.00003, total loss: 0.001067, minimum loss: 0.00107
# 30500/60000 PDE Loss: 0.00084, BC Loss: 0.00003, total loss: 0.000873, minimum loss: 0.00087
# 31000/60000 PDE Loss: 0.00078, BC Loss: 0.00003, total loss: 0.000808, minimum loss: 0.00081
# 31500/60000 PDE Loss: 0.00119, BC Loss: 0.00002, total loss: 0.001215, minimum loss: 0.00078
# 32000/60000 PDE Loss: 0.00094, BC Loss: 0.00002, total loss: 0.000959, minimum loss: 0.00078
# 32500/60000 PDE Loss: 0.00081, BC Loss: 0.00002, total loss: 0.000831, minimum loss: 0.00078
# 33000/60000 PDE Loss: 0.00068, BC Loss: 0.00002, total loss: 0.000700, minimum loss: 0.00070
# 33500/60000 PDE Loss: 0.00066, BC Loss: 0.00002, total loss: 0.000681, minimum loss: 0.00068
# 34000/60000 PDE Loss: 0.00065, BC Loss: 0.00001, total loss: 0.000665, minimum loss: 0.00066
# 34500/60000 PDE Loss: 0.00064, BC Loss: 0.00001, total loss: 0.000651, minimum loss: 0.00065
# 35000/60000 PDE Loss: 0.00063, BC Loss: 0.00001, total loss: 0.000646, minimum loss: 0.00065
# 35500/60000 PDE Loss: 0.00111, BC Loss: 0.00001, total loss: 0.001120, minimum loss: 0.00064
# 36000/60000 PDE Loss: 0.00087, BC Loss: 0.00001, total loss: 0.000884, minimum loss: 0.00064
# 36500/60000 PDE Loss: 0.00075, BC Loss: 0.00001, total loss: 0.000763, minimum loss: 0.00064
# 37000/60000 PDE Loss: 0.00063, BC Loss: 0.00001, total loss: 0.000639, minimum loss: 0.00064
# 37500/60000 PDE Loss: 0.00062, BC Loss: 0.00001, total loss: 0.000629, minimum loss: 0.00063
# 38000/60000 PDE Loss: 0.00061, BC Loss: 0.00001, total loss: 0.000617, minimum loss: 0.00062
# 38500/60000 PDE Loss: 0.00060, BC Loss: 0.00001, total loss: 0.000608, minimum loss: 0.00061
# 39000/60000 PDE Loss: 0.00059, BC Loss: 0.00001, total loss: 0.000600, minimum loss: 0.00060
# 39500/60000 PDE Loss: 0.00059, BC Loss: 0.00001, total loss: 0.000595, minimum loss: 0.00060
# 40000/60000 PDE Loss: 0.00104, BC Loss: 0.00001, total loss: 0.001050, minimum loss: 0.00059
# 40500/60000 PDE Loss: 0.00093, BC Loss: 0.00001, total loss: 0.000934, minimum loss: 0.00059
# 41000/60000 PDE Loss: 0.00070, BC Loss: 0.00001, total loss: 0.000705, minimum loss: 0.00059
# 41500/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000590, minimum loss: 0.00059
# 42000/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000588, minimum loss: 0.00059
# 42500/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000587, minimum loss: 0.00059
# 43000/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000585, minimum loss: 0.00058
# 43500/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000584, minimum loss: 0.00058
# 44000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000581, minimum loss: 0.00058
# 44500/60000 PDE Loss: 0.00102, BC Loss: 0.00001, total loss: 0.001031, minimum loss: 0.00058
# 45000/60000 PDE Loss: 0.00080, BC Loss: 0.00001, total loss: 0.000806, minimum loss: 0.00058
# 45500/60000 PDE Loss: 0.00069, BC Loss: 0.00001, total loss: 0.000695, minimum loss: 0.00058
# 46000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000582, minimum loss: 0.00058
# 46500/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000582, minimum loss: 0.00058
# 47000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000581, minimum loss: 0.00058
# 47500/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000582, minimum loss: 0.00058
# 48000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000582, minimum loss: 0.00058
# 48500/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000581, minimum loss: 0.00058
# 49000/60000 PDE Loss: 0.00136, BC Loss: 0.00002, total loss: 0.001383, minimum loss: 0.00058
# 49500/60000 PDE Loss: 0.00102, BC Loss: 0.00001, total loss: 0.001028, minimum loss: 0.00058
# 50000/60000 PDE Loss: 0.00080, BC Loss: 0.00001, total loss: 0.000803, minimum loss: 0.00058
# 50500/60000 PDE Loss: 0.00068, BC Loss: 0.00001, total loss: 0.000690, minimum loss: 0.00058
# 51000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000577, minimum loss: 0.00058
# 51500/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000577, minimum loss: 0.00058
# 52000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000576, minimum loss: 0.00058
# 52500/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000577, minimum loss: 0.00058
# 53000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000577, minimum loss: 0.00058
# 53500/60000 PDE Loss: 0.00069, BC Loss: 0.00001, total loss: 0.000698, minimum loss: 0.00058
# 54000/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000583, minimum loss: 0.00058
# 54500/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000582, minimum loss: 0.00058
# 55000/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000582, minimum loss: 0.00058
# 55500/60000 PDE Loss: 0.00058, BC Loss: 0.00001, total loss: 0.000582, minimum loss: 0.00058
# 56000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000581, minimum loss: 0.00058
# 56500/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000579, minimum loss: 0.00058
# 57000/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000578, minimum loss: 0.00058
# 57500/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000578, minimum loss: 0.00058
# 58000/60000 PDE Loss: 0.00081, BC Loss: 0.00028, total loss: 0.001096, minimum loss: 0.00058
# 58500/60000 PDE Loss: 0.00079, BC Loss: 0.00001, total loss: 0.000802, minimum loss: 0.00058
# 59000/60000 PDE Loss: 0.00068, BC Loss: 0.00001, total loss: 0.000690, minimum loss: 0.00058
# 59500/60000 PDE Loss: 0.00057, BC Loss: 0.00001, total loss: 0.000577, minimum loss: 0.00058
# run time: 290.94539165496826
