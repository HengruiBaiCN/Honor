# %% [markdown]
# # Neural Network
#
# Ref: https://www.youtube.com/watch?v=Spu4gH_YfNU&ab_channel=AleksandarHaber

# %%
import tensorflow as tf
from tensorflow import keras
import cmath
import time
from keras import models
from keras import layers
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.1

# %%
# number of samples for training
sample_number = 10000

# %%
# training input data: parameters
atrain=np.random.rand(sample_number,1)
btrain=np.random.rand(sample_number,1)
ctrain=np.random.rand(sample_number,1)

# concatenate the input data a, b, c as a vector input
dataXtrain=np.concatenate((atrain,btrain,ctrain),axis=1)

# training output data - a complex number: the roots of the given function
x1real_train=np.zeros(shape=(sample_number,1))
x1imag_train=np.zeros(shape=(sample_number,1))
x2real_train=np.zeros(shape=(sample_number,1))
x2imag_train=np.zeros(shape=(sample_number,1))

for i in range(sample_number):
    # the real solution of each input
    x1 = (-btrain[i,0] + cmath.sqrt(btrain[i,0]**2 - 4 * atrain[i,0]*ctrain[i,0])) / (2*atrain[i,0])
    x2 = (-btrain[i,0] - cmath.sqrt(btrain[i,0]**2 - 4 * atrain[i,0]*ctrain[i,0])) / (2*atrain[i,0])
    # transfer the real solution to our output traning data
    x1real_train[i,0]=np.real(x1)
    x1imag_train[i,0]=np.imag(x1)
    x2real_train[i,0]=np.real(x2)
    x2imag_train[i,0]=np.imag(x2)

# concatenate the output data as a vector output
dataYtrain=np.concatenate((x1real_train,x1imag_train,x2real_train,x2imag_train),axis=1)

# %%
# validation data
aval=np.random.rand(sample_number,1)
bval=np.random.rand(sample_number,1)
cval=np.random.rand(sample_number,1)
 
dataXval=np.concatenate((aval,bval,cval),axis=1)
 
x1real_val=np.zeros(shape=(sample_number,1))
x1imag_val=np.zeros(shape=(sample_number,1))
x2real_val=np.zeros(shape=(sample_number,1))
x2imag_val=np.zeros(shape=(sample_number,1))
 
 
for i in range(sample_number):
    x1=(-bval[i,0]+cmath.sqrt(bval[i,0]**2-4*aval[i,0]*cval[i,0]))/(2*aval[i,0])
    x2=(-bval[i,0]-cmath.sqrt(bval[i,0]**2-4*aval[i,0]*cval[i,0]))/(2*aval[i,0])
    x1real_val[i,0]=np.real(x1)
    x1imag_val[i,0]=np.imag(x1)
    x2real_val[i,0]=np.real(x2)
    x2imag_val[i,0]=np.imag(x2)
 
dataYval=np.concatenate((x1real_val,x1imag_val,x2real_val,x2imag_val),axis=1)

# %%
# test data
atest=np.random.rand(sample_number,1)
btest=np.random.rand(sample_number,1)
ctest=np.random.rand(sample_number,1)
 
dataXtest=np.concatenate((atest,btest,ctest),axis=1)
 
x1real_test=np.zeros(shape=(sample_number,1))
x1imag_test=np.zeros(shape=(sample_number,1))
x2real_test=np.zeros(shape=(sample_number,1))
x2imag_test=np.zeros(shape=(sample_number,1))
 
 
for i in range(sample_number):
    x1=(-btest[i,0]+cmath.sqrt(btest[i,0]**2-4*atest[i,0]*ctest[i,0]))/(2*atest[i,0])
    x2=(-btest[i,0]-cmath.sqrt(btest[i,0]**2-4*atest[i,0]*ctest[i,0]))/(2*atest[i,0])
    x1real_test[i,0]=np.real(x1)
    x1imag_test[i,0]=np.imag(x1)
    x2real_test[i,0]=np.real(x2)
    x2imag_test[i,0]=np.imag(x2)
 
dataYtest=np.concatenate((x1real_test,x1imag_test,x2real_test,x2imag_test),axis=1)

# %%
###############################################################################
#                         neural network
###############################################################################
with tf.device(device_name='/GPU:0'):
    network = models.Sequential()
    
    # define layers of the neural network
    network.add(layers.Dense(50, activation='tanh',kernel_initializer='random_normal',use_bias=False,input_dim=3))
    network.add(layers.Dense(50, activation='tanh',kernel_initializer='random_normal', use_bias=False))
    network.add(layers.Dense(50, activation='tanh',kernel_initializer='random_normal', use_bias=False))
    #network.add(layers.Dense(20, activation='relu',kernel_initializer='random_uniform', use_bias=False))
    network.add(layers.Dense(4, activation = 'linear',kernel_initializer='random_normal',use_bias=False))
    # number of training neurons = 3*10+10*20+20*20+20*10+10*4+4*4 = 886
    
    # define the optimizer, with different loss function
    network.compile(optimizer=RMSprop(), loss='mean_squared_error', metrics=['mse'])
    #network.compile(optimizer=RMSprop(), loss='mean_absolute_percentage_error', metrics=['mse'])  # 'mean_absolute_percentage_error' is another option
    #network.compile(optimizer=Adam(), loss='mean_squared_error')
     
     
    # only save the model with the best validation loss value
    filepath="C:/Users/hengr/Programs/Projects/Honor-Project/output/best_model_1.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='min')
    callbacks_list = [checkpoint]
    
    # neural network traning
    start_time = time.time()
    history = network.fit(dataXtrain, dataYtrain, epochs=100000, batch_size=2000, callbacks=callbacks_list, validation_data = (dataXval, dataYval), verbose = 2)
    end_time = time.time()
    print('Training time %f'%(end_time-start_time))
# Out:
# Epoch 1/3000
# 50/50 - 0s - loss: 106310.5469 - mse: 106310.5469 - val_loss: 17713.3066 - val_mse: 17713.3066 - 341ms/epoch - 7ms/step
# Epoch 2/3000
# 50/50 - 0s - loss: 106299.0000 - mse: 106299.0000 - val_loss: 17707.9805 - val_mse: 17707.9805 - 124ms/epoch - 2ms/step
# Epoch 3/3000
# 50/50 - 0s - loss: 106290.6953 - mse: 106290.6953 - val_loss: 17701.6777 - val_mse: 17701.6777 - 120ms/epoch - 2ms/step
# Epoch 4/3000
# 50/50 - 0s - loss: 106278.2500 - mse: 106278.2500 - val_loss: 17692.8672 - val_mse: 17692.8672 - 123ms/epoch - 2ms/step
# Epoch 5/3000
# 50/50 - 0s - loss: 106265.5859 - mse: 106265.5859 - val_loss: 17683.5215 - val_mse: 17683.5215 - 127ms/epoch - 3ms/step
# Epoch 6/3000
# 50/50 - 0s - loss: 106251.0156 - mse: 106251.0156 - val_loss: 17672.0938 - val_mse: 17672.0938 - 116ms/epoch - 2ms/step
# Epoch 7/3000
# 50/50 - 0s - loss: 106228.6719 - mse: 106228.6719 - val_loss: 17659.2227 - val_mse: 17659.2227 - 125ms/epoch - 3ms/step
# Epoch 8/3000
# 50/50 - 0s - loss: 106204.7812 - mse: 106204.7812 - val_loss: 17644.9531 - val_mse: 17644.9531 - 118ms/epoch - 2ms/step
# Epoch 9/3000
# 50/50 - 0s - loss: 106184.1094 - mse: 106184.1094 - val_loss: 17631.9941 - val_mse: 17631.9941 - 116ms/epoch - 2ms/step
# Epoch 10/3000
# 50/50 - 0s - loss: 106162.9844 - mse: 106162.9844 - val_loss: 17616.8223 - val_mse: 17616.8223 - 115ms/epoch - 2ms/step
# Epoch 11/3000
# 50/50 - 0s - loss: 106137.0156 - mse: 106137.0156 - val_loss: 17602.4941 - val_mse: 17602.4941 - 118ms/epoch - 2ms/step
# Epoch 12/3000
# 50/50 - 0s - loss: 106110.8438 - mse: 106110.8438 - val_loss: 17587.1660 - val_mse: 17587.1660 - 116ms/epoch - 2ms/step
# Epoch 13/3000
# 50/50 - 0s - loss: 106089.4688 - mse: 106089.4688 - val_loss: 17572.1230 - val_mse: 17572.1230 - 121ms/epoch - 2ms/step
# Epoch 14/3000
# 50/50 - 0s - loss: 106049.3203 - mse: 106049.3203 - val_loss: 17552.9785 - val_mse: 17552.9785 - 114ms/epoch - 2ms/step
# Epoch 15/3000
# 50/50 - 0s - loss: 106020.5859 - mse: 106020.5859 - val_loss: 17538.0723 - val_mse: 17538.0723 - 115ms/epoch - 2ms/step
# Epoch 16/3000
# 50/50 - 0s - loss: 105995.7266 - mse: 105995.7266 - val_loss: 17519.1484 - val_mse: 17519.1484 - 115ms/epoch - 2ms/step
# Epoch 17/3000
# 50/50 - 0s - loss: 105957.5078 - mse: 105957.5078 - val_loss: 17501.3770 - val_mse: 17501.3770 - 116ms/epoch - 2ms/step
# Epoch 18/3000
# 50/50 - 0s - loss: 105928.5781 - mse: 105928.5781 - val_loss: 17483.1934 - val_mse: 17483.1934 - 122ms/epoch - 2ms/step
# Epoch 19/3000
# 50/50 - 0s - loss: 105889.5781 - mse: 105889.5781 - val_loss: 17462.1230 - val_mse: 17462.1230 - 111ms/epoch - 2ms/step
# Epoch 20/3000
# 50/50 - 0s - loss: 105854.9375 - mse: 105854.9375 - val_loss: 17445.3027 - val_mse: 17445.3027 - 120ms/epoch - 2ms/step
# Epoch 21/3000
# 50/50 - 0s - loss: 105824.1641 - mse: 105824.1641 - val_loss: 17426.1309 - val_mse: 17426.1309 - 112ms/epoch - 2ms/step
# Epoch 22/3000
# 50/50 - 0s - loss: 105791.1016 - mse: 105791.1016 - val_loss: 17409.5977 - val_mse: 17409.5977 - 127ms/epoch - 3ms/step
# Epoch 23/3000
# 50/50 - 0s - loss: 105731.3359 - mse: 105731.3359 - val_loss: 17412.1582 - val_mse: 17412.1582 - 107ms/epoch - 2ms/step
# Epoch 24/3000
# 50/50 - 0s - loss: 105707.4453 - mse: 105707.4453 - val_loss: 17366.2578 - val_mse: 17366.2578 - 113ms/epoch - 2ms/step
# Epoch 25/3000
# 50/50 - 0s - loss: 105682.3906 - mse: 105682.3906 - val_loss: 17356.0508 - val_mse: 17356.0508 - 114ms/epoch - 2ms/step
# Epoch 26/3000
# 50/50 - 0s - loss: 105643.8359 - mse: 105643.8359 - val_loss: 17339.9688 - val_mse: 17339.9688 - 117ms/epoch - 2ms/step
# Epoch 27/3000
# 50/50 - 0s - loss: 105605.6953 - mse: 105605.6953 - val_loss: 17321.6211 - val_mse: 17321.6211 - 115ms/epoch - 2ms/step
# Epoch 28/3000
# 50/50 - 0s - loss: 105571.2266 - mse: 105571.2266 - val_loss: 17294.1172 - val_mse: 17294.1172 - 115ms/epoch - 2ms/step
# Epoch 29/3000
# 50/50 - 0s - loss: 105531.0312 - mse: 105531.0312 - val_loss: 17270.5059 - val_mse: 17270.5059 - 115ms/epoch - 2ms/step
# Epoch 30/3000
# 50/50 - 0s - loss: 105492.9922 - mse: 105492.9922 - val_loss: 17250.1602 - val_mse: 17250.1602 - 111ms/epoch - 2ms/step
# Epoch 31/3000
# 50/50 - 0s - loss: 105453.2500 - mse: 105453.2500 - val_loss: 17239.5078 - val_mse: 17239.5078 - 116ms/epoch - 2ms/step
# Epoch 32/3000
# 50/50 - 0s - loss: 105411.4609 - mse: 105411.4609 - val_loss: 17219.0000 - val_mse: 17219.0000 - 117ms/epoch - 2ms/step
# Epoch 33/3000
# 50/50 - 0s - loss: 105376.1094 - mse: 105376.1094 - val_loss: 17191.9883 - val_mse: 17191.9883 - 112ms/epoch - 2ms/step
# Epoch 34/3000
# 50/50 - 0s - loss: 105327.6875 - mse: 105327.6875 - val_loss: 17173.4316 - val_mse: 17173.4316 - 109ms/epoch - 2ms/step
# Epoch 35/3000
# 50/50 - 0s - loss: 105297.1016 - mse: 105297.1016 - val_loss: 17153.7305 - val_mse: 17153.7305 - 113ms/epoch - 2ms/step
# Epoch 36/3000
# 50/50 - 0s - loss: 105248.1953 - mse: 105248.1953 - val_loss: 17133.4766 - val_mse: 17133.4766 - 115ms/epoch - 2ms/step
# Epoch 37/3000
# 50/50 - 0s - loss: 105199.8281 - mse: 105199.8281 - val_loss: 17105.8184 - val_mse: 17105.8184 - 109ms/epoch - 2ms/step
# Epoch 38/3000
# 50/50 - 0s - loss: 105206.1719 - mse: 105206.1719 - val_loss: 17086.2012 - val_mse: 17086.2012 - 115ms/epoch - 2ms/step
# Epoch 39/3000
# 50/50 - 0s - loss: 105123.9766 - mse: 105123.9766 - val_loss: 17063.8945 - val_mse: 17063.8945 - 118ms/epoch - 2ms/step
# Epoch 40/3000
# 50/50 - 0s - loss: 105052.4844 - mse: 105052.4844 - val_loss: 17114.4023 - val_mse: 17114.4023 - 99ms/epoch - 2ms/step
# Epoch 41/3000
# 50/50 - 0s - loss: 105025.7344 - mse: 105025.7344 - val_loss: 17020.7070 - val_mse: 17020.7070 - 111ms/epoch - 2ms/step
# Epoch 42/3000
# 50/50 - 0s - loss: 105007.3516 - mse: 105007.3516 - val_loss: 16997.6562 - val_mse: 16997.6562 - 108ms/epoch - 2ms/step
# Epoch 43/3000
# 50/50 - 0s - loss: 104938.0156 - mse: 104938.0156 - val_loss: 16974.8438 - val_mse: 16974.8438 - 110ms/epoch - 2ms/step
# Epoch 44/3000
# 50/50 - 0s - loss: 104898.6641 - mse: 104898.6641 - val_loss: 16967.3867 - val_mse: 16967.3867 - 109ms/epoch - 2ms/step
# Epoch 45/3000
# 50/50 - 0s - loss: 104835.7500 - mse: 104835.7500 - val_loss: 16933.3770 - val_mse: 16933.3770 - 109ms/epoch - 2ms/step
# Epoch 46/3000
# 50/50 - 0s - loss: 104835.9141 - mse: 104835.9141 - val_loss: 16955.9062 - val_mse: 16955.9062 - 98ms/epoch - 2ms/step
# Epoch 47/3000
# 50/50 - 0s - loss: 104723.7969 - mse: 104723.7969 - val_loss: 16885.1719 - val_mse: 16885.1719 - 112ms/epoch - 2ms/step
# Epoch 48/3000
# 50/50 - 0s - loss: 104778.8672 - mse: 104778.8672 - val_loss: 16866.5000 - val_mse: 16866.5000 - 108ms/epoch - 2ms/step
# Epoch 49/3000
# 50/50 - 0s - loss: 104721.5547 - mse: 104721.5547 - val_loss: 16851.5781 - val_mse: 16851.5781 - 109ms/epoch - 2ms/step
# Epoch 50/3000
# 50/50 - 0s - loss: 104623.0703 - mse: 104623.0703 - val_loss: 16828.9434 - val_mse: 16828.9434 - 109ms/epoch - 2ms/step
# Epoch 51/3000
# 50/50 - 0s - loss: 104554.1172 - mse: 104554.1172 - val_loss: 16798.3633 - val_mse: 16798.3633 - 107ms/epoch - 2ms/step
# Epoch 52/3000
# 50/50 - 0s - loss: 104567.3203 - mse: 104567.3203 - val_loss: 16781.0098 - val_mse: 16781.0098 - 112ms/epoch - 2ms/step
# Epoch 53/3000
# 50/50 - 0s - loss: 104558.7734 - mse: 104558.7734 - val_loss: 16813.6465 - val_mse: 16813.6465 - 100ms/epoch - 2ms/step
# Epoch 54/3000
# 50/50 - 0s - loss: 104387.0625 - mse: 104387.0625 - val_loss: 16731.5605 - val_mse: 16731.5605 - 109ms/epoch - 2ms/step
# Epoch 55/3000
# 50/50 - 0s - loss: 104391.7500 - mse: 104391.7500 - val_loss: 16831.9180 - val_mse: 16831.9180 - 99ms/epoch - 2ms/step
# Epoch 56/3000
# 50/50 - 0s - loss: 104350.5391 - mse: 104350.5391 - val_loss: 16722.5430 - val_mse: 16722.5430 - 113ms/epoch - 2ms/step
# Epoch 57/3000
# 50/50 - 0s - loss: 104293.1953 - mse: 104293.1953 - val_loss: 16777.4746 - val_mse: 16777.4746 - 99ms/epoch - 2ms/step
# Epoch 58/3000
# 50/50 - 0s - loss: 104293.3438 - mse: 104293.3438 - val_loss: 16699.9023 - val_mse: 16699.9023 - 114ms/epoch - 2ms/step
# Epoch 59/3000
# 50/50 - 0s - loss: 104230.9766 - mse: 104230.9766 - val_loss: 16698.1133 - val_mse: 16698.1133 - 118ms/epoch - 2ms/step
# Epoch 60/3000
# 50/50 - 0s - loss: 104117.1562 - mse: 104117.1562 - val_loss: 16608.8320 - val_mse: 16608.8320 - 111ms/epoch - 2ms/step
# Epoch 61/3000
# 50/50 - 0s - loss: 104120.5312 - mse: 104120.5312 - val_loss: 16584.1621 - val_mse: 16584.1621 - 109ms/epoch - 2ms/step
# Epoch 62/3000
# 50/50 - 0s - loss: 104007.5859 - mse: 104007.5859 - val_loss: 16762.7480 - val_mse: 16762.7480 - 104ms/epoch - 2ms/step
# Epoch 63/3000
# 50/50 - 0s - loss: 104017.7188 - mse: 104017.7188 - val_loss: 16548.7422 - val_mse: 16548.7422 - 110ms/epoch - 2ms/step
# Epoch 64/3000
# 50/50 - 0s - loss: 104017.3672 - mse: 104017.3672 - val_loss: 16649.7656 - val_mse: 16649.7656 - 103ms/epoch - 2ms/step
# Epoch 65/3000
# 50/50 - 0s - loss: 103884.5781 - mse: 103884.5781 - val_loss: 16518.0430 - val_mse: 16518.0430 - 112ms/epoch - 2ms/step
# Epoch 66/3000
# 50/50 - 0s - loss: 103844.6016 - mse: 103844.6016 - val_loss: 16544.0879 - val_mse: 16544.0879 - 101ms/epoch - 2ms/step
# Epoch 67/3000
# 50/50 - 0s - loss: 103847.3750 - mse: 103847.3750 - val_loss: 16446.4746 - val_mse: 16446.4746 - 112ms/epoch - 2ms/step
# Epoch 68/3000
# 50/50 - 0s - loss: 103764.9609 - mse: 103764.9609 - val_loss: 16514.2051 - val_mse: 16514.2051 - 106ms/epoch - 2ms/step
# Epoch 69/3000
# 50/50 - 0s - loss: 103774.4141 - mse: 103774.4141 - val_loss: 16413.7520 - val_mse: 16413.7520 - 117ms/epoch - 2ms/step
# Epoch 70/3000
# 50/50 - 0s - loss: 103685.5938 - mse: 103685.5938 - val_loss: 16417.8691 - val_mse: 16417.8691 - 104ms/epoch - 2ms/step
# Epoch 71/3000
# 50/50 - 0s - loss: 103605.0938 - mse: 103605.0938 - val_loss: 16385.7441 - val_mse: 16385.7441 - 112ms/epoch - 2ms/step
# Epoch 72/3000
# 50/50 - 0s - loss: 103590.2578 - mse: 103590.2578 - val_loss: 16369.2402 - val_mse: 16369.2402 - 111ms/epoch - 2ms/step
# Epoch 73/3000
# 50/50 - 0s - loss: 103515.4219 - mse: 103515.4219 - val_loss: 16330.9834 - val_mse: 16330.9834 - 117ms/epoch - 2ms/step
# Epoch 74/3000
# 50/50 - 0s - loss: 103527.9219 - mse: 103527.9219 - val_loss: 16375.0703 - val_mse: 16375.0703 - 103ms/epoch - 2ms/step
# Epoch 75/3000
# 50/50 - 0s - loss: 103877.7656 - mse: 103877.7656 - val_loss: 16332.0010 - val_mse: 16332.0010 - 107ms/epoch - 2ms/step
# Epoch 76/3000
# 50/50 - 0s - loss: 103463.6406 - mse: 103463.6406 - val_loss: 16427.2441 - val_mse: 16427.2441 - 106ms/epoch - 2ms/step
# Epoch 77/3000
# 50/50 - 0s - loss: 103342.6406 - mse: 103342.6406 - val_loss: 16242.0723 - val_mse: 16242.0723 - 113ms/epoch - 2ms/step
# Epoch 78/3000
# 50/50 - 0s - loss: 103264.4375 - mse: 103264.4375 - val_loss: 16215.8545 - val_mse: 16215.8545 - 111ms/epoch - 2ms/step
# Epoch 79/3000
# 50/50 - 0s - loss: 103190.6094 - mse: 103190.6094 - val_loss: 16345.1777 - val_mse: 16345.1777 - 106ms/epoch - 2ms/step
# Epoch 80/3000
# 50/50 - 0s - loss: 103287.9688 - mse: 103287.9688 - val_loss: 16175.7393 - val_mse: 16175.7393 - 115ms/epoch - 2ms/step
# Epoch 81/3000
# 50/50 - 0s - loss: 103023.1484 - mse: 103023.1484 - val_loss: 16676.5820 - val_mse: 16676.5820 - 104ms/epoch - 2ms/step
# Epoch 82/3000
# 50/50 - 0s - loss: 103231.6953 - mse: 103231.6953 - val_loss: 16210.3281 - val_mse: 16210.3281 - 103ms/epoch - 2ms/step
# Epoch 83/3000
# 50/50 - 0s - loss: 103102.9219 - mse: 103102.9219 - val_loss: 16147.7002 - val_mse: 16147.7002 - 123ms/epoch - 2ms/step
# Epoch 84/3000
# 50/50 - 0s - loss: 103418.6875 - mse: 103418.6875 - val_loss: 16279.7832 - val_mse: 16279.7832 - 115ms/epoch - 2ms/step
# Epoch 85/3000
# 50/50 - 0s - loss: 102964.1016 - mse: 102964.1016 - val_loss: 16131.0322 - val_mse: 16131.0322 - 116ms/epoch - 2ms/step
# Epoch 86/3000
# 50/50 - 0s - loss: 102802.9844 - mse: 102802.9844 - val_loss: 16418.3516 - val_mse: 16418.3516 - 104ms/epoch - 2ms/step
# Epoch 87/3000
# 50/50 - 0s - loss: 103252.9297 - mse: 103252.9297 - val_loss: 16231.1445 - val_mse: 16231.1445 - 106ms/epoch - 2ms/step
# Epoch 88/3000
# 50/50 - 0s - loss: 102845.0000 - mse: 102845.0000 - val_loss: 16056.8457 - val_mse: 16056.8457 - 113ms/epoch - 2ms/step
# Epoch 89/3000
# 50/50 - 0s - loss: 102972.4766 - mse: 102972.4766 - val_loss: 16029.6738 - val_mse: 16029.6738 - 114ms/epoch - 2ms/step
# Epoch 90/3000
# 50/50 - 0s - loss: 102636.7422 - mse: 102636.7422 - val_loss: 16064.5811 - val_mse: 16064.5811 - 97ms/epoch - 2ms/step
# Epoch 91/3000
# 50/50 - 0s - loss: 102621.2344 - mse: 102621.2344 - val_loss: 15956.6523 - val_mse: 15956.6523 - 116ms/epoch - 2ms/step
# Epoch 92/3000
# 50/50 - 0s - loss: 102673.5625 - mse: 102673.5625 - val_loss: 16346.7510 - val_mse: 16346.7510 - 106ms/epoch - 2ms/step
# Epoch 93/3000
# 50/50 - 0s - loss: 102610.2812 - mse: 102610.2812 - val_loss: 15928.5312 - val_mse: 15928.5312 - 121ms/epoch - 2ms/step
# Epoch 94/3000
# 50/50 - 0s - loss: 102799.0625 - mse: 102799.0625 - val_loss: 16166.7422 - val_mse: 16166.7422 - 100ms/epoch - 2ms/step
# Epoch 95/3000
# 50/50 - 0s - loss: 102602.1250 - mse: 102602.1250 - val_loss: 16204.2803 - val_mse: 16204.2803 - 105ms/epoch - 2ms/step
# Epoch 96/3000
# 50/50 - 0s - loss: 102411.2656 - mse: 102411.2656 - val_loss: 16158.6533 - val_mse: 16158.6533 - 100ms/epoch - 2ms/step
# Epoch 97/3000
# 50/50 - 0s - loss: 103132.8359 - mse: 103132.8359 - val_loss: 15960.1289 - val_mse: 15960.1289 - 97ms/epoch - 2ms/step
# Epoch 98/3000
# 50/50 - 0s - loss: 102306.2188 - mse: 102306.2188 - val_loss: 16348.6299 - val_mse: 16348.6299 - 100ms/epoch - 2ms/step
# Epoch 99/3000
# 50/50 - 0s - loss: 102345.4844 - mse: 102345.4844 - val_loss: 15821.7432 - val_mse: 15821.7432 - 112ms/epoch - 2ms/step
# Epoch 100/3000
# 50/50 - 0s - loss: 102154.4453 - mse: 102154.4453 - val_loss: 15942.4785 - val_mse: 15942.4785 - 100ms/epoch - 2ms/step
# Epoch 101/3000
# 50/50 - 0s - loss: 102032.5000 - mse: 102032.5000 - val_loss: 15809.9238 - val_mse: 15809.9238 - 108ms/epoch - 2ms/step
# Epoch 102/3000
# 50/50 - 0s - loss: 102464.3047 - mse: 102464.3047 - val_loss: 15789.2275 - val_mse: 15789.2275 - 106ms/epoch - 2ms/step
# Epoch 103/3000
# 50/50 - 0s - loss: 102201.4688 - mse: 102201.4688 - val_loss: 15814.2910 - val_mse: 15814.2910 - 101ms/epoch - 2ms/step
# Epoch 104/3000
# 50/50 - 0s - loss: 102107.5469 - mse: 102107.5469 - val_loss: 15709.5518 - val_mse: 15709.5518 - 104ms/epoch - 2ms/step
# Epoch 105/3000
# 50/50 - 0s - loss: 103281.3672 - mse: 103281.3672 - val_loss: 15829.1055 - val_mse: 15829.1055 - 108ms/epoch - 2ms/step
# Epoch 106/3000
# 50/50 - 0s - loss: 102049.0469 - mse: 102049.0469 - val_loss: 15818.0811 - val_mse: 15818.0811 - 107ms/epoch - 2ms/step
# Epoch 107/3000
# 50/50 - 0s - loss: 101813.8281 - mse: 101813.8281 - val_loss: 15651.6172 - val_mse: 15651.6172 - 114ms/epoch - 2ms/step
# Epoch 108/3000
# 50/50 - 0s - loss: 102072.3203 - mse: 102072.3203 - val_loss: 15872.6123 - val_mse: 15872.6123 - 103ms/epoch - 2ms/step
# Epoch 109/3000
# 50/50 - 0s - loss: 101637.7031 - mse: 101637.7031 - val_loss: 15617.1826 - val_mse: 15617.1826 - 118ms/epoch - 2ms/step
# Epoch 110/3000
# 50/50 - 0s - loss: 102104.1562 - mse: 102104.1562 - val_loss: 15991.3037 - val_mse: 15991.3037 - 103ms/epoch - 2ms/step
# Epoch 111/3000
# 50/50 - 0s - loss: 101622.7344 - mse: 101622.7344 - val_loss: 15647.0166 - val_mse: 15647.0166 - 106ms/epoch - 2ms/step
# Epoch 112/3000
# 50/50 - 0s - loss: 101933.9688 - mse: 101933.9688 - val_loss: 16094.2539 - val_mse: 16094.2539 - 108ms/epoch - 2ms/step
# Epoch 113/3000
# 50/50 - 0s - loss: 102101.8594 - mse: 102101.8594 - val_loss: 16040.8994 - val_mse: 16040.8994 - 109ms/epoch - 2ms/step
# Epoch 114/3000
# 50/50 - 0s - loss: 101487.6250 - mse: 101487.6250 - val_loss: 15758.7676 - val_mse: 15758.7676 - 109ms/epoch - 2ms/step
# Epoch 115/3000
# 50/50 - 0s - loss: 102067.5469 - mse: 102067.5469 - val_loss: 15911.2305 - val_mse: 15911.2305 - 101ms/epoch - 2ms/step
# Epoch 116/3000
# 50/50 - 0s - loss: 101772.2812 - mse: 101772.2812 - val_loss: 15593.4043 - val_mse: 15593.4043 - 107ms/epoch - 2ms/step
# Epoch 117/3000
# 50/50 - 0s - loss: 101619.8125 - mse: 101619.8125 - val_loss: 15451.1924 - val_mse: 15451.1924 - 111ms/epoch - 2ms/step
# Epoch 118/3000
# 50/50 - 0s - loss: 102220.6641 - mse: 102220.6641 - val_loss: 15773.4941 - val_mse: 15773.4941 - 101ms/epoch - 2ms/step
# Epoch 119/3000
# 50/50 - 0s - loss: 101421.9766 - mse: 101421.9766 - val_loss: 15520.7451 - val_mse: 15520.7451 - 99ms/epoch - 2ms/step
# Epoch 120/3000
# 50/50 - 0s - loss: 101377.3516 - mse: 101377.3516 - val_loss: 15543.3066 - val_mse: 15543.3066 - 99ms/epoch - 2ms/step
# Epoch 121/3000
# 50/50 - 0s - loss: 103546.1562 - mse: 103546.1562 - val_loss: 17716.1270 - val_mse: 17716.1270 - 101ms/epoch - 2ms/step
# Epoch 122/3000
# 50/50 - 0s - loss: 106304.1953 - mse: 106304.1953 - val_loss: 17714.0898 - val_mse: 17714.0898 - 100ms/epoch - 2ms/step
# Epoch 123/3000
# 50/50 - 0s - loss: 106302.3750 - mse: 106302.3750 - val_loss: 17713.8438 - val_mse: 17713.8438 - 100ms/epoch - 2ms/step
# Epoch 124/3000
# 50/50 - 0s - loss: 106301.7500 - mse: 106301.7500 - val_loss: 17713.7891 - val_mse: 17713.7891 - 102ms/epoch - 2ms/step
# Epoch 125/3000
# 50/50 - 0s - loss: 106301.2891 - mse: 106301.2891 - val_loss: 17713.8008 - val_mse: 17713.8008 - 97ms/epoch - 2ms/step
# Epoch 126/3000
# 50/50 - 0s - loss: 106301.1094 - mse: 106301.1094 - val_loss: 17713.8223 - val_mse: 17713.8223 - 101ms/epoch - 2ms/step
# Epoch 127/3000
# 50/50 - 0s - loss: 106301.3516 - mse: 106301.3516 - val_loss: 17713.8145 - val_mse: 17713.8145 - 101ms/epoch - 2ms/step
# Epoch 128/3000
# 50/50 - 0s - loss: 106301.2969 - mse: 106301.2969 - val_loss: 17713.8008 - val_mse: 17713.8008 - 96ms/epoch - 2ms/step
# Epoch 129/3000
# 50/50 - 0s - loss: 106300.8984 - mse: 106300.8984 - val_loss: 17713.7969 - val_mse: 17713.7969 - 101ms/epoch - 2ms/step
# Epoch 130/3000
# 50/50 - 0s - loss: 106301.0703 - mse: 106301.0703 - val_loss: 17713.8418 - val_mse: 17713.8418 - 99ms/epoch - 2ms/step
# Epoch 131/3000
# 50/50 - 0s - loss: 106301.0078 - mse: 106301.0078 - val_loss: 17713.8594 - val_mse: 17713.8594 - 98ms/epoch - 2ms/step
# Epoch 132/3000
# 50/50 - 0s - loss: 106300.6797 - mse: 106300.6953 - val_loss: 17713.9238 - val_mse: 17713.9238 - 105ms/epoch - 2ms/step
# Epoch 133/3000
# 50/50 - 0s - loss: 106300.8594 - mse: 106300.8594 - val_loss: 17713.8945 - val_mse: 17713.8945 - 100ms/epoch - 2ms/step
# Epoch 134/3000
# 50/50 - 0s - loss: 106300.6719 - mse: 106300.6719 - val_loss: 17713.9473 - val_mse: 17713.9473 - 105ms/epoch - 2ms/step
# Epoch 135/3000
# 50/50 - 0s - loss: 106301.1250 - mse: 106301.1250 - val_loss: 17713.8730 - val_mse: 17713.8730 - 104ms/epoch - 2ms/step
# Epoch 136/3000
# 50/50 - 0s - loss: 106300.7344 - mse: 106300.7344 - val_loss: 17713.9355 - val_mse: 17713.9355 - 100ms/epoch - 2ms/step
# Epoch 137/3000
# 50/50 - 0s - loss: 106300.7656 - mse: 106300.7656 - val_loss: 17713.9414 - val_mse: 17713.9414 - 96ms/epoch - 2ms/step
# Epoch 138/3000
# 50/50 - 0s - loss: 106300.6484 - mse: 106300.6484 - val_loss: 17714.0156 - val_mse: 17714.0156 - 101ms/epoch - 2ms/step
# Epoch 139/3000
# 50/50 - 0s - loss: 106300.5703 - mse: 106300.5703 - val_loss: 17713.9180 - val_mse: 17713.9180 - 98ms/epoch - 2ms/step
# Epoch 140/3000
# 50/50 - 0s - loss: 106300.7344 - mse: 106300.7344 - val_loss: 17713.9316 - val_mse: 17713.9316 - 98ms/epoch - 2ms/step
# Epoch 141/3000
# 50/50 - 0s - loss: 106300.6172 - mse: 106300.6172 - val_loss: 17713.9609 - val_mse: 17713.9609 - 99ms/epoch - 2ms/step
# Epoch 142/3000
# 50/50 - 0s - loss: 106300.5312 - mse: 106300.5312 - val_loss: 17713.9609 - val_mse: 17713.9609 - 98ms/epoch - 2ms/step
# Epoch 143/3000
# 50/50 - 0s - loss: 106300.5625 - mse: 106300.5625 - val_loss: 17713.9414 - val_mse: 17713.9414 - 105ms/epoch - 2ms/step
# Epoch 144/3000
# 50/50 - 0s - loss: 106300.7031 - mse: 106300.7031 - val_loss: 17713.9434 - val_mse: 17713.9434 - 99ms/epoch - 2ms/step
# Epoch 145/3000
# 50/50 - 0s - loss: 106300.8047 - mse: 106300.8047 - val_loss: 17713.9199 - val_mse: 17713.9199 - 98ms/epoch - 2ms/step
# Epoch 146/3000
# 50/50 - 0s - loss: 106300.6797 - mse: 106300.6797 - val_loss: 17713.9219 - val_mse: 17713.9219 - 99ms/epoch - 2ms/step
# Epoch 147/3000
# 50/50 - 0s - loss: 106301.0234 - mse: 106301.0234 - val_loss: 17713.8672 - val_mse: 17713.8672 - 101ms/epoch - 2ms/step
# Epoch 148/3000
# 50/50 - 0s - loss: 106300.5781 - mse: 106300.5781 - val_loss: 17713.8535 - val_mse: 17713.8535 - 98ms/epoch - 2ms/step
# Epoch 149/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.8672 - val_mse: 17713.8672 - 99ms/epoch - 2ms/step
# Epoch 150/3000
# 50/50 - 0s - loss: 106300.9766 - mse: 106300.9766 - val_loss: 17713.8672 - val_mse: 17713.8672 - 96ms/epoch - 2ms/step
# Epoch 151/3000
# 50/50 - 0s - loss: 106300.5391 - mse: 106300.5391 - val_loss: 17713.8438 - val_mse: 17713.8438 - 107ms/epoch - 2ms/step
# Epoch 152/3000
# 50/50 - 0s - loss: 106300.8438 - mse: 106300.8438 - val_loss: 17713.8867 - val_mse: 17713.8867 - 99ms/epoch - 2ms/step
# Epoch 153/3000
# 50/50 - 0s - loss: 106300.5156 - mse: 106300.5156 - val_loss: 17713.8145 - val_mse: 17713.8145 - 101ms/epoch - 2ms/step
# Epoch 154/3000
# 50/50 - 0s - loss: 106300.9766 - mse: 106300.9766 - val_loss: 17713.8223 - val_mse: 17713.8223 - 107ms/epoch - 2ms/step
# Epoch 155/3000
# 50/50 - 0s - loss: 106301.0938 - mse: 106301.0938 - val_loss: 17713.8438 - val_mse: 17713.8438 - 106ms/epoch - 2ms/step
# Epoch 156/3000
# 50/50 - 0s - loss: 106301.0703 - mse: 106301.0703 - val_loss: 17713.8535 - val_mse: 17713.8535 - 105ms/epoch - 2ms/step
# Epoch 157/3000
# 50/50 - 0s - loss: 106300.7812 - mse: 106300.7812 - val_loss: 17713.9219 - val_mse: 17713.9219 - 103ms/epoch - 2ms/step
# Epoch 158/3000
# 50/50 - 0s - loss: 106301.0312 - mse: 106301.0312 - val_loss: 17713.8594 - val_mse: 17713.8594 - 114ms/epoch - 2ms/step
# Epoch 159/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.9062 - val_mse: 17713.9062 - 102ms/epoch - 2ms/step
# Epoch 160/3000
# 50/50 - 0s - loss: 106300.6641 - mse: 106300.6641 - val_loss: 17713.9414 - val_mse: 17713.9414 - 98ms/epoch - 2ms/step
# Epoch 161/3000
# 50/50 - 0s - loss: 106300.6719 - mse: 106300.6719 - val_loss: 17713.9414 - val_mse: 17713.9414 - 100ms/epoch - 2ms/step
# Epoch 162/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17713.9297 - val_mse: 17713.9297 - 107ms/epoch - 2ms/step
# Epoch 163/3000
# 50/50 - 0s - loss: 106301.0781 - mse: 106301.0781 - val_loss: 17713.8672 - val_mse: 17713.8672 - 98ms/epoch - 2ms/step
# Epoch 164/3000
# 50/50 - 0s - loss: 106300.7656 - mse: 106300.7656 - val_loss: 17713.9102 - val_mse: 17713.9102 - 98ms/epoch - 2ms/step
# Epoch 165/3000
# 50/50 - 0s - loss: 106300.7656 - mse: 106300.7656 - val_loss: 17713.8438 - val_mse: 17713.8438 - 104ms/epoch - 2ms/step
# Epoch 166/3000
# 50/50 - 0s - loss: 106301.0938 - mse: 106301.0938 - val_loss: 17713.8496 - val_mse: 17713.8496 - 99ms/epoch - 2ms/step
# Epoch 167/3000
# 50/50 - 0s - loss: 106301.1719 - mse: 106301.1719 - val_loss: 17713.8516 - val_mse: 17713.8516 - 101ms/epoch - 2ms/step
# Epoch 168/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.8496 - val_mse: 17713.8496 - 98ms/epoch - 2ms/step
# Epoch 169/3000
# 50/50 - 0s - loss: 106301.2031 - mse: 106301.2031 - val_loss: 17713.8301 - val_mse: 17713.8301 - 97ms/epoch - 2ms/step
# Epoch 170/3000
# 50/50 - 0s - loss: 106301.1328 - mse: 106301.1328 - val_loss: 17713.8477 - val_mse: 17713.8477 - 98ms/epoch - 2ms/step
# Epoch 171/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.9219 - val_mse: 17713.9219 - 99ms/epoch - 2ms/step
# Epoch 172/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17713.9941 - val_mse: 17713.9941 - 102ms/epoch - 2ms/step
# Epoch 173/3000
# 50/50 - 0s - loss: 106300.7031 - mse: 106300.7031 - val_loss: 17713.9531 - val_mse: 17713.9531 - 98ms/epoch - 2ms/step
# Epoch 174/3000
# 50/50 - 0s - loss: 106300.4297 - mse: 106300.4297 - val_loss: 17713.8965 - val_mse: 17713.8965 - 102ms/epoch - 2ms/step
# Epoch 175/3000
# 50/50 - 0s - loss: 106300.4688 - mse: 106300.4688 - val_loss: 17713.8496 - val_mse: 17713.8496 - 102ms/epoch - 2ms/step
# Epoch 176/3000
# 50/50 - 0s - loss: 106301.1250 - mse: 106301.1250 - val_loss: 17713.8262 - val_mse: 17713.8262 - 102ms/epoch - 2ms/step
# Epoch 177/3000
# 50/50 - 0s - loss: 106301.0000 - mse: 106301.0000 - val_loss: 17713.8594 - val_mse: 17713.8594 - 108ms/epoch - 2ms/step
# Epoch 178/3000
# 50/50 - 0s - loss: 106301.0078 - mse: 106301.0078 - val_loss: 17713.8887 - val_mse: 17713.8887 - 107ms/epoch - 2ms/step
# Epoch 179/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.8633 - val_mse: 17713.8633 - 108ms/epoch - 2ms/step
# Epoch 180/3000
# 50/50 - 0s - loss: 106300.7812 - mse: 106300.7812 - val_loss: 17713.9355 - val_mse: 17713.9355 - 112ms/epoch - 2ms/step
# Epoch 181/3000
# 50/50 - 0s - loss: 106301.0781 - mse: 106301.0781 - val_loss: 17713.8633 - val_mse: 17713.8633 - 100ms/epoch - 2ms/step
# Epoch 182/3000
# 50/50 - 0s - loss: 106300.8984 - mse: 106300.8984 - val_loss: 17713.8926 - val_mse: 17713.8926 - 102ms/epoch - 2ms/step
# Epoch 183/3000
# 50/50 - 0s - loss: 106300.7422 - mse: 106300.7422 - val_loss: 17713.9570 - val_mse: 17713.9570 - 99ms/epoch - 2ms/step
# Epoch 184/3000
# 50/50 - 0s - loss: 106300.5000 - mse: 106300.5000 - val_loss: 17713.9609 - val_mse: 17713.9609 - 101ms/epoch - 2ms/step
# Epoch 185/3000
# 50/50 - 0s - loss: 106300.4844 - mse: 106300.4844 - val_loss: 17713.9531 - val_mse: 17713.9531 - 101ms/epoch - 2ms/step
# Epoch 186/3000
# 50/50 - 0s - loss: 106300.9297 - mse: 106300.9297 - val_loss: 17713.9160 - val_mse: 17713.9160 - 99ms/epoch - 2ms/step
# Epoch 187/3000
# 50/50 - 0s - loss: 106300.5938 - mse: 106300.5938 - val_loss: 17713.9355 - val_mse: 17713.9355 - 103ms/epoch - 2ms/step
# Epoch 188/3000
# 50/50 - 0s - loss: 106301.2969 - mse: 106301.2969 - val_loss: 17713.8398 - val_mse: 17713.8398 - 101ms/epoch - 2ms/step
# Epoch 189/3000
# 50/50 - 0s - loss: 106301.0312 - mse: 106301.0312 - val_loss: 17713.8926 - val_mse: 17713.8926 - 104ms/epoch - 2ms/step
# Epoch 190/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.9297 - val_mse: 17713.9297 - 97ms/epoch - 2ms/step
# Epoch 191/3000
# 50/50 - 0s - loss: 106300.5078 - mse: 106300.5078 - val_loss: 17713.8945 - val_mse: 17713.8945 - 100ms/epoch - 2ms/step
# Epoch 192/3000
# 50/50 - 0s - loss: 106300.6094 - mse: 106300.6094 - val_loss: 17713.9355 - val_mse: 17713.9355 - 100ms/epoch - 2ms/step
# Epoch 193/3000
# 50/50 - 0s - loss: 106301.7969 - mse: 106301.7969 - val_loss: 17713.7871 - val_mse: 17713.7871 - 99ms/epoch - 2ms/step
# Epoch 194/3000
# 50/50 - 0s - loss: 106301.2891 - mse: 106301.2891 - val_loss: 17713.8184 - val_mse: 17713.8184 - 101ms/epoch - 2ms/step
# Epoch 195/3000
# 50/50 - 0s - loss: 106301.0312 - mse: 106301.0312 - val_loss: 17713.8477 - val_mse: 17713.8477 - 97ms/epoch - 2ms/step
# Epoch 196/3000
# 50/50 - 0s - loss: 106300.8594 - mse: 106300.8594 - val_loss: 17713.8809 - val_mse: 17713.8809 - 101ms/epoch - 2ms/step
# Epoch 197/3000
# 50/50 - 0s - loss: 106300.6953 - mse: 106300.6953 - val_loss: 17713.8945 - val_mse: 17713.8945 - 97ms/epoch - 2ms/step
# Epoch 198/3000
# 50/50 - 0s - loss: 106300.5469 - mse: 106300.5469 - val_loss: 17713.8438 - val_mse: 17713.8438 - 102ms/epoch - 2ms/step
# Epoch 199/3000
# 50/50 - 0s - loss: 106300.9453 - mse: 106300.9453 - val_loss: 17713.8711 - val_mse: 17713.8711 - 103ms/epoch - 2ms/step
# Epoch 200/3000
# 50/50 - 0s - loss: 106300.7031 - mse: 106300.7031 - val_loss: 17713.8809 - val_mse: 17713.8809 - 104ms/epoch - 2ms/step
# Epoch 201/3000
# 50/50 - 0s - loss: 106300.5938 - mse: 106300.5938 - val_loss: 17713.8301 - val_mse: 17713.8301 - 106ms/epoch - 2ms/step
# Epoch 202/3000
# 50/50 - 0s - loss: 106301.4688 - mse: 106301.4688 - val_loss: 17713.8008 - val_mse: 17713.8008 - 108ms/epoch - 2ms/step
# Epoch 203/3000
# 50/50 - 0s - loss: 106301.0234 - mse: 106301.0234 - val_loss: 17713.8398 - val_mse: 17713.8398 - 103ms/epoch - 2ms/step
# Epoch 204/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.8789 - val_mse: 17713.8789 - 100ms/epoch - 2ms/step
# Epoch 205/3000
# 50/50 - 0s - loss: 106301.0000 - mse: 106301.0000 - val_loss: 17713.8691 - val_mse: 17713.8691 - 102ms/epoch - 2ms/step
# Epoch 206/3000
# 50/50 - 0s - loss: 106300.6953 - mse: 106300.6953 - val_loss: 17713.8965 - val_mse: 17713.8965 - 99ms/epoch - 2ms/step
# Epoch 207/3000
# 50/50 - 0s - loss: 106300.6328 - mse: 106300.6328 - val_loss: 17713.9336 - val_mse: 17713.9336 - 100ms/epoch - 2ms/step
# Epoch 208/3000
# 50/50 - 0s - loss: 106300.6953 - mse: 106300.6953 - val_loss: 17713.9531 - val_mse: 17713.9531 - 102ms/epoch - 2ms/step
# Epoch 209/3000
# 50/50 - 0s - loss: 106300.5000 - mse: 106300.5000 - val_loss: 17713.9922 - val_mse: 17713.9922 - 104ms/epoch - 2ms/step
# Epoch 210/3000
# 50/50 - 0s - loss: 106300.9453 - mse: 106300.9453 - val_loss: 17713.8906 - val_mse: 17713.8906 - 102ms/epoch - 2ms/step
# Epoch 211/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.8887 - val_mse: 17713.8887 - 100ms/epoch - 2ms/step
# Epoch 212/3000
# 50/50 - 0s - loss: 106300.6406 - mse: 106300.6406 - val_loss: 17713.9531 - val_mse: 17713.9531 - 99ms/epoch - 2ms/step
# Epoch 213/3000
# 50/50 - 0s - loss: 106300.6094 - mse: 106300.6094 - val_loss: 17714.0215 - val_mse: 17714.0215 - 99ms/epoch - 2ms/step
# Epoch 214/3000
# 50/50 - 0s - loss: 106300.7812 - mse: 106300.7812 - val_loss: 17713.9707 - val_mse: 17713.9707 - 101ms/epoch - 2ms/step
# Epoch 215/3000
# 50/50 - 0s - loss: 106300.6484 - mse: 106300.6484 - val_loss: 17714.0215 - val_mse: 17714.0215 - 99ms/epoch - 2ms/step
# Epoch 216/3000
# 50/50 - 0s - loss: 106300.3984 - mse: 106300.3984 - val_loss: 17714.0039 - val_mse: 17714.0039 - 100ms/epoch - 2ms/step
# Epoch 217/3000
# 50/50 - 0s - loss: 106300.7656 - mse: 106300.7656 - val_loss: 17713.9609 - val_mse: 17713.9609 - 100ms/epoch - 2ms/step
# Epoch 218/3000
# 50/50 - 0s - loss: 106300.4766 - mse: 106300.4766 - val_loss: 17713.9434 - val_mse: 17713.9434 - 99ms/epoch - 2ms/step
# Epoch 219/3000
# 50/50 - 0s - loss: 106300.6406 - mse: 106300.6328 - val_loss: 17713.9375 - val_mse: 17713.9375 - 100ms/epoch - 2ms/step
# Epoch 220/3000
# 50/50 - 0s - loss: 106300.3984 - mse: 106300.3984 - val_loss: 17713.8320 - val_mse: 17713.8320 - 98ms/epoch - 2ms/step
# Epoch 221/3000
# 50/50 - 0s - loss: 106301.0391 - mse: 106301.0391 - val_loss: 17713.8223 - val_mse: 17713.8223 - 101ms/epoch - 2ms/step
# Epoch 222/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.8477 - val_mse: 17713.8477 - 107ms/epoch - 2ms/step
# Epoch 223/3000
# 50/50 - 0s - loss: 106300.7578 - mse: 106300.7578 - val_loss: 17713.8770 - val_mse: 17713.8770 - 106ms/epoch - 2ms/step
# Epoch 224/3000
# 50/50 - 0s - loss: 106300.7656 - mse: 106300.7656 - val_loss: 17713.8848 - val_mse: 17713.8848 - 103ms/epoch - 2ms/step
# Epoch 225/3000
# 50/50 - 0s - loss: 106300.7344 - mse: 106300.7344 - val_loss: 17713.9062 - val_mse: 17713.9062 - 104ms/epoch - 2ms/step
# Epoch 226/3000
# 50/50 - 0s - loss: 106300.6719 - mse: 106300.6719 - val_loss: 17713.9414 - val_mse: 17713.9414 - 102ms/epoch - 2ms/step
# Epoch 227/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.9160 - val_mse: 17713.9160 - 102ms/epoch - 2ms/step
# Epoch 228/3000
# 50/50 - 0s - loss: 106301.1641 - mse: 106301.1641 - val_loss: 17713.8652 - val_mse: 17713.8652 - 105ms/epoch - 2ms/step
# Epoch 229/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.8535 - val_mse: 17713.8535 - 107ms/epoch - 2ms/step
# Epoch 230/3000
# 50/50 - 0s - loss: 106300.6719 - mse: 106300.6719 - val_loss: 17713.8164 - val_mse: 17713.8164 - 105ms/epoch - 2ms/step
# Epoch 231/3000
# 50/50 - 0s - loss: 106300.8047 - mse: 106300.8047 - val_loss: 17713.8516 - val_mse: 17713.8516 - 102ms/epoch - 2ms/step
# Epoch 232/3000
# 50/50 - 0s - loss: 106300.8672 - mse: 106300.8672 - val_loss: 17713.8809 - val_mse: 17713.8809 - 109ms/epoch - 2ms/step
# Epoch 233/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.9180 - val_mse: 17713.9180 - 103ms/epoch - 2ms/step
# Epoch 234/3000
# 50/50 - 0s - loss: 106300.6328 - mse: 106300.6328 - val_loss: 17713.9570 - val_mse: 17713.9570 - 104ms/epoch - 2ms/step
# Epoch 235/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17713.9688 - val_mse: 17713.9688 - 108ms/epoch - 2ms/step
# Epoch 236/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17714.0000 - val_mse: 17714.0000 - 101ms/epoch - 2ms/step
# Epoch 237/3000
# 50/50 - 0s - loss: 106300.7578 - mse: 106300.7578 - val_loss: 17713.9980 - val_mse: 17713.9980 - 110ms/epoch - 2ms/step
# Epoch 238/3000
# 50/50 - 0s - loss: 106300.7578 - mse: 106300.7578 - val_loss: 17714.0000 - val_mse: 17714.0000 - 103ms/epoch - 2ms/step
# Epoch 239/3000
# 50/50 - 0s - loss: 106300.5156 - mse: 106300.5156 - val_loss: 17714.0957 - val_mse: 17714.0957 - 104ms/epoch - 2ms/step
# Epoch 240/3000
# 50/50 - 0s - loss: 106300.7422 - mse: 106300.7422 - val_loss: 17714.0234 - val_mse: 17714.0234 - 102ms/epoch - 2ms/step
# Epoch 241/3000
# 50/50 - 0s - loss: 106300.5078 - mse: 106300.5078 - val_loss: 17713.9980 - val_mse: 17713.9980 - 104ms/epoch - 2ms/step
# Epoch 242/3000
# 50/50 - 0s - loss: 106300.3750 - mse: 106300.3750 - val_loss: 17713.9336 - val_mse: 17713.9336 - 104ms/epoch - 2ms/step
# Epoch 243/3000
# 50/50 - 0s - loss: 106301.5000 - mse: 106301.5000 - val_loss: 17713.7949 - val_mse: 17713.7949 - 105ms/epoch - 2ms/step
# Epoch 244/3000
# 50/50 - 0s - loss: 106301.2266 - mse: 106301.2266 - val_loss: 17713.8320 - val_mse: 17713.8320 - 106ms/epoch - 2ms/step
# Epoch 245/3000
# 50/50 - 0s - loss: 106300.8906 - mse: 106300.8906 - val_loss: 17713.8320 - val_mse: 17713.8320 - 107ms/epoch - 2ms/step
# Epoch 246/3000
# 50/50 - 0s - loss: 106301.0703 - mse: 106301.0703 - val_loss: 17713.8516 - val_mse: 17713.8516 - 100ms/epoch - 2ms/step
# Epoch 247/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.8672 - val_mse: 17713.8672 - 100ms/epoch - 2ms/step
# Epoch 248/3000
# 50/50 - 0s - loss: 106300.5781 - mse: 106300.5781 - val_loss: 17713.9141 - val_mse: 17713.9141 - 103ms/epoch - 2ms/step
# Epoch 249/3000
# 50/50 - 0s - loss: 106300.8984 - mse: 106300.8984 - val_loss: 17713.8906 - val_mse: 17713.8906 - 102ms/epoch - 2ms/step
# Epoch 250/3000
# 50/50 - 0s - loss: 106300.7266 - mse: 106300.7266 - val_loss: 17713.9355 - val_mse: 17713.9355 - 104ms/epoch - 2ms/step
# Epoch 251/3000
# 50/50 - 0s - loss: 106300.7266 - mse: 106300.7266 - val_loss: 17713.9414 - val_mse: 17713.9414 - 105ms/epoch - 2ms/step
# Epoch 252/3000
# 50/50 - 0s - loss: 106300.7578 - mse: 106300.7578 - val_loss: 17713.9805 - val_mse: 17713.9805 - 109ms/epoch - 2ms/step
# Epoch 253/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.8965 - val_mse: 17713.8965 - 104ms/epoch - 2ms/step
# Epoch 254/3000
# 50/50 - 0s - loss: 106300.7656 - mse: 106300.7656 - val_loss: 17713.9590 - val_mse: 17713.9590 - 99ms/epoch - 2ms/step
# Epoch 255/3000
# 50/50 - 0s - loss: 106300.6406 - mse: 106300.6406 - val_loss: 17714.0215 - val_mse: 17714.0215 - 99ms/epoch - 2ms/step
# Epoch 256/3000
# 50/50 - 0s - loss: 106300.5156 - mse: 106300.5156 - val_loss: 17714.0312 - val_mse: 17714.0312 - 99ms/epoch - 2ms/step
# Epoch 257/3000
# 50/50 - 0s - loss: 106300.9453 - mse: 106300.9453 - val_loss: 17713.9258 - val_mse: 17713.9258 - 103ms/epoch - 2ms/step
# Epoch 258/3000
# 50/50 - 0s - loss: 106300.6172 - mse: 106300.6172 - val_loss: 17713.9434 - val_mse: 17713.9434 - 106ms/epoch - 2ms/step
# Epoch 259/3000
# 50/50 - 0s - loss: 106300.6094 - mse: 106300.6094 - val_loss: 17714.0098 - val_mse: 17714.0098 - 104ms/epoch - 2ms/step
# Epoch 260/3000
# 50/50 - 0s - loss: 106300.6641 - mse: 106300.6641 - val_loss: 17714.0156 - val_mse: 17714.0156 - 99ms/epoch - 2ms/step
# Epoch 261/3000
# 50/50 - 0s - loss: 106300.6406 - mse: 106300.6406 - val_loss: 17714.0117 - val_mse: 17714.0117 - 98ms/epoch - 2ms/step
# Epoch 262/3000
# 50/50 - 0s - loss: 106300.4531 - mse: 106300.4531 - val_loss: 17714.0098 - val_mse: 17714.0098 - 98ms/epoch - 2ms/step
# Epoch 263/3000
# 50/50 - 0s - loss: 106300.4297 - mse: 106300.4297 - val_loss: 17713.9746 - val_mse: 17713.9746 - 101ms/epoch - 2ms/step
# Epoch 264/3000
# 50/50 - 0s - loss: 106300.7422 - mse: 106300.7422 - val_loss: 17713.9375 - val_mse: 17713.9375 - 104ms/epoch - 2ms/step
# Epoch 265/3000
# 50/50 - 0s - loss: 106300.5781 - mse: 106300.5781 - val_loss: 17713.8945 - val_mse: 17713.8945 - 105ms/epoch - 2ms/step
# Epoch 266/3000
# 50/50 - 0s - loss: 106300.5781 - mse: 106300.5781 - val_loss: 17713.8789 - val_mse: 17713.8789 - 106ms/epoch - 2ms/step
# Epoch 267/3000
# 50/50 - 0s - loss: 106300.8984 - mse: 106300.8984 - val_loss: 17713.8691 - val_mse: 17713.8691 - 100ms/epoch - 2ms/step
# Epoch 268/3000
# 50/50 - 0s - loss: 106301.3984 - mse: 106301.3984 - val_loss: 17713.8145 - val_mse: 17713.8145 - 109ms/epoch - 2ms/step
# Epoch 269/3000
# 50/50 - 0s - loss: 106300.9297 - mse: 106300.9297 - val_loss: 17713.8711 - val_mse: 17713.8711 - 100ms/epoch - 2ms/step
# Epoch 270/3000
# 50/50 - 0s - loss: 106300.6641 - mse: 106300.6641 - val_loss: 17713.8691 - val_mse: 17713.8691 - 100ms/epoch - 2ms/step
# Epoch 271/3000
# 50/50 - 0s - loss: 106301.4297 - mse: 106301.4297 - val_loss: 17713.8047 - val_mse: 17713.8047 - 107ms/epoch - 2ms/step
# Epoch 272/3000
# 50/50 - 0s - loss: 106300.9141 - mse: 106300.9141 - val_loss: 17713.8438 - val_mse: 17713.8438 - 111ms/epoch - 2ms/step
# Epoch 273/3000
# 50/50 - 0s - loss: 106301.0234 - mse: 106301.0234 - val_loss: 17713.8770 - val_mse: 17713.8770 - 105ms/epoch - 2ms/step
# Epoch 274/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.8730 - val_mse: 17713.8730 - 107ms/epoch - 2ms/step
# Epoch 275/3000
# 50/50 - 0s - loss: 106300.8906 - mse: 106300.8906 - val_loss: 17713.9062 - val_mse: 17713.9062 - 102ms/epoch - 2ms/step
# Epoch 276/3000
# 50/50 - 0s - loss: 106301.1328 - mse: 106301.1328 - val_loss: 17713.8633 - val_mse: 17713.8633 - 111ms/epoch - 2ms/step
# Epoch 277/3000
# 50/50 - 0s - loss: 106300.6328 - mse: 106300.6328 - val_loss: 17713.8926 - val_mse: 17713.8926 - 107ms/epoch - 2ms/step
# Epoch 278/3000
# 50/50 - 0s - loss: 106300.7812 - mse: 106300.7812 - val_loss: 17713.9160 - val_mse: 17713.9160 - 104ms/epoch - 2ms/step
# Epoch 279/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.9238 - val_mse: 17713.9238 - 103ms/epoch - 2ms/step
# Epoch 280/3000
# 50/50 - 0s - loss: 106300.5391 - mse: 106300.5391 - val_loss: 17713.9375 - val_mse: 17713.9375 - 106ms/epoch - 2ms/step
# Epoch 281/3000
# 50/50 - 0s - loss: 106301.1094 - mse: 106301.1094 - val_loss: 17713.8359 - val_mse: 17713.8359 - 108ms/epoch - 2ms/step
# Epoch 282/3000
# 50/50 - 0s - loss: 106300.6953 - mse: 106300.6953 - val_loss: 17713.7910 - val_mse: 17713.7910 - 107ms/epoch - 2ms/step
# Epoch 283/3000
# 50/50 - 0s - loss: 106301.8125 - mse: 106301.8125 - val_loss: 17713.7910 - val_mse: 17713.7910 - 105ms/epoch - 2ms/step
# Epoch 284/3000
# 50/50 - 0s - loss: 106301.3984 - mse: 106301.3984 - val_loss: 17713.8066 - val_mse: 17713.8066 - 106ms/epoch - 2ms/step
# Epoch 285/3000
# 50/50 - 0s - loss: 106301.0000 - mse: 106301.0000 - val_loss: 17713.8457 - val_mse: 17713.8457 - 105ms/epoch - 2ms/step
# Epoch 286/3000
# 50/50 - 0s - loss: 106301.0703 - mse: 106301.0703 - val_loss: 17713.8477 - val_mse: 17713.8477 - 106ms/epoch - 2ms/step
# Epoch 287/3000
# 50/50 - 0s - loss: 106301.0234 - mse: 106301.0234 - val_loss: 17713.8672 - val_mse: 17713.8672 - 102ms/epoch - 2ms/step
# Epoch 288/3000
# 50/50 - 0s - loss: 106300.6641 - mse: 106300.6641 - val_loss: 17713.8691 - val_mse: 17713.8691 - 103ms/epoch - 2ms/step
# Epoch 289/3000
# 50/50 - 0s - loss: 106301.0078 - mse: 106301.0078 - val_loss: 17713.8457 - val_mse: 17713.8457 - 104ms/epoch - 2ms/step
# Epoch 290/3000
# 50/50 - 0s - loss: 106300.8594 - mse: 106300.8594 - val_loss: 17713.8945 - val_mse: 17713.8945 - 104ms/epoch - 2ms/step
# Epoch 291/3000
# 50/50 - 0s - loss: 106301.4609 - mse: 106301.4609 - val_loss: 17713.8105 - val_mse: 17713.8105 - 105ms/epoch - 2ms/step
# Epoch 292/3000
# 50/50 - 0s - loss: 106300.9766 - mse: 106300.9766 - val_loss: 17713.8574 - val_mse: 17713.8574 - 111ms/epoch - 2ms/step
# Epoch 293/3000
# 50/50 - 0s - loss: 106300.8984 - mse: 106300.8984 - val_loss: 17713.8965 - val_mse: 17713.8965 - 109ms/epoch - 2ms/step
# Epoch 294/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.9473 - val_mse: 17713.9473 - 104ms/epoch - 2ms/step
# Epoch 295/3000
# 50/50 - 0s - loss: 106300.7266 - mse: 106300.7266 - val_loss: 17713.9805 - val_mse: 17713.9805 - 100ms/epoch - 2ms/step
# Epoch 296/3000
# 50/50 - 0s - loss: 106300.5000 - mse: 106300.5000 - val_loss: 17713.9707 - val_mse: 17713.9707 - 109ms/epoch - 2ms/step
# Epoch 297/3000
# 50/50 - 0s - loss: 106300.5469 - mse: 106300.5469 - val_loss: 17713.9922 - val_mse: 17713.9922 - 108ms/epoch - 2ms/step
# Epoch 298/3000
# 50/50 - 0s - loss: 106300.7109 - mse: 106300.7109 - val_loss: 17713.9707 - val_mse: 17713.9707 - 108ms/epoch - 2ms/step
# Epoch 299/3000
# 50/50 - 0s - loss: 106300.4062 - mse: 106300.4062 - val_loss: 17713.9180 - val_mse: 17713.9180 - 107ms/epoch - 2ms/step
# Epoch 300/3000
# 50/50 - 0s - loss: 106300.7422 - mse: 106300.7422 - val_loss: 17713.8496 - val_mse: 17713.8496 - 103ms/epoch - 2ms/step
# Epoch 301/3000
# 50/50 - 0s - loss: 106301.6953 - mse: 106301.6953 - val_loss: 17713.7910 - val_mse: 17713.7910 - 109ms/epoch - 2ms/step
# Epoch 302/3000
# 50/50 - 0s - loss: 106301.4062 - mse: 106301.4062 - val_loss: 17713.8066 - val_mse: 17713.8066 - 107ms/epoch - 2ms/step
# Epoch 303/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.8223 - val_mse: 17713.8223 - 97ms/epoch - 2ms/step
# Epoch 304/3000
# 50/50 - 0s - loss: 106300.8438 - mse: 106300.8438 - val_loss: 17713.8242 - val_mse: 17713.8242 - 102ms/epoch - 2ms/step
# Epoch 305/3000
# 50/50 - 0s - loss: 106300.8125 - mse: 106300.8125 - val_loss: 17713.8789 - val_mse: 17713.8789 - 103ms/epoch - 2ms/step
# Epoch 306/3000
# 50/50 - 0s - loss: 106300.7656 - mse: 106300.7656 - val_loss: 17713.9219 - val_mse: 17713.9219 - 96ms/epoch - 2ms/step
# Epoch 307/3000
# 50/50 - 0s - loss: 106301.2578 - mse: 106301.2578 - val_loss: 17713.8105 - val_mse: 17713.8105 - 105ms/epoch - 2ms/step
# Epoch 308/3000
# 50/50 - 0s - loss: 106300.9609 - mse: 106300.9609 - val_loss: 17713.8574 - val_mse: 17713.8574 - 97ms/epoch - 2ms/step
# Epoch 309/3000
# 50/50 - 0s - loss: 106301.0000 - mse: 106301.0000 - val_loss: 17713.8594 - val_mse: 17713.8594 - 101ms/epoch - 2ms/step
# Epoch 310/3000
# 50/50 - 0s - loss: 106300.9453 - mse: 106300.9453 - val_loss: 17713.8574 - val_mse: 17713.8574 - 98ms/epoch - 2ms/step
# Epoch 311/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.8965 - val_mse: 17713.8965 - 105ms/epoch - 2ms/step
# Epoch 312/3000
# 50/50 - 0s - loss: 106300.8672 - mse: 106300.8672 - val_loss: 17713.8926 - val_mse: 17713.8926 - 109ms/epoch - 2ms/step
# Epoch 313/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.8945 - val_mse: 17713.8945 - 105ms/epoch - 2ms/step
# Epoch 314/3000
# 50/50 - 0s - loss: 106300.6797 - mse: 106300.6797 - val_loss: 17713.9297 - val_mse: 17713.9297 - 102ms/epoch - 2ms/step
# Epoch 315/3000
# 50/50 - 0s - loss: 106300.8984 - mse: 106300.8984 - val_loss: 17713.8887 - val_mse: 17713.8887 - 100ms/epoch - 2ms/step
# Epoch 316/3000
# 50/50 - 0s - loss: 106300.9297 - mse: 106300.9297 - val_loss: 17713.8848 - val_mse: 17713.8848 - 107ms/epoch - 2ms/step
# Epoch 317/3000
# 50/50 - 0s - loss: 106300.7344 - mse: 106300.7344 - val_loss: 17713.9375 - val_mse: 17713.9375 - 113ms/epoch - 2ms/step
# Epoch 318/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.9316 - val_mse: 17713.9316 - 110ms/epoch - 2ms/step
# Epoch 319/3000
# 50/50 - 0s - loss: 106300.4062 - mse: 106300.4062 - val_loss: 17713.8672 - val_mse: 17713.8672 - 110ms/epoch - 2ms/step
# Epoch 320/3000
# 50/50 - 0s - loss: 106300.9297 - mse: 106300.9297 - val_loss: 17713.8633 - val_mse: 17713.8633 - 100ms/epoch - 2ms/step
# Epoch 321/3000
# 50/50 - 0s - loss: 106301.2266 - mse: 106301.2266 - val_loss: 17713.8359 - val_mse: 17713.8359 - 97ms/epoch - 2ms/step
# Epoch 322/3000
# 50/50 - 0s - loss: 106300.8047 - mse: 106300.8047 - val_loss: 17713.9160 - val_mse: 17713.9160 - 99ms/epoch - 2ms/step
# Epoch 323/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.9453 - val_mse: 17713.9453 - 101ms/epoch - 2ms/step
# Epoch 324/3000
# 50/50 - 0s - loss: 106300.5078 - mse: 106300.5078 - val_loss: 17713.9375 - val_mse: 17713.9375 - 97ms/epoch - 2ms/step
# Epoch 325/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.9160 - val_mse: 17713.9160 - 102ms/epoch - 2ms/step
# Epoch 326/3000
# 50/50 - 0s - loss: 106300.7578 - mse: 106300.7578 - val_loss: 17713.9531 - val_mse: 17713.9531 - 106ms/epoch - 2ms/step
# Epoch 327/3000
# 50/50 - 0s - loss: 106300.5781 - mse: 106300.5781 - val_loss: 17714.0078 - val_mse: 17714.0078 - 105ms/epoch - 2ms/step
# Epoch 328/3000
# 50/50 - 0s - loss: 106300.6406 - mse: 106300.6406 - val_loss: 17714.0078 - val_mse: 17714.0078 - 104ms/epoch - 2ms/step
# Epoch 329/3000
# 50/50 - 0s - loss: 106301.0078 - mse: 106301.0078 - val_loss: 17713.9160 - val_mse: 17713.9160 - 98ms/epoch - 2ms/step
# Epoch 330/3000
# 50/50 - 0s - loss: 106300.7109 - mse: 106300.7109 - val_loss: 17713.9434 - val_mse: 17713.9434 - 103ms/epoch - 2ms/step
# Epoch 331/3000
# 50/50 - 0s - loss: 106300.7422 - mse: 106300.7422 - val_loss: 17713.9219 - val_mse: 17713.9219 - 110ms/epoch - 2ms/step
# Epoch 332/3000
# 50/50 - 0s - loss: 106301.2578 - mse: 106301.2578 - val_loss: 17713.8457 - val_mse: 17713.8457 - 104ms/epoch - 2ms/step
# Epoch 333/3000
# 50/50 - 0s - loss: 106300.7422 - mse: 106300.7422 - val_loss: 17713.8730 - val_mse: 17713.8730 - 101ms/epoch - 2ms/step
# Epoch 334/3000
# 50/50 - 0s - loss: 106300.9609 - mse: 106300.9609 - val_loss: 17713.8574 - val_mse: 17713.8574 - 103ms/epoch - 2ms/step
# Epoch 335/3000
# 50/50 - 0s - loss: 106300.6719 - mse: 106300.6719 - val_loss: 17713.9062 - val_mse: 17713.9062 - 126ms/epoch - 3ms/step
# Epoch 336/3000
# 50/50 - 0s - loss: 106300.7266 - mse: 106300.7266 - val_loss: 17713.9609 - val_mse: 17713.9609 - 120ms/epoch - 2ms/step
# Epoch 337/3000
# 50/50 - 0s - loss: 106300.5469 - mse: 106300.5469 - val_loss: 17713.9980 - val_mse: 17713.9980 - 104ms/epoch - 2ms/step
# Epoch 338/3000
# 50/50 - 0s - loss: 106300.9297 - mse: 106300.9297 - val_loss: 17713.9160 - val_mse: 17713.9160 - 110ms/epoch - 2ms/step
# Epoch 339/3000
# 50/50 - 0s - loss: 106300.5703 - mse: 106300.5703 - val_loss: 17713.9297 - val_mse: 17713.9297 - 99ms/epoch - 2ms/step
# Epoch 340/3000
# 50/50 - 0s - loss: 106300.7656 - mse: 106300.7656 - val_loss: 17713.9590 - val_mse: 17713.9590 - 98ms/epoch - 2ms/step
# Epoch 341/3000
# 50/50 - 0s - loss: 106301.0234 - mse: 106301.0234 - val_loss: 17713.9062 - val_mse: 17713.9062 - 99ms/epoch - 2ms/step
# Epoch 342/3000
# 50/50 - 0s - loss: 106300.7031 - mse: 106300.7031 - val_loss: 17713.9512 - val_mse: 17713.9512 - 99ms/epoch - 2ms/step
# Epoch 343/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17713.9922 - val_mse: 17713.9922 - 103ms/epoch - 2ms/step
# Epoch 344/3000
# 50/50 - 0s - loss: 106300.2656 - mse: 106300.2656 - val_loss: 17713.9434 - val_mse: 17713.9434 - 103ms/epoch - 2ms/step
# Epoch 345/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.8906 - val_mse: 17713.8906 - 105ms/epoch - 2ms/step
# Epoch 346/3000
# 50/50 - 0s - loss: 106301.0078 - mse: 106301.0078 - val_loss: 17713.8555 - val_mse: 17713.8555 - 99ms/epoch - 2ms/step
# Epoch 347/3000
# 50/50 - 0s - loss: 106301.1406 - mse: 106301.1406 - val_loss: 17713.8438 - val_mse: 17713.8438 - 101ms/epoch - 2ms/step
# Epoch 348/3000
# 50/50 - 0s - loss: 106300.8047 - mse: 106300.8047 - val_loss: 17713.8691 - val_mse: 17713.8691 - 100ms/epoch - 2ms/step
# Epoch 349/3000
# 50/50 - 0s - loss: 106301.2344 - mse: 106301.2344 - val_loss: 17713.8457 - val_mse: 17713.8457 - 105ms/epoch - 2ms/step
# Epoch 350/3000
# 50/50 - 0s - loss: 106300.9062 - mse: 106300.9062 - val_loss: 17713.8691 - val_mse: 17713.8691 - 104ms/epoch - 2ms/step
# Epoch 351/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.9258 - val_mse: 17713.9258 - 97ms/epoch - 2ms/step
# Epoch 352/3000
# 50/50 - 0s - loss: 106300.5469 - mse: 106300.5469 - val_loss: 17713.9668 - val_mse: 17713.9668 - 102ms/epoch - 2ms/step
# Epoch 353/3000
# 50/50 - 0s - loss: 106300.5938 - mse: 106300.5938 - val_loss: 17713.9746 - val_mse: 17713.9746 - 99ms/epoch - 2ms/step
# Epoch 354/3000
# 50/50 - 0s - loss: 106300.6797 - mse: 106300.6797 - val_loss: 17713.9980 - val_mse: 17713.9980 - 99ms/epoch - 2ms/step
# Epoch 355/3000
# 50/50 - 0s - loss: 106300.4453 - mse: 106300.4453 - val_loss: 17713.9863 - val_mse: 17713.9863 - 102ms/epoch - 2ms/step
# Epoch 356/3000
# 50/50 - 0s - loss: 106300.9453 - mse: 106300.9453 - val_loss: 17713.8438 - val_mse: 17713.8438 - 107ms/epoch - 2ms/step
# Epoch 357/3000
# ...
# Epoch 2884/3000
# 50/50 - 0s - loss: 106300.6953 - mse: 106300.6953 - val_loss: 17713.9551 - val_mse: 17713.9551 - 96ms/epoch - 2ms/step
# Epoch 2885/3000
# 50/50 - 0s - loss: 106301.3672 - mse: 106301.3672 - val_loss: 17713.8359 - val_mse: 17713.8359 - 96ms/epoch - 2ms/step
# Epoch 2886/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.9180 - val_mse: 17713.9180 - 99ms/epoch - 2ms/step
# Epoch 2887/3000
# 50/50 - 0s - loss: 106300.8438 - mse: 106300.8438 - val_loss: 17713.9336 - val_mse: 17713.9336 - 97ms/epoch - 2ms/step
# Epoch 2888/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.8926 - val_mse: 17713.8926 - 101ms/epoch - 2ms/step
# Epoch 2889/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.9297 - val_mse: 17713.9297 - 100ms/epoch - 2ms/step
# Epoch 2890/3000
# 50/50 - 0s - loss: 106300.7266 - mse: 106300.7266 - val_loss: 17713.8730 - val_mse: 17713.8730 - 97ms/epoch - 2ms/step
# Epoch 2891/3000
# 50/50 - 0s - loss: 106300.9688 - mse: 106300.9688 - val_loss: 17713.8418 - val_mse: 17713.8418 - 102ms/epoch - 2ms/step
# Epoch 2892/3000
# 50/50 - 0s - loss: 106300.9609 - mse: 106300.9609 - val_loss: 17713.8340 - val_mse: 17713.8340 - 98ms/epoch - 2ms/step
# Epoch 2893/3000
# 50/50 - 0s - loss: 106300.9062 - mse: 106300.9062 - val_loss: 17713.9082 - val_mse: 17713.9082 - 103ms/epoch - 2ms/step
# Epoch 2894/3000
# 50/50 - 0s - loss: 106300.5703 - mse: 106300.5703 - val_loss: 17713.9258 - val_mse: 17713.9258 - 106ms/epoch - 2ms/step
# Epoch 2895/3000
# 50/50 - 0s - loss: 106300.7422 - mse: 106300.7422 - val_loss: 17713.9512 - val_mse: 17713.9512 - 98ms/epoch - 2ms/step
# Epoch 2896/3000
# 50/50 - 0s - loss: 106300.7109 - mse: 106300.7109 - val_loss: 17713.9297 - val_mse: 17713.9297 - 103ms/epoch - 2ms/step
# Epoch 2897/3000
# 50/50 - 0s - loss: 106300.8047 - mse: 106300.8047 - val_loss: 17713.9551 - val_mse: 17713.9551 - 97ms/epoch - 2ms/step
# Epoch 2898/3000
# 50/50 - 0s - loss: 106300.8672 - mse: 106300.8672 - val_loss: 17713.9043 - val_mse: 17713.9043 - 104ms/epoch - 2ms/step
# Epoch 2899/3000
# 50/50 - 0s - loss: 106300.9688 - mse: 106300.9688 - val_loss: 17713.8945 - val_mse: 17713.8945 - 101ms/epoch - 2ms/step
# Epoch 2900/3000
# 50/50 - 0s - loss: 106300.5156 - mse: 106300.5156 - val_loss: 17713.8691 - val_mse: 17713.8691 - 98ms/epoch - 2ms/step
# Epoch 2901/3000
# 50/50 - 0s - loss: 106301.5703 - mse: 106301.5703 - val_loss: 17713.7930 - val_mse: 17713.7930 - 98ms/epoch - 2ms/step
# Epoch 2902/3000
# 50/50 - 0s - loss: 106301.0703 - mse: 106301.0703 - val_loss: 17713.8223 - val_mse: 17713.8223 - 100ms/epoch - 2ms/step
# Epoch 2903/3000
# 50/50 - 0s - loss: 106301.1328 - mse: 106301.1328 - val_loss: 17713.8242 - val_mse: 17713.8242 - 102ms/epoch - 2ms/step
# Epoch 2904/3000
# 50/50 - 0s - loss: 106300.9062 - mse: 106300.9062 - val_loss: 17713.8633 - val_mse: 17713.8633 - 110ms/epoch - 2ms/step
# Epoch 2905/3000
# 50/50 - 0s - loss: 106300.8672 - mse: 106300.8672 - val_loss: 17713.8672 - val_mse: 17713.8672 - 103ms/epoch - 2ms/step
# Epoch 2906/3000
# 50/50 - 0s - loss: 106300.9688 - mse: 106300.9688 - val_loss: 17713.8691 - val_mse: 17713.8691 - 108ms/epoch - 2ms/step
# Epoch 2907/3000
# 50/50 - 0s - loss: 106300.8984 - mse: 106300.8984 - val_loss: 17713.9180 - val_mse: 17713.9180 - 98ms/epoch - 2ms/step
# Epoch 2908/3000
# 50/50 - 0s - loss: 106300.6797 - mse: 106300.6797 - val_loss: 17713.9863 - val_mse: 17713.9863 - 103ms/epoch - 2ms/step
# Epoch 2909/3000
# 50/50 - 0s - loss: 106300.5703 - mse: 106300.5703 - val_loss: 17714.0078 - val_mse: 17714.0078 - 99ms/epoch - 2ms/step
# Epoch 2910/3000
# 50/50 - 0s - loss: 106300.5781 - mse: 106300.5781 - val_loss: 17714.0332 - val_mse: 17714.0332 - 102ms/epoch - 2ms/step
# Epoch 2911/3000
# 50/50 - 0s - loss: 106300.4141 - mse: 106300.4141 - val_loss: 17714.0879 - val_mse: 17714.0879 - 100ms/epoch - 2ms/step
# Epoch 2912/3000
# 50/50 - 0s - loss: 106300.2500 - mse: 106300.2500 - val_loss: 17713.9590 - val_mse: 17713.9590 - 101ms/epoch - 2ms/step
# Epoch 2913/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.8867 - val_mse: 17713.8867 - 107ms/epoch - 2ms/step
# Epoch 2914/3000
# 50/50 - 0s - loss: 106301.4688 - mse: 106301.4688 - val_loss: 17713.7988 - val_mse: 17713.7988 - 98ms/epoch - 2ms/step
# Epoch 2915/3000
# 50/50 - 0s - loss: 106300.9766 - mse: 106300.9766 - val_loss: 17713.8555 - val_mse: 17713.8555 - 99ms/epoch - 2ms/step
# Epoch 2916/3000
# 50/50 - 0s - loss: 106300.9609 - mse: 106300.9609 - val_loss: 17713.8223 - val_mse: 17713.8223 - 105ms/epoch - 2ms/step
# Epoch 2917/3000
# 50/50 - 0s - loss: 106300.9453 - mse: 106300.9453 - val_loss: 17713.8633 - val_mse: 17713.8633 - 98ms/epoch - 2ms/step
# Epoch 2918/3000
# 50/50 - 0s - loss: 106300.8906 - mse: 106300.8906 - val_loss: 17713.8672 - val_mse: 17713.8672 - 99ms/epoch - 2ms/step
# Epoch 2919/3000
# 50/50 - 0s - loss: 106300.6797 - mse: 106300.6797 - val_loss: 17713.8828 - val_mse: 17713.8828 - 108ms/epoch - 2ms/step
# Epoch 2920/3000
# 50/50 - 0s - loss: 106300.8438 - mse: 106300.8438 - val_loss: 17713.9062 - val_mse: 17713.9062 - 103ms/epoch - 2ms/step
# Epoch 2921/3000
# 50/50 - 0s - loss: 106300.4453 - mse: 106300.4453 - val_loss: 17713.8398 - val_mse: 17713.8398 - 100ms/epoch - 2ms/step
# Epoch 2922/3000
# 50/50 - 0s - loss: 106301.7812 - mse: 106301.7812 - val_loss: 17713.7852 - val_mse: 17713.7852 - 97ms/epoch - 2ms/step
# Epoch 2923/3000
# 50/50 - 0s - loss: 106301.2344 - mse: 106301.2344 - val_loss: 17713.8223 - val_mse: 17713.8223 - 95ms/epoch - 2ms/step
# Epoch 2924/3000
# 50/50 - 0s - loss: 106301.0781 - mse: 106301.0781 - val_loss: 17713.8496 - val_mse: 17713.8496 - 101ms/epoch - 2ms/step
# Epoch 2925/3000
# 50/50 - 0s - loss: 106300.7578 - mse: 106300.7578 - val_loss: 17713.8926 - val_mse: 17713.8926 - 94ms/epoch - 2ms/step
# Epoch 2926/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.8867 - val_mse: 17713.8867 - 95ms/epoch - 2ms/step
# Epoch 2927/3000
# 50/50 - 0s - loss: 106300.9453 - mse: 106300.9453 - val_loss: 17713.9082 - val_mse: 17713.9082 - 98ms/epoch - 2ms/step
# Epoch 2928/3000
# 50/50 - 0s - loss: 106300.8047 - mse: 106300.8047 - val_loss: 17713.9551 - val_mse: 17713.9551 - 102ms/epoch - 2ms/step
# Epoch 2929/3000
# 50/50 - 0s - loss: 106300.7031 - mse: 106300.7031 - val_loss: 17713.9688 - val_mse: 17713.9688 - 96ms/epoch - 2ms/step
# Epoch 2930/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17713.9922 - val_mse: 17713.9922 - 104ms/epoch - 2ms/step
# Epoch 2931/3000
# 50/50 - 0s - loss: 106300.4062 - mse: 106300.4062 - val_loss: 17713.9785 - val_mse: 17713.9785 - 95ms/epoch - 2ms/step
# Epoch 2932/3000
# 50/50 - 0s - loss: 106301.1328 - mse: 106301.1328 - val_loss: 17713.8379 - val_mse: 17713.8379 - 99ms/epoch - 2ms/step
# Epoch 2933/3000
# 50/50 - 0s - loss: 106300.8906 - mse: 106300.8906 - val_loss: 17713.8809 - val_mse: 17713.8809 - 94ms/epoch - 2ms/step
# Epoch 2934/3000
# 50/50 - 0s - loss: 106300.7422 - mse: 106300.7422 - val_loss: 17713.9199 - val_mse: 17713.9199 - 95ms/epoch - 2ms/step
# Epoch 2935/3000
# 50/50 - 0s - loss: 106300.5312 - mse: 106300.5312 - val_loss: 17713.8867 - val_mse: 17713.8867 - 97ms/epoch - 2ms/step
# Epoch 2936/3000
# 50/50 - 0s - loss: 106301.1016 - mse: 106301.1016 - val_loss: 17713.8633 - val_mse: 17713.8633 - 98ms/epoch - 2ms/step
# Epoch 2937/3000
# 50/50 - 0s - loss: 106300.9141 - mse: 106300.9141 - val_loss: 17713.9062 - val_mse: 17713.9062 - 97ms/epoch - 2ms/step
# Epoch 2938/3000
# 50/50 - 0s - loss: 106300.8125 - mse: 106300.8125 - val_loss: 17713.9551 - val_mse: 17713.9551 - 96ms/epoch - 2ms/step
# Epoch 2939/3000
# 50/50 - 0s - loss: 106300.5469 - mse: 106300.5469 - val_loss: 17713.9863 - val_mse: 17713.9863 - 98ms/epoch - 2ms/step
# Epoch 2940/3000
# 50/50 - 0s - loss: 106300.6484 - mse: 106300.6484 - val_loss: 17713.9629 - val_mse: 17713.9629 - 102ms/epoch - 2ms/step
# Epoch 2941/3000
# 50/50 - 0s - loss: 106300.5156 - mse: 106300.5156 - val_loss: 17713.9785 - val_mse: 17713.9785 - 100ms/epoch - 2ms/step
# Epoch 2942/3000
# 50/50 - 0s - loss: 106300.9141 - mse: 106300.9141 - val_loss: 17713.8965 - val_mse: 17713.8965 - 105ms/epoch - 2ms/step
# Epoch 2943/3000
# 50/50 - 0s - loss: 106300.6797 - mse: 106300.6797 - val_loss: 17713.8945 - val_mse: 17713.8945 - 106ms/epoch - 2ms/step
# Epoch 2944/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.9434 - val_mse: 17713.9434 - 98ms/epoch - 2ms/step
# Epoch 2945/3000
# 50/50 - 0s - loss: 106300.5078 - mse: 106300.5078 - val_loss: 17713.9590 - val_mse: 17713.9590 - 97ms/epoch - 2ms/step
# Epoch 2946/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.8652 - val_mse: 17713.8652 - 101ms/epoch - 2ms/step
# Epoch 2947/3000
# 50/50 - 0s - loss: 106300.9375 - mse: 106300.9375 - val_loss: 17713.8789 - val_mse: 17713.8789 - 98ms/epoch - 2ms/step
# Epoch 2948/3000
# 50/50 - 0s - loss: 106300.7578 - mse: 106300.7578 - val_loss: 17713.9082 - val_mse: 17713.9082 - 100ms/epoch - 2ms/step
# Epoch 2949/3000
# 50/50 - 0s - loss: 106300.9062 - mse: 106300.9062 - val_loss: 17713.9180 - val_mse: 17713.9180 - 98ms/epoch - 2ms/step
# Epoch 2950/3000
# 50/50 - 0s - loss: 106300.5938 - mse: 106300.5938 - val_loss: 17713.9453 - val_mse: 17713.9453 - 96ms/epoch - 2ms/step
# Epoch 2951/3000
# 50/50 - 0s - loss: 106300.6641 - mse: 106300.6641 - val_loss: 17713.9668 - val_mse: 17713.9668 - 99ms/epoch - 2ms/step
# Epoch 2952/3000
# 50/50 - 0s - loss: 106301.1641 - mse: 106301.1641 - val_loss: 17713.8145 - val_mse: 17713.8145 - 107ms/epoch - 2ms/step
# Epoch 2953/3000
# 50/50 - 0s - loss: 106300.9375 - mse: 106300.9375 - val_loss: 17713.8613 - val_mse: 17713.8613 - 99ms/epoch - 2ms/step
# Epoch 2954/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.8047 - val_mse: 17713.8047 - 103ms/epoch - 2ms/step
# Epoch 2955/3000
# 50/50 - 0s - loss: 106301.0078 - mse: 106301.0234 - val_loss: 17713.8496 - val_mse: 17713.8496 - 103ms/epoch - 2ms/step
# Epoch 2956/3000
# 50/50 - 0s - loss: 106301.3203 - mse: 106301.3203 - val_loss: 17713.8242 - val_mse: 17713.8242 - 103ms/epoch - 2ms/step
# Epoch 2957/3000
# 50/50 - 0s - loss: 106300.9609 - mse: 106300.9609 - val_loss: 17713.8848 - val_mse: 17713.8848 - 103ms/epoch - 2ms/step
# Epoch 2958/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17713.8926 - val_mse: 17713.8926 - 99ms/epoch - 2ms/step
# Epoch 2959/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.8848 - val_mse: 17713.8848 - 100ms/epoch - 2ms/step
# Epoch 2960/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.9141 - val_mse: 17713.9141 - 107ms/epoch - 2ms/step
# Epoch 2961/3000
# 50/50 - 0s - loss: 106300.8672 - mse: 106300.8672 - val_loss: 17713.9082 - val_mse: 17713.9082 - 100ms/epoch - 2ms/step
# Epoch 2962/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.9082 - val_mse: 17713.9082 - 105ms/epoch - 2ms/step
# Epoch 2963/3000
# 50/50 - 0s - loss: 106300.7031 - mse: 106300.7031 - val_loss: 17713.9629 - val_mse: 17713.9629 - 104ms/epoch - 2ms/step
# Epoch 2964/3000
# 50/50 - 0s - loss: 106300.5938 - mse: 106300.5938 - val_loss: 17713.9512 - val_mse: 17713.9512 - 99ms/epoch - 2ms/step
# Epoch 2965/3000
# 50/50 - 0s - loss: 106301.2109 - mse: 106301.2109 - val_loss: 17713.8477 - val_mse: 17713.8477 - 101ms/epoch - 2ms/step
# Epoch 2966/3000
# 50/50 - 0s - loss: 106300.8594 - mse: 106300.8594 - val_loss: 17713.8789 - val_mse: 17713.8789 - 101ms/epoch - 2ms/step
# Epoch 2967/3000
# 50/50 - 0s - loss: 106300.7812 - mse: 106300.7812 - val_loss: 17713.9180 - val_mse: 17713.9180 - 102ms/epoch - 2ms/step
# Epoch 2968/3000
# 50/50 - 0s - loss: 106300.6484 - mse: 106300.6484 - val_loss: 17713.9629 - val_mse: 17713.9629 - 105ms/epoch - 2ms/step
# Epoch 2969/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.9082 - val_mse: 17713.9082 - 101ms/epoch - 2ms/step
# Epoch 2970/3000
# 50/50 - 0s - loss: 106300.8906 - mse: 106300.8906 - val_loss: 17713.9141 - val_mse: 17713.9141 - 99ms/epoch - 2ms/step
# Epoch 2971/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17713.9316 - val_mse: 17713.9316 - 103ms/epoch - 2ms/step
# Epoch 2972/3000
# 50/50 - 0s - loss: 106300.8359 - mse: 106300.8359 - val_loss: 17713.9062 - val_mse: 17713.9062 - 112ms/epoch - 2ms/step
# Epoch 2973/3000
# 50/50 - 0s - loss: 106300.6719 - mse: 106300.6719 - val_loss: 17713.9375 - val_mse: 17713.9375 - 99ms/epoch - 2ms/step
# Epoch 2974/3000
# 50/50 - 0s - loss: 106300.5625 - mse: 106300.5625 - val_loss: 17713.9551 - val_mse: 17713.9551 - 102ms/epoch - 2ms/step
# Epoch 2975/3000
# 50/50 - 0s - loss: 106300.5469 - mse: 106300.5469 - val_loss: 17713.9531 - val_mse: 17713.9531 - 104ms/epoch - 2ms/step
# Epoch 2976/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.8809 - val_mse: 17713.8809 - 107ms/epoch - 2ms/step
# Epoch 2977/3000
# 50/50 - 0s - loss: 106300.6406 - mse: 106300.6406 - val_loss: 17713.9375 - val_mse: 17713.9375 - 102ms/epoch - 2ms/step
# Epoch 2978/3000
# 50/50 - 0s - loss: 106300.6484 - mse: 106300.6484 - val_loss: 17713.9629 - val_mse: 17713.9629 - 99ms/epoch - 2ms/step
# Epoch 2979/3000
# 50/50 - 0s - loss: 106300.5781 - mse: 106300.5781 - val_loss: 17713.9727 - val_mse: 17713.9727 - 103ms/epoch - 2ms/step
# Epoch 2980/3000
# 50/50 - 0s - loss: 106300.5469 - mse: 106300.5469 - val_loss: 17713.9766 - val_mse: 17713.9766 - 106ms/epoch - 2ms/step
# Epoch 2981/3000
# 50/50 - 0s - loss: 106300.6797 - mse: 106300.6797 - val_loss: 17713.9551 - val_mse: 17713.9551 - 99ms/epoch - 2ms/step
# Epoch 2982/3000
# 50/50 - 0s - loss: 106300.6719 - mse: 106300.6719 - val_loss: 17713.9844 - val_mse: 17713.9844 - 107ms/epoch - 2ms/step
# Epoch 2983/3000
# 50/50 - 0s - loss: 106300.8125 - mse: 106300.8125 - val_loss: 17713.9492 - val_mse: 17713.9492 - 99ms/epoch - 2ms/step
# Epoch 2984/3000
# 50/50 - 0s - loss: 106300.6016 - mse: 106300.6016 - val_loss: 17713.9844 - val_mse: 17713.9844 - 99ms/epoch - 2ms/step
# Epoch 2985/3000
# 50/50 - 0s - loss: 106300.9922 - mse: 106300.9922 - val_loss: 17713.8809 - val_mse: 17713.8809 - 99ms/epoch - 2ms/step
# Epoch 2986/3000
# 50/50 - 0s - loss: 106300.7734 - mse: 106300.7734 - val_loss: 17713.9414 - val_mse: 17713.9414 - 104ms/epoch - 2ms/step
# Epoch 2987/3000
# 50/50 - 0s - loss: 106300.6172 - mse: 106300.6172 - val_loss: 17713.9688 - val_mse: 17713.9688 - 99ms/epoch - 2ms/step
# Epoch 2988/3000
# 50/50 - 0s - loss: 106300.6719 - mse: 106300.6719 - val_loss: 17713.9785 - val_mse: 17713.9785 - 99ms/epoch - 2ms/step
# Epoch 2989/3000
# 50/50 - 0s - loss: 106300.5391 - mse: 106300.5391 - val_loss: 17713.9922 - val_mse: 17713.9922 - 104ms/epoch - 2ms/step
# Epoch 2990/3000
# 50/50 - 0s - loss: 106300.5156 - mse: 106300.5156 - val_loss: 17713.9629 - val_mse: 17713.9629 - 99ms/epoch - 2ms/step
# Epoch 2991/3000
# 50/50 - 0s - loss: 106300.6641 - mse: 106300.6641 - val_loss: 17713.9297 - val_mse: 17713.9297 - 102ms/epoch - 2ms/step
# Epoch 2992/3000
# 50/50 - 0s - loss: 106300.6484 - mse: 106300.6484 - val_loss: 17713.9219 - val_mse: 17713.9219 - 107ms/epoch - 2ms/step
# Epoch 2993/3000
# 50/50 - 0s - loss: 106300.6484 - mse: 106300.6484 - val_loss: 17713.9492 - val_mse: 17713.9492 - 102ms/epoch - 2ms/step
# Epoch 2994/3000
# 50/50 - 0s - loss: 106300.6328 - mse: 106300.6328 - val_loss: 17713.9746 - val_mse: 17713.9746 - 100ms/epoch - 2ms/step
# Epoch 2995/3000
# 50/50 - 0s - loss: 106300.9688 - mse: 106300.9688 - val_loss: 17713.8965 - val_mse: 17713.8965 - 101ms/epoch - 2ms/step
# Epoch 2996/3000
# 50/50 - 0s - loss: 106300.9688 - mse: 106300.9688 - val_loss: 17713.8184 - val_mse: 17713.8184 - 103ms/epoch - 2ms/step
# Epoch 2997/3000
# 50/50 - 0s - loss: 106300.9375 - mse: 106300.9375 - val_loss: 17713.8594 - val_mse: 17713.8594 - 103ms/epoch - 2ms/step
# Epoch 2998/3000
# 50/50 - 0s - loss: 106300.8906 - mse: 106300.8906 - val_loss: 17713.8945 - val_mse: 17713.8945 - 104ms/epoch - 2ms/step
# Epoch 2999/3000
# 50/50 - 0s - loss: 106300.6484 - mse: 106300.6484 - val_loss: 17713.9414 - val_mse: 17713.9414 - 106ms/epoch - 2ms/step
# Epoch 3000/3000
# 50/50 - 0s - loss: 106300.8281 - mse: 106300.8281 - val_loss: 17713.8809 - val_mse: 17713.8809 - 105ms/epoch - 2ms/step
# Training time 312.224451

# %%
###############################################################################
#                    Plot the history    
###############################################################################
     
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(loss)+1)
plt.figure()
plt.plot(epochs, loss,'b', label='Training loss')
plt.plot(epochs, val_loss,'r', label='Validation loss')
plt.title('Training and validation losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.savefig('loss_curves4.png')
plt.show()

# %%
###############################################################################
#                   test the model prediction performance
###############################################################################
# load the best model we get from training
network.load_weights(filepath)
 
dataYtrain_prediction=network.predict(dataXtrain)
dataYval_prediction=network.predict(dataXval)
dataYtest_prediction=network.predict(dataXtest)
 
 
x1real_test[i,0]=np.real(x1)
x1imag_test[i,0]=np.imag(x1)
x2real_test[i,0]=np.real(x2)
x2imag_test[i,0]=np.imag(x2)
 
x1real_test_prediction=np.zeros(shape=(sample_number,1))
x1imag_test_prediction=np.zeros(shape=(sample_number,1))
x2real_test_prediction=np.zeros(shape=(sample_number,1))
x2imag_test_prediction=np.zeros(shape=(sample_number,1))
 
for i in range(sample_number):
    x1real_test_prediction[i,0]=dataYtest_prediction[i,0]
    x1imag_test_prediction[i,0]=dataYtest_prediction[i,1]
    x2real_test_prediction[i,0]=dataYtest_prediction[i,2]
    x2imag_test_prediction[i,0]=dataYtest_prediction[i,3]
     
plt.plot(x1real_test,x1imag_test,'bo',markersize=7,label='True solution')    
plt.plot(x2real_test,x2imag_test,'bo',markersize=7) 
plt.plot(x1real_test_prediction,x1imag_test_prediction,'rx',markersize=7,label='Predicted solution')    
plt.plot(x2real_test_prediction,x2imag_test_prediction,'rx',markersize=7)    
plt.xlabel('Real part')
plt.ylabel('Imaginary part')
plt.xlim(-100, 10)
plt.ylim(-15, 15)
plt.legend()
plt.savefig('identified4.png')
plt.show()

print(len(x1imag_test_prediction))
# Out:
# 3125/3125 [==============================] - 2s 571us/step
# 3125/3125 [==============================] - 2s 541us/step
# 3125/3125 [==============================] - 2s 550us/step
# 100000
