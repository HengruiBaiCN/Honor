# %% [markdown]
# # Neural Network
#
# Ref: https://www.youtube.com/watch?v=Spu4gH_YfNU&ab_channel=AleksandarHaber

# %%
import tensorflow as tf
from tensorflow import keras
import cmath
import time
from keras import models
from keras import layers
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.10.1

# %%
# number of samples for training
sample_number = 100000

# %%
# create a function to generate random numbers in a range but without 0
def nonzero_random(min, max):
    x = 0
    epsilon = 1e-10
    while abs(x) < epsilon: x = np.random.uniform(min, max)
    return x

# training input data: parameters, the value of the input value is [-10, 10] and exclude 0
Adata, Bdata, Cdata = [], [], []
for i in range(sample_number):
    Adata.append([nonzero_random(-10, 10)])
    Bdata.append([nonzero_random(-10, 10)])
    Cdata.append([nonzero_random(-10, 10)])
    pass
# Transfer the list to numpy array with dimension 1
Adata = np.array(Adata)
Bdata = np.array(Bdata)
Cdata = np.array(Cdata)
# Adata = np.random.rand(sample_number, 1)
print(Adata)
# Bdata = np.random.rand(sample_number, 1)
# print(Bdata)
# Cdata = np.random.rand(sample_number, 1)
# print(Cdata)

# split the data for traning, validate and test
trainAdata, testingAdata = train_test_split(Adata, test_size=0.15, random_state=25)
trainBdata, testingBdata = train_test_split(Bdata, test_size=0.15, random_state=25)
trainCdata, testingCdata = train_test_split(Cdata, test_size=0.15, random_state=25)

trainingAdata, validatingAdata = train_test_split(trainAdata, test_size=0.05, random_state=25)
trainingBdata, validatingBdata = train_test_split(trainBdata, test_size=0.05, random_state=25)
trainingCdata, validatingCdata = train_test_split(trainCdata, test_size=0.05, random_state=25)

# concatenate the input data a, b, c as a vector input
dataXtrain = np.concatenate((trainingAdata, trainingBdata, trainingCdata), axis=1)
# print(dataXtrain)
dataXval = np.concatenate((validatingAdata, validatingBdata, validatingCdata), axis=1)
dataXtest = np.concatenate((testingAdata, testingBdata, testingCdata), axis=1)
print(dataXtrain)
print(len(dataXtrain))
# Out:
# [[ 7.54166816]
#  [ 3.16402892]
#  [-9.50013912]
#  ...
#  [-4.84468409]
#  [ 0.2164758 ]
#  [-9.82072839]]
# [[ 7.77050097  2.97565377  1.43286641]
#  [-3.72157527  9.03463163  1.14757239]
#  [-3.77373039 -1.37397983  6.58929213]
#  ...
#  [-0.73150596 -5.68532755  7.89826645]
#  [-4.36641273  0.08555944  3.16204484]
#  [-0.02874479 -2.06855961 -4.46437016]]
# 80750

# %%
# training output data - a complex number: the roots of the given function
x1real = np.zeros(shape=(sample_number, 1))
x1imag = np.zeros(shape=(sample_number, 1))
x2real = np.zeros(shape=(sample_number, 1))
x2imag = np.zeros(shape=(sample_number, 1))

for i in range(sample_number):
    # the real solution of each input
    x1 = (-Bdata[i,0] + cmath.sqrt(Bdata[i,0]**2 - 4 * Adata[i,0]*Cdata[i,0])) / (2*Adata[i,0])
    x2 = (-Bdata[i,0] - cmath.sqrt(Bdata[i,0]**2 - 4 * Adata[i,0]*Cdata[i,0])) / (2*Adata[i,0])
    # transfer the real solution to our output traning data
    x1real[i,0] = np.real(x1)
    x1imag[i,0] = np.imag(x1)
    x2real[i,0] = np.real(x2)
    x2imag[i,0] = np.imag(x2)
    pass

# split the data for traning, validate and test
x1real_85, x1real_test = train_test_split(x1real, test_size=0.15, random_state=25)
x1imag_85, x1imag_test = train_test_split(x1imag, test_size=0.15, random_state=25)
x2real_85, x2real_test = train_test_split(x2real, test_size=0.15, random_state=25)
x2imag_85, x2imag_test = train_test_split(x2imag, test_size=0.15, random_state=25)

x1real_train, x1real_val = train_test_split(x1real_85, test_size=0.05, random_state=25)
x1imag_train, x1imag_val = train_test_split(x1imag_85, test_size=0.05, random_state=25)
x2real_train, x2real_val = train_test_split(x2real_85, test_size=0.05, random_state=25)
x2imag_train, x2imag_val = train_test_split(x2imag_85, test_size=0.05, random_state=25)

# create a function to concatenate the output values in an order
def ordered_concate(x1, x2, x3, x4):
    result = []
    length = len(x1)
    for i in range(length):
        # change the sort function
        # reduce the dimension of the output - first 2 values are the real part, third value is the imagenary part
        # only sort the first 2 values
        pairs = [x1[i,0], x2[i,0], x3[i,0], x4[i,0]]
        # print(pairs)
        pairs.sort()
        # print(pairs)
        result.append(pairs)
        pass
    return result

# concatenate the output data as a vector output
dataYtrain = np.array(ordered_concate(x1real_train, x1imag_train, x2real_train, x2imag_train))
dataYval = np.array(ordered_concate(x1real_val, x1imag_val, x2real_val, x2imag_val))
# print(x1imag_val)
# print(x2imag_val)
# print(dataYval)
dataYtest = np.array(ordered_concate(x1real_test, x1imag_test, x2real_test, x2imag_test))
print(dataYtrain)
print(len(dataYtrain))
# Out:
# [[ -0.3843657   -0.19147117  -0.19147117   0.3843657 ]
#  [ -0.12098937  -0.          -0.           2.54862578]
#  [ -1.51592521  -0.          -0.           1.15183459]
#  ...
#  [ -8.97511001  -0.          -0.           1.20302356]
#  [ -0.84124339  -0.          -0.           0.86083829]
#  [-69.73580857  -2.22712807  -0.          -0.        ]]
# 80750

# %%
# # validation data
# aval = np.random.rand(sample_number, 1)
# bval = np.random.rand(sample_number, 1)
# cval = np.random.rand(sample_number, 1)
 
# dataXval = np.concatenate((aval, bval, cval), axis = 1)

# x1real_val = np.zeros(shape = (sample_number, 1))
# x1imag_val = np.zeros(shape = (sample_number, 1))
# x2real_val = np.zeros(shape = (sample_number, 1))
# x2imag_val = np.zeros(shape = (sample_number, 1))
 
 
# for i in range(sample_number):
#     x1 = (-bval[i,0] + cmath.sqrt(bval[i,0]**2 - 4 * aval[i,0] * cval[i,0])) / (2*aval[i,0])
#     x2 = (-bval[i,0] - cmath.sqrt(bval[i,0]**2 - 4 * aval[i,0] * cval[i,0])) / (2*aval[i,0])
#     x1real_val[i,0] = np.real(x1)
#     x1imag_val[i,0] = np.imag(x1)
#     x2real_val[i,0] = np.real(x2)
#     x2imag_val[i,0] = np.imag(x2)
#     pass

# dataYval = np.concatenate((x1real_val,x1imag_val,x2real_val,x2imag_val), axis = 1)

# %%
# # test data
# atest = np.random.rand(sample_number, 1)
# btest = np.random.rand(sample_number, 1)
# ctest = np.random.rand(sample_number, 1)
 
# dataXtest = np.concatenate((atest, btest, ctest), axis = 1)
 
# x1real_test = np.zeros(shape = (sample_number, 1))
# x1imag_test = np.zeros(shape = (sample_number,1))
# x2real_test = np.zeros(shape = (sample_number,1))
# x2imag_test = np.zeros(shape = (sample_number,1))
 
 
# for i in range(sample_number):
#     x1 = (-btest[i, 0] + cmath.sqrt(btest[i, 0]**2 - 4 * atest[i, 0] * ctest[i, 0])) / (2*atest[i, 0])
#     x2 = (-btest[i, 0] - cmath.sqrt(btest[i, 0]**2 - 4 * atest[i, 0] * ctest[i, 0])) / (2*atest[i, 0])
    
#     x1real_test[i, 0] = np.real(x1)
#     x1imag_test[i, 0] = np.imag(x1)
#     x2real_test[i, 0] = np.real(x2)
#     x2imag_test[i, 0] = np.imag(x2)
 
# dataYtest = np.concatenate((x1real_test, x1imag_test, x2real_test, x2imag_test), axis = 1)

# %%
###############################################################################
#                         neural network
###############################################################################
with tf.device(device_name='/GPU:0'):
    network = models.Sequential()
    
    # define layers of the neural network
    network.add(layers.Dense(10, activation='tanh', kernel_initializer='random_normal', use_bias=False, input_dim=3))
    network.add(layers.Dense(20, activation='tanh', kernel_initializer='random_normal', use_bias=False))
    network.add(layers.Dense(20, activation='tanh', kernel_initializer='random_normal', use_bias=False))
    network.add(layers.Dense(10, activation='relu', kernel_initializer='random_uniform', use_bias=False))
    network.add(layers.Dense(4, activation = 'linear', kernel_initializer='random_normal', use_bias=False))
    # number of training neurons = 3*10+10*20+20*20+20*10+10*4+4*4 = 886
    
    # define the optimizer, with different loss function
    network.compile(optimizer=RMSprop(), loss='mean_squared_error', metrics=['mse'])
    #network.compile(optimizer=RMSprop(), loss='mean_absolute_percentage_error', metrics=['mse'])  # 'mean_absolute_percentage_error' is another option
    #network.compile(optimizer=Adam(), loss='mean_squared_error')
     
     
    # only save the model with the best validation loss value
    filepath="C:/Users/hengr/Programs/Projects/Honor-Project/Honor/best_model_2.hdf5"
    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='min')
    callbacks_list = [checkpoint]
    
    # neural network traning
    start_time = time.time()
    history = network.fit(dataXtrain, dataYtrain, epochs=100000, batch_size=20000, callbacks=callbacks_list, validation_data = (dataXval, dataYval), verbose = 2)
    end_time = time.time()
    print('Training time %f'%(end_time-start_time))
# Out:
# Epoch 1/100000
# 5/5 - 1s - loss: 4468.7969 - mse: 4468.7969 - val_loss: 175.4872 - val_mse: 175.4872 - 1s/epoch - 223ms/step
# Epoch 2/100000
# 5/5 - 0s - loss: 4468.7944 - mse: 4468.7944 - val_loss: 175.4851 - val_mse: 175.4851 - 35ms/epoch - 7ms/step
# Epoch 3/100000
# 5/5 - 0s - loss: 4468.7891 - mse: 4468.7891 - val_loss: 175.4767 - val_mse: 175.4767 - 33ms/epoch - 7ms/step
# Epoch 4/100000
# 5/5 - 0s - loss: 4468.7720 - mse: 4468.7720 - val_loss: 175.4534 - val_mse: 175.4534 - 32ms/epoch - 6ms/step
# Epoch 5/100000
# 5/5 - 0s - loss: 4468.7349 - mse: 4468.7339 - val_loss: 175.4178 - val_mse: 175.4178 - 32ms/epoch - 6ms/step
# Epoch 6/100000
# 5/5 - 0s - loss: 4468.6733 - mse: 4468.6733 - val_loss: 175.3604 - val_mse: 175.3604 - 34ms/epoch - 7ms/step
# Epoch 7/100000
# 5/5 - 0s - loss: 4468.5786 - mse: 4468.5786 - val_loss: 175.2586 - val_mse: 175.2586 - 32ms/epoch - 6ms/step
# Epoch 8/100000
# 5/5 - 0s - loss: 4468.4487 - mse: 4468.4487 - val_loss: 175.1834 - val_mse: 175.1834 - 33ms/epoch - 7ms/step
# Epoch 9/100000
# 5/5 - 0s - loss: 4468.3457 - mse: 4468.3457 - val_loss: 175.0941 - val_mse: 175.0941 - 34ms/epoch - 7ms/step
# Epoch 10/100000
# 5/5 - 0s - loss: 4468.2197 - mse: 4468.2197 - val_loss: 174.9908 - val_mse: 174.9908 - 35ms/epoch - 7ms/step
# Epoch 11/100000
# 5/5 - 0s - loss: 4468.0728 - mse: 4468.0728 - val_loss: 174.8478 - val_mse: 174.8478 - 33ms/epoch - 7ms/step
# Epoch 12/100000
# 5/5 - 0s - loss: 4467.8794 - mse: 4467.8794 - val_loss: 174.7117 - val_mse: 174.7117 - 31ms/epoch - 6ms/step
# Epoch 13/100000
# 5/5 - 0s - loss: 4467.6860 - mse: 4467.6860 - val_loss: 174.5600 - val_mse: 174.5600 - 34ms/epoch - 7ms/step
# Epoch 14/100000
# 5/5 - 0s - loss: 4467.4678 - mse: 4467.4678 - val_loss: 174.3734 - val_mse: 174.3734 - 36ms/epoch - 7ms/step
# Epoch 15/100000
# 5/5 - 0s - loss: 4467.2056 - mse: 4467.2056 - val_loss: 174.2010 - val_mse: 174.2010 - 34ms/epoch - 7ms/step
# Epoch 16/100000
# 5/5 - 0s - loss: 4466.9609 - mse: 4466.9609 - val_loss: 174.0266 - val_mse: 174.0266 - 35ms/epoch - 7ms/step
# Epoch 17/100000
# 5/5 - 0s - loss: 4466.7056 - mse: 4466.7056 - val_loss: 173.8688 - val_mse: 173.8688 - 33ms/epoch - 7ms/step
# Epoch 18/100000
# 5/5 - 0s - loss: 4466.4707 - mse: 4466.4707 - val_loss: 173.7060 - val_mse: 173.7060 - 33ms/epoch - 7ms/step
# Epoch 19/100000
# 5/5 - 0s - loss: 4466.2271 - mse: 4466.2271 - val_loss: 173.5621 - val_mse: 173.5621 - 33ms/epoch - 7ms/step
# Epoch 20/100000
# 5/5 - 0s - loss: 4466.0044 - mse: 4466.0044 - val_loss: 173.4109 - val_mse: 173.4109 - 33ms/epoch - 7ms/step
# Epoch 21/100000
# 5/5 - 0s - loss: 4465.7637 - mse: 4465.7637 - val_loss: 173.2681 - val_mse: 173.2681 - 33ms/epoch - 7ms/step
# Epoch 22/100000
# 5/5 - 0s - loss: 4465.5366 - mse: 4465.5366 - val_loss: 173.1559 - val_mse: 173.1559 - 34ms/epoch - 7ms/step
# Epoch 23/100000
# 5/5 - 0s - loss: 4465.3511 - mse: 4465.3511 - val_loss: 173.0618 - val_mse: 173.0618 - 34ms/epoch - 7ms/step
# Epoch 24/100000
# 5/5 - 0s - loss: 4465.1753 - mse: 4465.1753 - val_loss: 172.9626 - val_mse: 172.9626 - 34ms/epoch - 7ms/step
# Epoch 25/100000
# 5/5 - 0s - loss: 4464.9883 - mse: 4464.9883 - val_loss: 172.8844 - val_mse: 172.8844 - 33ms/epoch - 7ms/step
# Epoch 26/100000
# 5/5 - 0s - loss: 4464.8096 - mse: 4464.8096 - val_loss: 172.8208 - val_mse: 172.8208 - 33ms/epoch - 7ms/step
# Epoch 27/100000
# 5/5 - 0s - loss: 4464.6763 - mse: 4464.6763 - val_loss: 172.7535 - val_mse: 172.7535 - 34ms/epoch - 7ms/step
# Epoch 28/100000
# 5/5 - 0s - loss: 4464.5264 - mse: 4464.5264 - val_loss: 172.7202 - val_mse: 172.7202 - 36ms/epoch - 7ms/step
# Epoch 29/100000
# 5/5 - 0s - loss: 4464.4502 - mse: 4464.4502 - val_loss: 172.6991 - val_mse: 172.6991 - 34ms/epoch - 7ms/step
# Epoch 30/100000
# 5/5 - 0s - loss: 4464.3667 - mse: 4464.3667 - val_loss: 172.6640 - val_mse: 172.6640 - 34ms/epoch - 7ms/step
# Epoch 31/100000
# 5/5 - 0s - loss: 4464.2871 - mse: 4464.2871 - val_loss: 172.6235 - val_mse: 172.6235 - 34ms/epoch - 7ms/step
# Epoch 32/100000
# 5/5 - 0s - loss: 4464.1997 - mse: 4464.1997 - val_loss: 172.5883 - val_mse: 172.5883 - 36ms/epoch - 7ms/step
# Epoch 33/100000
# 5/5 - 0s - loss: 4464.0977 - mse: 4464.0977 - val_loss: 172.5477 - val_mse: 172.5477 - 36ms/epoch - 7ms/step
# Epoch 34/100000
# 5/5 - 0s - loss: 4464.0117 - mse: 4464.0117 - val_loss: 172.5093 - val_mse: 172.5093 - 34ms/epoch - 7ms/step
# Epoch 35/100000
# 5/5 - 0s - loss: 4463.9272 - mse: 4463.9272 - val_loss: 172.5053 - val_mse: 172.5053 - 32ms/epoch - 6ms/step
# Epoch 36/100000
# 5/5 - 0s - loss: 4463.8066 - mse: 4463.8066 - val_loss: 172.4737 - val_mse: 172.4737 - 38ms/epoch - 8ms/step
# Epoch 37/100000
# 5/5 - 0s - loss: 4463.7183 - mse: 4463.7183 - val_loss: 172.4305 - val_mse: 172.4305 - 34ms/epoch - 7ms/step
# Epoch 38/100000
# 5/5 - 0s - loss: 4463.6201 - mse: 4463.6201 - val_loss: 172.3864 - val_mse: 172.3864 - 34ms/epoch - 7ms/step
# Epoch 39/100000
# 5/5 - 0s - loss: 4463.5029 - mse: 4463.5029 - val_loss: 172.3855 - val_mse: 172.3855 - 35ms/epoch - 7ms/step
# Epoch 40/100000
# 5/5 - 0s - loss: 4463.4277 - mse: 4463.4277 - val_loss: 172.3425 - val_mse: 172.3425 - 34ms/epoch - 7ms/step
# Epoch 41/100000
# 5/5 - 0s - loss: 4463.3555 - mse: 4463.3555 - val_loss: 172.3075 - val_mse: 172.3075 - 36ms/epoch - 7ms/step
# Epoch 42/100000
# 5/5 - 0s - loss: 4463.2783 - mse: 4463.2783 - val_loss: 172.2752 - val_mse: 172.2752 - 34ms/epoch - 7ms/step
# Epoch 43/100000
# 5/5 - 0s - loss: 4463.1738 - mse: 4463.1738 - val_loss: 172.2559 - val_mse: 172.2559 - 35ms/epoch - 7ms/step
# Epoch 44/100000
# 5/5 - 0s - loss: 4463.0874 - mse: 4463.0874 - val_loss: 172.2271 - val_mse: 172.2271 - 36ms/epoch - 7ms/step
# Epoch 45/100000
# 5/5 - 0s - loss: 4462.9893 - mse: 4462.9893 - val_loss: 172.1731 - val_mse: 172.1731 - 35ms/epoch - 7ms/step
# Epoch 46/100000
# 5/5 - 0s - loss: 4462.8892 - mse: 4462.8892 - val_loss: 172.1699 - val_mse: 172.1699 - 34ms/epoch - 7ms/step
# Epoch 47/100000
# 5/5 - 0s - loss: 4462.7905 - mse: 4462.7905 - val_loss: 172.1175 - val_mse: 172.1175 - 35ms/epoch - 7ms/step
# Epoch 48/100000
# 5/5 - 0s - loss: 4462.6880 - mse: 4462.6880 - val_loss: 172.0793 - val_mse: 172.0793 - 34ms/epoch - 7ms/step
# Epoch 49/100000
# 5/5 - 0s - loss: 4462.5757 - mse: 4462.5757 - val_loss: 172.0291 - val_mse: 172.0291 - 34ms/epoch - 7ms/step
# Epoch 50/100000
# 5/5 - 0s - loss: 4462.4810 - mse: 4462.4810 - val_loss: 171.9557 - val_mse: 171.9557 - 34ms/epoch - 7ms/step
# Epoch 51/100000
# 5/5 - 0s - loss: 4462.3633 - mse: 4462.3633 - val_loss: 171.8831 - val_mse: 171.8831 - 33ms/epoch - 7ms/step
# Epoch 52/100000
# 5/5 - 0s - loss: 4462.2314 - mse: 4462.2314 - val_loss: 171.8438 - val_mse: 171.8438 - 33ms/epoch - 7ms/step
# Epoch 53/100000
# 5/5 - 0s - loss: 4462.0723 - mse: 4462.0723 - val_loss: 171.7592 - val_mse: 171.7592 - 33ms/epoch - 7ms/step
# Epoch 54/100000
# 5/5 - 0s - loss: 4461.9268 - mse: 4461.9268 - val_loss: 171.6698 - val_mse: 171.6698 - 33ms/epoch - 7ms/step
# Epoch 55/100000
# 5/5 - 0s - loss: 4461.7803 - mse: 4461.7803 - val_loss: 171.5908 - val_mse: 171.5908 - 34ms/epoch - 7ms/step
# Epoch 56/100000
# 5/5 - 0s - loss: 4461.6099 - mse: 4461.6099 - val_loss: 171.4989 - val_mse: 171.4989 - 30ms/epoch - 6ms/step
# Epoch 57/100000
# 5/5 - 0s - loss: 4461.4033 - mse: 4461.4033 - val_loss: 171.3796 - val_mse: 171.3796 - 33ms/epoch - 7ms/step
# Epoch 58/100000
# 5/5 - 0s - loss: 4461.2388 - mse: 4461.2388 - val_loss: 171.2714 - val_mse: 171.2714 - 33ms/epoch - 7ms/step
# Epoch 59/100000
# 5/5 - 0s - loss: 4461.0166 - mse: 4461.0166 - val_loss: 171.1316 - val_mse: 171.1316 - 32ms/epoch - 6ms/step
# Epoch 60/100000
# 5/5 - 0s - loss: 4460.7832 - mse: 4460.7832 - val_loss: 171.0240 - val_mse: 171.0240 - 33ms/epoch - 7ms/step
# Epoch 61/100000
# 5/5 - 0s - loss: 4460.5210 - mse: 4460.5210 - val_loss: 170.8951 - val_mse: 170.8951 - 33ms/epoch - 7ms/step
# Epoch 62/100000
# 5/5 - 0s - loss: 4460.3057 - mse: 4460.3057 - val_loss: 170.7486 - val_mse: 170.7486 - 31ms/epoch - 6ms/step
# Epoch 63/100000
# 5/5 - 0s - loss: 4460.1284 - mse: 4460.1284 - val_loss: 170.6649 - val_mse: 170.6649 - 32ms/epoch - 6ms/step
# Epoch 64/100000
# 5/5 - 0s - loss: 4459.8774 - mse: 4459.8774 - val_loss: 170.5707 - val_mse: 170.5707 - 33ms/epoch - 7ms/step
# Epoch 65/100000
# 5/5 - 0s - loss: 4459.6230 - mse: 4459.6230 - val_loss: 170.4868 - val_mse: 170.4868 - 32ms/epoch - 6ms/step
# Epoch 66/100000
# 5/5 - 0s - loss: 4459.3818 - mse: 4459.3818 - val_loss: 170.3369 - val_mse: 170.3369 - 33ms/epoch - 7ms/step
# Epoch 67/100000
# 5/5 - 0s - loss: 4459.1221 - mse: 4459.1221 - val_loss: 170.2117 - val_mse: 170.2117 - 32ms/epoch - 6ms/step
# Epoch 68/100000
# 5/5 - 0s - loss: 4458.8667 - mse: 4458.8667 - val_loss: 170.0760 - val_mse: 170.0760 - 33ms/epoch - 7ms/step
# Epoch 69/100000
# 5/5 - 0s - loss: 4458.5977 - mse: 4458.5981 - val_loss: 169.8994 - val_mse: 169.8994 - 34ms/epoch - 7ms/step
# Epoch 70/100000
# 5/5 - 0s - loss: 4458.2974 - mse: 4458.2974 - val_loss: 169.7151 - val_mse: 169.7151 - 32ms/epoch - 6ms/step
# Epoch 71/100000
# 5/5 - 0s - loss: 4457.9927 - mse: 4457.9927 - val_loss: 169.5733 - val_mse: 169.5733 - 32ms/epoch - 6ms/step
# Epoch 72/100000
# 5/5 - 0s - loss: 4457.7378 - mse: 4457.7378 - val_loss: 169.4165 - val_mse: 169.4165 - 32ms/epoch - 6ms/step
# Epoch 73/100000
# 5/5 - 0s - loss: 4457.4595 - mse: 4457.4595 - val_loss: 169.2855 - val_mse: 169.2855 - 35ms/epoch - 7ms/step
# Epoch 74/100000
# 5/5 - 0s - loss: 4457.1602 - mse: 4457.1602 - val_loss: 169.1399 - val_mse: 169.1399 - 33ms/epoch - 7ms/step
# Epoch 75/100000
# 5/5 - 0s - loss: 4456.8521 - mse: 4456.8521 - val_loss: 168.9956 - val_mse: 168.9956 - 31ms/epoch - 6ms/step
# Epoch 76/100000
# 5/5 - 0s - loss: 4456.5298 - mse: 4456.5298 - val_loss: 168.9635 - val_mse: 168.9635 - 31ms/epoch - 6ms/step
# Epoch 77/100000
# 5/5 - 0s - loss: 4456.2563 - mse: 4456.2563 - val_loss: 168.7657 - val_mse: 168.7657 - 32ms/epoch - 6ms/step
# Epoch 78/100000
# 5/5 - 0s - loss: 4455.9316 - mse: 4455.9316 - val_loss: 168.7215 - val_mse: 168.7215 - 33ms/epoch - 7ms/step
# Epoch 79/100000
# 5/5 - 0s - loss: 4455.6240 - mse: 4455.6240 - val_loss: 168.5920 - val_mse: 168.5920 - 33ms/epoch - 7ms/step
# Epoch 80/100000
# 5/5 - 0s - loss: 4455.3389 - mse: 4455.3389 - val_loss: 168.4688 - val_mse: 168.4688 - 32ms/epoch - 6ms/step
# Epoch 81/100000
# 5/5 - 0s - loss: 4455.0728 - mse: 4455.0728 - val_loss: 168.3245 - val_mse: 168.3245 - 33ms/epoch - 7ms/step
# Epoch 82/100000
# 5/5 - 0s - loss: 4454.7583 - mse: 4454.7583 - val_loss: 168.1306 - val_mse: 168.1306 - 33ms/epoch - 7ms/step
# Epoch 83/100000
# 5/5 - 0s - loss: 4454.4126 - mse: 4454.4126 - val_loss: 167.9503 - val_mse: 167.9503 - 33ms/epoch - 7ms/step
# Epoch 84/100000
# 5/5 - 0s - loss: 4454.0771 - mse: 4454.0771 - val_loss: 167.8108 - val_mse: 167.8108 - 32ms/epoch - 6ms/step
# Epoch 85/100000
# 5/5 - 0s - loss: 4453.7437 - mse: 4453.7437 - val_loss: 167.6288 - val_mse: 167.6288 - 33ms/epoch - 7ms/step
# Epoch 86/100000
# 5/5 - 0s - loss: 4453.3813 - mse: 4453.3813 - val_loss: 167.5082 - val_mse: 167.5082 - 33ms/epoch - 7ms/step
# Epoch 87/100000
# 5/5 - 0s - loss: 4453.0151 - mse: 4453.0151 - val_loss: 167.2942 - val_mse: 167.2942 - 32ms/epoch - 6ms/step
# Epoch 88/100000
# 5/5 - 0s - loss: 4452.6099 - mse: 4452.6099 - val_loss: 167.1455 - val_mse: 167.1455 - 33ms/epoch - 7ms/step
# Epoch 89/100000
# 5/5 - 0s - loss: 4452.2769 - mse: 4452.2769 - val_loss: 167.1100 - val_mse: 167.1100 - 33ms/epoch - 7ms/step
# Epoch 90/100000
# 5/5 - 0s - loss: 4452.0479 - mse: 4452.0479 - val_loss: 166.9284 - val_mse: 166.9284 - 34ms/epoch - 7ms/step
# Epoch 91/100000
# 5/5 - 0s - loss: 4451.7529 - mse: 4451.7529 - val_loss: 166.7292 - val_mse: 166.7292 - 32ms/epoch - 6ms/step
# Epoch 92/100000
# 5/5 - 0s - loss: 4451.4971 - mse: 4451.4971 - val_loss: 166.5510 - val_mse: 166.5510 - 32ms/epoch - 6ms/step
# Epoch 93/100000
# 5/5 - 0s - loss: 4451.2329 - mse: 4451.2329 - val_loss: 166.3576 - val_mse: 166.3576 - 33ms/epoch - 7ms/step
# Epoch 94/100000
# 5/5 - 0s - loss: 4450.8560 - mse: 4450.8560 - val_loss: 166.1718 - val_mse: 166.1718 - 32ms/epoch - 6ms/step
# Epoch 95/100000
# 5/5 - 0s - loss: 4450.4756 - mse: 4450.4756 - val_loss: 165.9351 - val_mse: 165.9351 - 33ms/epoch - 7ms/step
# Epoch 96/100000
# 5/5 - 0s - loss: 4450.0703 - mse: 4450.0703 - val_loss: 165.7665 - val_mse: 165.7665 - 36ms/epoch - 7ms/step
# Epoch 97/100000
# 5/5 - 0s - loss: 4449.7324 - mse: 4449.7324 - val_loss: 165.6745 - val_mse: 165.6745 - 35ms/epoch - 7ms/step
# Epoch 98/100000
# 5/5 - 0s - loss: 4449.3594 - mse: 4449.3589 - val_loss: 165.4781 - val_mse: 165.4781 - 33ms/epoch - 7ms/step
# Epoch 99/100000
# 5/5 - 0s - loss: 4448.9727 - mse: 4448.9727 - val_loss: 165.2510 - val_mse: 165.2510 - 35ms/epoch - 7ms/step
# Epoch 100/100000
# 5/5 - 0s - loss: 4448.5942 - mse: 4448.5942 - val_loss: 165.0868 - val_mse: 165.0868 - 31ms/epoch - 6ms/step
# Epoch 101/100000
# 5/5 - 0s - loss: 4448.2471 - mse: 4448.2466 - val_loss: 164.9023 - val_mse: 164.9023 - 33ms/epoch - 7ms/step
# Epoch 102/100000
# 5/5 - 0s - loss: 4447.8169 - mse: 4447.8169 - val_loss: 164.6990 - val_mse: 164.6990 - 33ms/epoch - 7ms/step
# Epoch 103/100000
# 5/5 - 0s - loss: 4447.3301 - mse: 4447.3301 - val_loss: 164.5273 - val_mse: 164.5273 - 32ms/epoch - 6ms/step
# Epoch 104/100000
# 5/5 - 0s - loss: 4446.8779 - mse: 4446.8779 - val_loss: 164.2748 - val_mse: 164.2748 - 31ms/epoch - 6ms/step
# Epoch 105/100000
# 5/5 - 0s - loss: 4446.4282 - mse: 4446.4282 - val_loss: 164.1386 - val_mse: 164.1386 - 33ms/epoch - 7ms/step
# Epoch 106/100000
# 5/5 - 0s - loss: 4445.8540 - mse: 4445.8540 - val_loss: 164.0311 - val_mse: 164.0311 - 33ms/epoch - 7ms/step
# Epoch 107/100000
# 5/5 - 0s - loss: 4445.4458 - mse: 4445.4458 - val_loss: 163.8697 - val_mse: 163.8697 - 44ms/epoch - 9ms/step
# Epoch 108/100000
# 5/5 - 0s - loss: 4445.0459 - mse: 4445.0459 - val_loss: 163.7038 - val_mse: 163.7038 - 34ms/epoch - 7ms/step
# Epoch 109/100000
# 5/5 - 0s - loss: 4444.6855 - mse: 4444.6855 - val_loss: 163.5290 - val_mse: 163.5290 - 31ms/epoch - 6ms/step
# Epoch 110/100000
# 5/5 - 0s - loss: 4444.1943 - mse: 4444.1943 - val_loss: 163.4595 - val_mse: 163.4595 - 32ms/epoch - 6ms/step
# Epoch 111/100000
# 5/5 - 0s - loss: 4443.7769 - mse: 4443.7769 - val_loss: 163.3761 - val_mse: 163.3761 - 32ms/epoch - 6ms/step
# Epoch 112/100000
# 5/5 - 0s - loss: 4443.3765 - mse: 4443.3765 - val_loss: 163.2621 - val_mse: 163.2621 - 35ms/epoch - 7ms/step
# Epoch 113/100000
# 5/5 - 0s - loss: 4442.8159 - mse: 4442.8159 - val_loss: 163.0092 - val_mse: 163.0092 - 31ms/epoch - 6ms/step
# Epoch 114/100000
# 5/5 - 0s - loss: 4442.5049 - mse: 4442.5049 - val_loss: 162.9361 - val_mse: 162.9361 - 33ms/epoch - 7ms/step
# Epoch 115/100000
# 5/5 - 0s - loss: 4442.2100 - mse: 4442.2100 - val_loss: 162.7379 - val_mse: 162.7379 - 32ms/epoch - 6ms/step
# Epoch 116/100000
# 5/5 - 0s - loss: 4441.8599 - mse: 4441.8599 - val_loss: 162.6805 - val_mse: 162.6805 - 34ms/epoch - 7ms/step
# Epoch 117/100000
# 5/5 - 0s - loss: 4441.5869 - mse: 4441.5869 - val_loss: 162.7440 - val_mse: 162.7440 - 23ms/epoch - 5ms/step
# Epoch 118/100000
# 5/5 - 0s - loss: 4440.9990 - mse: 4440.9990 - val_loss: 162.6014 - val_mse: 162.6014 - 33ms/epoch - 7ms/step
# Epoch 119/100000
# 5/5 - 0s - loss: 4440.6733 - mse: 4440.6733 - val_loss: 162.4706 - val_mse: 162.4706 - 35ms/epoch - 7ms/step
# Epoch 120/100000
# 5/5 - 0s - loss: 4440.4038 - mse: 4440.4038 - val_loss: 162.2953 - val_mse: 162.2953 - 33ms/epoch - 7ms/step
# Epoch 121/100000
# 5/5 - 0s - loss: 4439.9575 - mse: 4439.9575 - val_loss: 161.9503 - val_mse: 161.9503 - 35ms/epoch - 7ms/step
# Epoch 122/100000
# 5/5 - 0s - loss: 4439.6147 - mse: 4439.6147 - val_loss: 161.8388 - val_mse: 161.8388 - 33ms/epoch - 7ms/step
# Epoch 123/100000
# 5/5 - 0s - loss: 4439.2661 - mse: 4439.2661 - val_loss: 161.7461 - val_mse: 161.7461 - 32ms/epoch - 6ms/step
# Epoch 124/100000
# 5/5 - 0s - loss: 4438.9912 - mse: 4438.9912 - val_loss: 161.6651 - val_mse: 161.6651 - 33ms/epoch - 7ms/step
# Epoch 125/100000
# 5/5 - 0s - loss: 4438.7295 - mse: 4438.7295 - val_loss: 161.5506 - val_mse: 161.5506 - 35ms/epoch - 7ms/step
# Epoch 126/100000
# 5/5 - 0s - loss: 4438.3755 - mse: 4438.3755 - val_loss: 161.5280 - val_mse: 161.5280 - 34ms/epoch - 7ms/step
# Epoch 127/100000
# 5/5 - 0s - loss: 4437.8989 - mse: 4437.8989 - val_loss: 161.4366 - val_mse: 161.4366 - 35ms/epoch - 7ms/step
# Epoch 128/100000
# 5/5 - 0s - loss: 4437.4160 - mse: 4437.4160 - val_loss: 161.2181 - val_mse: 161.2181 - 36ms/epoch - 7ms/step
# Epoch 129/100000
# 5/5 - 0s - loss: 4437.1152 - mse: 4437.1152 - val_loss: 161.0677 - val_mse: 161.0677 - 37ms/epoch - 7ms/step
# Epoch 130/100000
# 5/5 - 0s - loss: 4436.5718 - mse: 4436.5718 - val_loss: 160.8860 - val_mse: 160.8860 - 38ms/epoch - 8ms/step
# Epoch 131/100000
# 5/5 - 0s - loss: 4436.1284 - mse: 4436.1284 - val_loss: 160.8628 - val_mse: 160.8628 - 40ms/epoch - 8ms/step
# Epoch 132/100000
# 5/5 - 0s - loss: 4435.6152 - mse: 4435.6152 - val_loss: 160.4248 - val_mse: 160.4248 - 37ms/epoch - 7ms/step
# Epoch 133/100000
# 5/5 - 0s - loss: 4435.0996 - mse: 4435.0996 - val_loss: 160.1877 - val_mse: 160.1877 - 40ms/epoch - 8ms/step
# Epoch 134/100000
# 5/5 - 0s - loss: 4434.4980 - mse: 4434.4980 - val_loss: 160.3284 - val_mse: 160.3284 - 25ms/epoch - 5ms/step
# Epoch 135/100000
# 5/5 - 0s - loss: 4434.1011 - mse: 4434.1011 - val_loss: 160.1356 - val_mse: 160.1356 - 38ms/epoch - 8ms/step
# Epoch 136/100000
# 5/5 - 0s - loss: 4433.5259 - mse: 4433.5259 - val_loss: 159.9885 - val_mse: 159.9885 - 35ms/epoch - 7ms/step
# Epoch 137/100000
# 5/5 - 0s - loss: 4433.0410 - mse: 4433.0410 - val_loss: 159.7555 - val_mse: 159.7555 - 35ms/epoch - 7ms/step
# Epoch 138/100000
# 5/5 - 0s - loss: 4432.4033 - mse: 4432.4033 - val_loss: 159.5498 - val_mse: 159.5498 - 36ms/epoch - 7ms/step
# Epoch 139/100000
# 5/5 - 0s - loss: 4431.8901 - mse: 4431.8901 - val_loss: 159.5259 - val_mse: 159.5259 - 34ms/epoch - 7ms/step
# Epoch 140/100000
# 5/5 - 0s - loss: 4431.3628 - mse: 4431.3628 - val_loss: 159.2426 - val_mse: 159.2426 - 34ms/epoch - 7ms/step
# Epoch 141/100000
# 5/5 - 0s - loss: 4430.7998 - mse: 4430.7998 - val_loss: 158.7476 - val_mse: 158.7476 - 34ms/epoch - 7ms/step
# Epoch 142/100000
# 5/5 - 0s - loss: 4430.3394 - mse: 4430.3394 - val_loss: 158.6042 - val_mse: 158.6042 - 40ms/epoch - 8ms/step
# Epoch 143/100000
# 5/5 - 0s - loss: 4429.9858 - mse: 4429.9858 - val_loss: 158.4680 - val_mse: 158.4680 - 36ms/epoch - 7ms/step
# Epoch 144/100000
# 5/5 - 0s - loss: 4429.6187 - mse: 4429.6187 - val_loss: 158.9011 - val_mse: 158.9011 - 26ms/epoch - 5ms/step
# Epoch 145/100000
# 5/5 - 0s - loss: 4429.1294 - mse: 4429.1294 - val_loss: 158.8150 - val_mse: 158.8150 - 27ms/epoch - 5ms/step
# Epoch 146/100000
# 5/5 - 0s - loss: 4428.7983 - mse: 4428.7983 - val_loss: 158.7122 - val_mse: 158.7122 - 27ms/epoch - 5ms/step
# Epoch 147/100000
# 5/5 - 0s - loss: 4428.3740 - mse: 4428.3740 - val_loss: 158.5862 - val_mse: 158.5862 - 33ms/epoch - 7ms/step
# Epoch 148/100000
# 5/5 - 0s - loss: 4427.9731 - mse: 4427.9731 - val_loss: 158.4857 - val_mse: 158.4857 - 28ms/epoch - 6ms/step
# Epoch 149/100000
# 5/5 - 0s - loss: 4427.5781 - mse: 4427.5781 - val_loss: 158.3862 - val_mse: 158.3862 - 37ms/epoch - 7ms/step
# Epoch 150/100000
# 5/5 - 0s - loss: 4427.1992 - mse: 4427.1992 - val_loss: 158.1728 - val_mse: 158.1728 - 35ms/epoch - 7ms/step
# Epoch 151/100000
# 5/5 - 0s - loss: 4426.6943 - mse: 4426.6943 - val_loss: 157.8876 - val_mse: 157.8876 - 41ms/epoch - 8ms/step
# Epoch 152/100000
# 5/5 - 0s - loss: 4426.2329 - mse: 4426.2329 - val_loss: 157.8181 - val_mse: 157.8181 - 40ms/epoch - 8ms/step
# Epoch 153/100000
# 5/5 - 0s - loss: 4425.7935 - mse: 4425.7935 - val_loss: 157.2855 - val_mse: 157.2855 - 36ms/epoch - 7ms/step
# Epoch 154/100000
# 5/5 - 0s - loss: 4425.3164 - mse: 4425.3164 - val_loss: 156.8796 - val_mse: 156.8796 - 38ms/epoch - 8ms/step
# Epoch 155/100000
# 5/5 - 0s - loss: 4425.1636 - mse: 4425.1636 - val_loss: 157.0422 - val_mse: 157.0422 - 25ms/epoch - 5ms/step
# Epoch 156/100000
# 5/5 - 0s - loss: 4424.5220 - mse: 4424.5220 - val_loss: 156.8707 - val_mse: 156.8707 - 38ms/epoch - 8ms/step
# Epoch 157/100000
# 5/5 - 0s - loss: 4423.8740 - mse: 4423.8740 - val_loss: 156.4553 - val_mse: 156.4553 - 35ms/epoch - 7ms/step
# Epoch 158/100000
# 5/5 - 0s - loss: 4423.6680 - mse: 4423.6680 - val_loss: 156.2540 - val_mse: 156.2540 - 39ms/epoch - 8ms/step
# Epoch 159/100000
# 5/5 - 0s - loss: 4422.8672 - mse: 4422.8672 - val_loss: 156.6289 - val_mse: 156.6289 - 25ms/epoch - 5ms/step
# Epoch 160/100000
# 5/5 - 0s - loss: 4422.2451 - mse: 4422.2451 - val_loss: 156.3268 - val_mse: 156.3268 - 26ms/epoch - 5ms/step
# Epoch 161/100000
# 5/5 - 0s - loss: 4421.8154 - mse: 4421.8154 - val_loss: 155.8523 - val_mse: 155.8523 - 38ms/epoch - 8ms/step
# Epoch 162/100000
# 5/5 - 0s - loss: 4421.1387 - mse: 4421.1387 - val_loss: 156.1590 - val_mse: 156.1590 - 26ms/epoch - 5ms/step
# Epoch 163/100000
# 5/5 - 0s - loss: 4420.6909 - mse: 4420.6909 - val_loss: 155.9310 - val_mse: 155.9310 - 24ms/epoch - 5ms/step
# Epoch 164/100000
# 5/5 - 0s - loss: 4419.8823 - mse: 4419.8823 - val_loss: 155.7166 - val_mse: 155.7166 - 40ms/epoch - 8ms/step
# Epoch 165/100000
# 5/5 - 0s - loss: 4419.3047 - mse: 4419.3047 - val_loss: 155.5919 - val_mse: 155.5919 - 37ms/epoch - 7ms/step
# Epoch 166/100000
# 5/5 - 0s - loss: 4418.7148 - mse: 4418.7148 - val_loss: 155.3889 - val_mse: 155.3889 - 39ms/epoch - 8ms/step
# Epoch 167/100000
# 5/5 - 0s - loss: 4418.2583 - mse: 4418.2583 - val_loss: 155.1538 - val_mse: 155.1538 - 35ms/epoch - 7ms/step
# Epoch 168/100000
# 5/5 - 0s - loss: 4417.5815 - mse: 4417.5815 - val_loss: 154.6123 - val_mse: 154.6123 - 33ms/epoch - 7ms/step
# Epoch 169/100000
# 5/5 - 0s - loss: 4417.1997 - mse: 4417.1997 - val_loss: 154.3006 - val_mse: 154.3006 - 36ms/epoch - 7ms/step
# Epoch 170/100000
# 5/5 - 0s - loss: 4416.4448 - mse: 4416.4448 - val_loss: 154.0670 - val_mse: 154.0670 - 37ms/epoch - 7ms/step
# Epoch 171/100000
# 5/5 - 0s - loss: 4416.0288 - mse: 4416.0288 - val_loss: 153.9565 - val_mse: 153.9565 - 35ms/epoch - 7ms/step
# Epoch 172/100000
# 5/5 - 0s - loss: 4415.5239 - mse: 4415.5239 - val_loss: 153.7486 - val_mse: 153.7486 - 38ms/epoch - 8ms/step
# Epoch 173/100000
# 5/5 - 0s - loss: 4415.1357 - mse: 4415.1357 - val_loss: 153.5958 - val_mse: 153.5958 - 38ms/epoch - 8ms/step
# Epoch 174/100000
# 5/5 - 0s - loss: 4414.8169 - mse: 4414.8169 - val_loss: 153.7010 - val_mse: 153.7010 - 25ms/epoch - 5ms/step
# Epoch 175/100000
# 5/5 - 0s - loss: 4414.0195 - mse: 4414.0200 - val_loss: 153.4778 - val_mse: 153.4778 - 35ms/epoch - 7ms/step
# Epoch 176/100000
# 5/5 - 0s - loss: 4413.4346 - mse: 4413.4346 - val_loss: 153.9905 - val_mse: 153.9905 - 25ms/epoch - 5ms/step
# Epoch 177/100000
# 5/5 - 0s - loss: 4412.7954 - mse: 4412.7954 - val_loss: 153.8448 - val_mse: 153.8448 - 27ms/epoch - 5ms/step
# Epoch 178/100000
# 5/5 - 0s - loss: 4412.2271 - mse: 4412.2271 - val_loss: 153.7464 - val_mse: 153.7464 - 34ms/epoch - 7ms/step
# Epoch 179/100000
# 5/5 - 0s - loss: 4411.5532 - mse: 4411.5532 - val_loss: 153.2921 - val_mse: 153.2921 - 34ms/epoch - 7ms/step
# Epoch 180/100000
# 5/5 - 0s - loss: 4411.0068 - mse: 4411.0068 - val_loss: 153.1196 - val_mse: 153.1196 - 34ms/epoch - 7ms/step
# Epoch 181/100000
# 5/5 - 0s - loss: 4410.2437 - mse: 4410.2437 - val_loss: 152.7928 - val_mse: 152.7928 - 38ms/epoch - 8ms/step
# Epoch 182/100000
# 5/5 - 0s - loss: 4409.8989 - mse: 4409.8989 - val_loss: 153.3593 - val_mse: 153.3593 - 25ms/epoch - 5ms/step
# Epoch 183/100000
# 5/5 - 0s - loss: 4409.2725 - mse: 4409.2725 - val_loss: 152.9948 - val_mse: 152.9948 - 28ms/epoch - 6ms/step
# Epoch 184/100000
# 5/5 - 0s - loss: 4408.4951 - mse: 4408.4951 - val_loss: 152.5105 - val_mse: 152.5105 - 36ms/epoch - 7ms/step
# Epoch 185/100000
# 5/5 - 0s - loss: 4407.9834 - mse: 4407.9834 - val_loss: 152.2098 - val_mse: 152.2098 - 37ms/epoch - 7ms/step
# Epoch 186/100000
# 5/5 - 0s - loss: 4407.3101 - mse: 4407.3101 - val_loss: 151.7458 - val_mse: 151.7458 - 42ms/epoch - 8ms/step
# Epoch 187/100000
# 5/5 - 0s - loss: 4406.3301 - mse: 4406.3301 - val_loss: 151.6038 - val_mse: 151.6038 - 38ms/epoch - 8ms/step
# Epoch 188/100000
# 5/5 - 0s - loss: 4405.6885 - mse: 4405.6885 - val_loss: 151.5392 - val_mse: 151.5392 - 38ms/epoch - 8ms/step
# Epoch 189/100000
# 5/5 - 0s - loss: 4404.9531 - mse: 4404.9531 - val_loss: 151.4888 - val_mse: 151.4888 - 35ms/epoch - 7ms/step
# Epoch 190/100000
# 5/5 - 0s - loss: 4404.4302 - mse: 4404.4302 - val_loss: 151.2314 - val_mse: 151.2314 - 34ms/epoch - 7ms/step
# Epoch 191/100000
# 5/5 - 0s - loss: 4403.8955 - mse: 4403.8960 - val_loss: 151.0310 - val_mse: 151.0310 - 36ms/epoch - 7ms/step
# Epoch 192/100000
# 5/5 - 0s - loss: 4403.6377 - mse: 4403.6377 - val_loss: 151.8168 - val_mse: 151.8168 - 30ms/epoch - 6ms/step
# Epoch 193/100000
# 5/5 - 0s - loss: 4403.1147 - mse: 4403.1147 - val_loss: 151.3814 - val_mse: 151.3814 - 27ms/epoch - 5ms/step
# Epoch 194/100000
# 5/5 - 0s - loss: 4402.2622 - mse: 4402.2622 - val_loss: 151.1621 - val_mse: 151.1621 - 24ms/epoch - 5ms/step
# Epoch 195/100000
# 5/5 - 0s - loss: 4401.7710 - mse: 4401.7705 - val_loss: 150.9801 - val_mse: 150.9801 - 37ms/epoch - 7ms/step
# Epoch 196/100000
# 5/5 - 0s - loss: 4401.0913 - mse: 4401.0903 - val_loss: 150.6510 - val_mse: 150.6510 - 37ms/epoch - 7ms/step
# Epoch 197/100000
# 5/5 - 0s - loss: 4400.1709 - mse: 4400.1709 - val_loss: 150.9260 - val_mse: 150.9260 - 27ms/epoch - 5ms/step
# Epoch 198/100000
# 5/5 - 0s - loss: 4400.1611 - mse: 4400.1611 - val_loss: 150.3520 - val_mse: 150.3520 - 33ms/epoch - 7ms/step
# Epoch 199/100000
# 5/5 - 0s - loss: 4399.2861 - mse: 4399.2861 - val_loss: 149.8531 - val_mse: 149.8531 - 41ms/epoch - 8ms/step
# Epoch 200/100000
# 5/5 - 0s - loss: 4398.8477 - mse: 4398.8477 - val_loss: 149.5980 - val_mse: 149.5980 - 35ms/epoch - 7ms/step
# Epoch 201/100000
# 5/5 - 0s - loss: 4398.2227 - mse: 4398.2227 - val_loss: 149.3422 - val_mse: 149.3422 - 33ms/epoch - 7ms/step
# Epoch 202/100000
# 5/5 - 0s - loss: 4397.3066 - mse: 4397.3066 - val_loss: 148.9127 - val_mse: 148.9127 - 37ms/epoch - 7ms/step
# Epoch 203/100000
# 5/5 - 0s - loss: 4396.7935 - mse: 4396.7935 - val_loss: 149.4831 - val_mse: 149.4831 - 26ms/epoch - 5ms/step
# Epoch 204/100000
# 5/5 - 0s - loss: 4396.0928 - mse: 4396.0928 - val_loss: 149.0596 - val_mse: 149.0596 - 24ms/epoch - 5ms/step
# Epoch 205/100000
# 5/5 - 0s - loss: 4395.7563 - mse: 4395.7563 - val_loss: 149.4525 - val_mse: 149.4525 - 24ms/epoch - 5ms/step
# Epoch 206/100000
# 5/5 - 0s - loss: 4395.7822 - mse: 4395.7822 - val_loss: 149.0556 - val_mse: 149.0556 - 24ms/epoch - 5ms/step
# Epoch 207/100000
# 5/5 - 0s - loss: 4395.4297 - mse: 4395.4297 - val_loss: 148.8443 - val_mse: 148.8443 - 35ms/epoch - 7ms/step
# Epoch 208/100000
# 5/5 - 0s - loss: 4394.2480 - mse: 4394.2480 - val_loss: 148.6538 - val_mse: 148.6538 - 38ms/epoch - 8ms/step
# Epoch 209/100000
# 5/5 - 0s - loss: 4393.6255 - mse: 4393.6255 - val_loss: 149.0171 - val_mse: 149.0171 - 25ms/epoch - 5ms/step
# Epoch 210/100000
# 5/5 - 0s - loss: 4393.7290 - mse: 4393.7290 - val_loss: 148.4699 - val_mse: 148.4699 - 33ms/epoch - 7ms/step
# Epoch 211/100000
# 5/5 - 0s - loss: 4392.7593 - mse: 4392.7593 - val_loss: 148.2052 - val_mse: 148.2052 - 37ms/epoch - 7ms/step
# Epoch 212/100000
# 5/5 - 0s - loss: 4391.8262 - mse: 4391.8262 - val_loss: 147.9165 - val_mse: 147.9165 - 33ms/epoch - 7ms/step
# Epoch 213/100000
# 5/5 - 0s - loss: 4391.0322 - mse: 4391.0322 - val_loss: 147.8614 - val_mse: 147.8614 - 37ms/epoch - 7ms/step
# Epoch 214/100000
# 5/5 - 0s - loss: 4390.3169 - mse: 4390.3169 - val_loss: 147.9623 - val_mse: 147.9623 - 24ms/epoch - 5ms/step
# Epoch 215/100000
# 5/5 - 0s - loss: 4389.8257 - mse: 4389.8257 - val_loss: 147.9758 - val_mse: 147.9758 - 25ms/epoch - 5ms/step
# Epoch 216/100000
# 5/5 - 0s - loss: 4389.5698 - mse: 4389.5698 - val_loss: 147.5851 - val_mse: 147.5851 - 38ms/epoch - 8ms/step
# Epoch 217/100000
# 5/5 - 0s - loss: 4388.3125 - mse: 4388.3125 - val_loss: 147.0434 - val_mse: 147.0434 - 37ms/epoch - 7ms/step
# Epoch 218/100000
# 5/5 - 0s - loss: 4387.7993 - mse: 4387.7993 - val_loss: 147.3709 - val_mse: 147.3709 - 24ms/epoch - 5ms/step
# Epoch 219/100000
# 5/5 - 0s - loss: 4387.1831 - mse: 4387.1831 - val_loss: 147.0619 - val_mse: 147.0619 - 24ms/epoch - 5ms/step
# Epoch 220/100000
# 5/5 - 0s - loss: 4386.2729 - mse: 4386.2729 - val_loss: 146.6803 - val_mse: 146.6803 - 35ms/epoch - 7ms/step
# Epoch 221/100000
# 5/5 - 0s - loss: 4385.5015 - mse: 4385.5015 - val_loss: 145.6895 - val_mse: 145.6895 - 36ms/epoch - 7ms/step
# Epoch 222/100000
# 5/5 - 0s - loss: 4384.8774 - mse: 4384.8774 - val_loss: 145.0104 - val_mse: 145.0104 - 38ms/epoch - 8ms/step
# Epoch 223/100000
# 5/5 - 0s - loss: 4384.6201 - mse: 4384.6201 - val_loss: 144.9856 - val_mse: 144.9856 - 36ms/epoch - 7ms/step
# Epoch 224/100000
# 5/5 - 0s - loss: 4383.8413 - mse: 4383.8413 - val_loss: 145.2153 - val_mse: 145.2153 - 24ms/epoch - 5ms/step
# Epoch 225/100000
# 5/5 - 0s - loss: 4383.0610 - mse: 4383.0610 - val_loss: 145.3078 - val_mse: 145.3078 - 24ms/epoch - 5ms/step
# Epoch 226/100000
# 5/5 - 0s - loss: 4382.2314 - mse: 4382.2314 - val_loss: 145.3354 - val_mse: 145.3354 - 24ms/epoch - 5ms/step
# Epoch 227/100000
# 5/5 - 0s - loss: 4383.6299 - mse: 4383.6299 - val_loss: 145.4600 - val_mse: 145.4600 - 24ms/epoch - 5ms/step
# Epoch 228/100000
# 5/5 - 0s - loss: 4381.0615 - mse: 4381.0615 - val_loss: 145.2962 - val_mse: 145.2962 - 30ms/epoch - 6ms/step
# Epoch 229/100000
# 5/5 - 0s - loss: 4380.0752 - mse: 4380.0757 - val_loss: 144.9423 - val_mse: 144.9423 - 36ms/epoch - 7ms/step
# Epoch 230/100000
# 5/5 - 0s - loss: 4379.5713 - mse: 4379.5713 - val_loss: 145.5229 - val_mse: 145.5229 - 24ms/epoch - 5ms/step
# Epoch 231/100000
# 5/5 - 0s - loss: 4379.1294 - mse: 4379.1294 - val_loss: 145.2830 - val_mse: 145.2830 - 24ms/epoch - 5ms/step
# Epoch 232/100000
# 5/5 - 0s - loss: 4378.5269 - mse: 4378.5269 - val_loss: 145.6518 - val_mse: 145.6518 - 25ms/epoch - 5ms/step
# Epoch 233/100000
# 5/5 - 0s - loss: 4378.5728 - mse: 4378.5728 - val_loss: 144.6769 - val_mse: 144.6769 - 33ms/epoch - 7ms/step
# Epoch 234/100000
# 5/5 - 0s - loss: 4377.7930 - mse: 4377.7930 - val_loss: 144.7288 - val_mse: 144.7288 - 27ms/epoch - 5ms/step
# Epoch 235/100000
# 5/5 - 0s - loss: 4376.6489 - mse: 4376.6489 - val_loss: 144.4203 - val_mse: 144.4203 - 37ms/epoch - 7ms/step
# Epoch 236/100000
# 5/5 - 0s - loss: 4376.0190 - mse: 4376.0190 - val_loss: 145.1366 - val_mse: 145.1366 - 25ms/epoch - 5ms/step
# Epoch 237/100000
# 5/5 - 0s - loss: 4376.6157 - mse: 4376.6157 - val_loss: 144.3627 - val_mse: 144.3627 - 37ms/epoch - 7ms/step
# Epoch 238/100000
# 5/5 - 0s - loss: 4375.2285 - mse: 4375.2285 - val_loss: 144.1835 - val_mse: 144.1835 - 37ms/epoch - 7ms/step
# Epoch 239/100000
# 5/5 - 0s - loss: 4374.4609 - mse: 4374.4609 - val_loss: 143.9507 - val_mse: 143.9507 - 33ms/epoch - 7ms/step
# Epoch 240/100000
# 5/5 - 0s - loss: 4373.7422 - mse: 4373.7422 - val_loss: 144.9102 - val_mse: 144.9102 - 26ms/epoch - 5ms/step
# Epoch 241/100000
# 5/5 - 0s - loss: 4374.2271 - mse: 4374.2271 - val_loss: 143.5466 - val_mse: 143.5466 - 38ms/epoch - 8ms/step
# Epoch 242/100000
# 5/5 - 0s - loss: 4372.9214 - mse: 4372.9214 - val_loss: 143.4284 - val_mse: 143.4284 - 35ms/epoch - 7ms/step
# Epoch 243/100000
# 5/5 - 0s - loss: 4372.0859 - mse: 4372.0859 - val_loss: 143.6364 - val_mse: 143.6364 - 27ms/epoch - 5ms/step
# Epoch 244/100000
# 5/5 - 0s - loss: 4370.8960 - mse: 4370.8960 - val_loss: 143.8343 - val_mse: 143.8343 - 26ms/epoch - 5ms/step
# Epoch 245/100000
# 5/5 - 0s - loss: 4371.1309 - mse: 4371.1309 - val_loss: 143.3221 - val_mse: 143.3221 - 35ms/epoch - 7ms/step
# Epoch 246/100000
# 5/5 - 0s - loss: 4370.0645 - mse: 4370.0645 - val_loss: 142.5081 - val_mse: 142.5081 - 44ms/epoch - 9ms/step
# Epoch 247/100000
# 5/5 - 0s - loss: 4368.9575 - mse: 4368.9575 - val_loss: 142.1982 - val_mse: 142.1982 - 40ms/epoch - 8ms/step
# Epoch 248/100000
# 5/5 - 0s - loss: 4368.1079 - mse: 4368.1079 - val_loss: 141.7486 - val_mse: 141.7486 - 38ms/epoch - 8ms/step
# Epoch 249/100000
# 5/5 - 0s - loss: 4368.1426 - mse: 4368.1426 - val_loss: 141.9289 - val_mse: 141.9289 - 26ms/epoch - 5ms/step
# Epoch 250/100000
# 5/5 - 0s - loss: 4367.0806 - mse: 4367.0801 - val_loss: 141.4147 - val_mse: 141.4147 - 36ms/epoch - 7ms/step
# Epoch 251/100000
# 5/5 - 0s - loss: 4366.7334 - mse: 4366.7334 - val_loss: 142.7164 - val_mse: 142.7164 - 26ms/epoch - 5ms/step
# Epoch 252/100000
# 5/5 - 0s - loss: 4366.6055 - mse: 4366.6055 - val_loss: 141.9633 - val_mse: 141.9633 - 28ms/epoch - 6ms/step
# Epoch 253/100000
# 5/5 - 0s - loss: 4364.3984 - mse: 4364.3984 - val_loss: 140.4384 - val_mse: 140.4384 - 36ms/epoch - 7ms/step
# Epoch 254/100000
# 5/5 - 0s - loss: 4363.8555 - mse: 4363.8555 - val_loss: 140.4912 - val_mse: 140.4912 - 31ms/epoch - 6ms/step
# Epoch 255/100000
# 5/5 - 0s - loss: 4364.0825 - mse: 4364.0825 - val_loss: 140.3670 - val_mse: 140.3670 - 50ms/epoch - 10ms/step
# Epoch 256/100000
# 5/5 - 0s - loss: 4362.7178 - mse: 4362.7178 - val_loss: 140.2244 - val_mse: 140.2244 - 35ms/epoch - 7ms/step
# Epoch 257/100000
# 5/5 - 0s - loss: 4362.8613 - mse: 4362.8613 - val_loss: 140.2745 - val_mse: 140.2745 - 23ms/epoch - 5ms/step
# Epoch 258/100000
# 5/5 - 0s - loss: 4361.0244 - mse: 4361.0244 - val_loss: 139.7236 - val_mse: 139.7236 - 33ms/epoch - 7ms/step
# Epoch 259/100000
# 5/5 - 0s - loss: 4360.1880 - mse: 4360.1880 - val_loss: 139.8363 - val_mse: 139.8363 - 25ms/epoch - 5ms/step
# Epoch 260/100000
# 5/5 - 0s - loss: 4359.1655 - mse: 4359.1655 - val_loss: 139.9587 - val_mse: 139.9587 - 30ms/epoch - 6ms/step
# Epoch 261/100000
# 5/5 - 0s - loss: 4358.8130 - mse: 4358.8130 - val_loss: 139.4554 - val_mse: 139.4554 - 38ms/epoch - 8ms/step
# Epoch 262/100000
# 5/5 - 0s - loss: 4358.5396 - mse: 4358.5396 - val_loss: 139.3393 - val_mse: 139.3393 - 37ms/epoch - 7ms/step
# Epoch 263/100000
# 5/5 - 0s - loss: 4356.7734 - mse: 4356.7734 - val_loss: 139.3721 - val_mse: 139.3721 - 27ms/epoch - 5ms/step
# Epoch 264/100000
# 5/5 - 0s - loss: 4356.1299 - mse: 4356.1299 - val_loss: 139.7215 - val_mse: 139.7215 - 25ms/epoch - 5ms/step
# Epoch 265/100000
# 5/5 - 0s - loss: 4355.2559 - mse: 4355.2559 - val_loss: 138.8914 - val_mse: 138.8914 - 39ms/epoch - 8ms/step
# Epoch 266/100000
# 5/5 - 0s - loss: 4355.0400 - mse: 4355.0400 - val_loss: 137.9917 - val_mse: 137.9917 - 38ms/epoch - 8ms/step
# Epoch 267/100000
# 5/5 - 0s - loss: 4355.0522 - mse: 4355.0522 - val_loss: 138.0744 - val_mse: 138.0744 - 26ms/epoch - 5ms/step
# Epoch 268/100000
# 5/5 - 0s - loss: 4353.2632 - mse: 4353.2632 - val_loss: 138.7062 - val_mse: 138.7062 - 24ms/epoch - 5ms/step
# Epoch 269/100000
# 5/5 - 0s - loss: 4352.2075 - mse: 4352.2075 - val_loss: 138.6642 - val_mse: 138.6642 - 24ms/epoch - 5ms/step
# Epoch 270/100000
# 5/5 - 0s - loss: 4352.5986 - mse: 4352.5981 - val_loss: 138.7524 - val_mse: 138.7524 - 24ms/epoch - 5ms/step
# Epoch 271/100000
# 5/5 - 0s - loss: 4350.5713 - mse: 4350.5718 - val_loss: 139.1220 - val_mse: 139.1220 - 24ms/epoch - 5ms/step
# Epoch 272/100000
# 5/5 - 0s - loss: 4350.0723 - mse: 4350.0723 - val_loss: 138.4596 - val_mse: 138.4596 - 23ms/epoch - 5ms/step
# Epoch 273/100000
# 5/5 - 0s - loss: 4349.2993 - mse: 4349.2993 - val_loss: 137.7570 - val_mse: 137.7570 - 33ms/epoch - 7ms/step
# Epoch 274/100000
# 5/5 - 0s - loss: 4348.9927 - mse: 4348.9927 - val_loss: 137.5184 - val_mse: 137.5184 - 32ms/epoch - 6ms/step
# Epoch 275/100000
# 5/5 - 0s - loss: 4348.0869 - mse: 4348.0869 - val_loss: 137.1460 - val_mse: 137.1460 - 34ms/epoch - 7ms/step
# Epoch 276/100000
# 5/5 - 0s - loss: 4348.8164 - mse: 4348.8164 - val_loss: 137.2243 - val_mse: 137.2243 - 25ms/epoch - 5ms/step
# Epoch 277/100000
# 5/5 - 0s - loss: 4346.8374 - mse: 4346.8374 - val_loss: 137.2592 - val_mse: 137.2592 - 26ms/epoch - 5ms/step
# Epoch 278/100000
# 5/5 - 0s - loss: 4346.6416 - mse: 4346.6416 - val_loss: 136.6594 - val_mse: 136.6594 - 34ms/epoch - 7ms/step
# Epoch 279/100000
# 5/5 - 0s - loss: 4345.3955 - mse: 4345.3960 - val_loss: 137.3628 - val_mse: 137.3628 - 25ms/epoch - 5ms/step
# Epoch 280/100000
# 5/5 - 0s - loss: 4351.0127 - mse: 4351.0127 - val_loss: 136.4247 - val_mse: 136.4247 - 33ms/epoch - 7ms/step
# Epoch 281/100000
# 5/5 - 0s - loss: 4344.0903 - mse: 4344.0903 - val_loss: 136.6160 - val_mse: 136.6160 - 23ms/epoch - 5ms/step
# Epoch 282/100000
# 5/5 - 0s - loss: 4344.7368 - mse: 4344.7368 - val_loss: 136.7574 - val_mse: 136.7574 - 25ms/epoch - 5ms/step
# Epoch 283/100000
# 5/5 - 0s - loss: 4342.3301 - mse: 4342.3301 - val_loss: 135.9221 - val_mse: 135.9221 - 35ms/epoch - 7ms/step
# Epoch 284/100000
# 5/5 - 0s - loss: 4346.9106 - mse: 4346.9106 - val_loss: 136.4912 - val_mse: 136.4912 - 25ms/epoch - 5ms/step
# Epoch 285/100000
# 5/5 - 0s - loss: 4341.5327 - mse: 4341.5327 - val_loss: 134.8799 - val_mse: 134.8799 - 35ms/epoch - 7ms/step
# Epoch 286/100000
# 5/5 - 0s - loss: 4340.8984 - mse: 4340.8984 - val_loss: 135.1453 - val_mse: 135.1453 - 24ms/epoch - 5ms/step
# Epoch 287/100000
# 5/5 - 0s - loss: 4340.2114 - mse: 4340.2114 - val_loss: 134.2834 - val_mse: 134.2834 - 35ms/epoch - 7ms/step
# Epoch 288/100000
# 5/5 - 0s - loss: 4339.5210 - mse: 4339.5210 - val_loss: 134.5451 - val_mse: 134.5451 - 24ms/epoch - 5ms/step
# Epoch 289/100000
# 5/5 - 0s - loss: 4339.2915 - mse: 4339.2915 - val_loss: 133.7132 - val_mse: 133.7132 - 34ms/epoch - 7ms/step
# Epoch 290/100000
# 5/5 - 0s - loss: 4340.5996 - mse: 4340.5996 - val_loss: 133.3948 - val_mse: 133.3948 - 36ms/epoch - 7ms/step
# Epoch 291/100000
# 5/5 - 0s - loss: 4339.4375 - mse: 4339.4375 - val_loss: 133.8919 - val_mse: 133.8919 - 24ms/epoch - 5ms/step
# Epoch 292/100000
# 5/5 - 0s - loss: 4337.6743 - mse: 4337.6738 - val_loss: 133.9446 - val_mse: 133.9446 - 26ms/epoch - 5ms/step
# Epoch 293/100000
# 5/5 - 0s - loss: 4336.9585 - mse: 4336.9585 - val_loss: 133.8148 - val_mse: 133.8148 - 25ms/epoch - 5ms/step
# Epoch 294/100000
# 5/5 - 0s - loss: 4335.8379 - mse: 4335.8379 - val_loss: 132.9374 - val_mse: 132.9374 - 35ms/epoch - 7ms/step
# Epoch 295/100000
# 5/5 - 0s - loss: 4335.1636 - mse: 4335.1636 - val_loss: 132.1839 - val_mse: 132.1839 - 34ms/epoch - 7ms/step
# Epoch 296/100000
# 5/5 - 0s - loss: 4334.2231 - mse: 4334.2231 - val_loss: 133.8646 - val_mse: 133.8646 - 25ms/epoch - 5ms/step
# Epoch 297/100000
# 5/5 - 0s - loss: 4334.3794 - mse: 4334.3794 - val_loss: 131.8015 - val_mse: 131.8015 - 37ms/epoch - 7ms/step
# Epoch 298/100000
# 5/5 - 0s - loss: 4332.7461 - mse: 4332.7461 - val_loss: 132.2878 - val_mse: 132.2878 - 23ms/epoch - 5ms/step
# Epoch 299/100000
# 5/5 - 0s - loss: 4333.2817 - mse: 4333.2817 - val_loss: 133.1372 - val_mse: 133.1372 - 25ms/epoch - 5ms/step
# Epoch 300/100000
# 5/5 - 0s - loss: 4331.1255 - mse: 4331.1255 - val_loss: 132.5861 - val_mse: 132.5861 - 26ms/epoch - 5ms/step
# Epoch 301/100000
# 5/5 - 0s - loss: 4330.7798 - mse: 4330.7798 - val_loss: 132.4445 - val_mse: 132.4445 - 28ms/epoch - 6ms/step
# Epoch 302/100000
# 5/5 - 0s - loss: 4330.7998 - mse: 4330.7998 - val_loss: 132.4849 - val_mse: 132.4849 - 30ms/epoch - 6ms/step
# Epoch 303/100000
# 5/5 - 0s - loss: 4329.8530 - mse: 4329.8535 - val_loss: 130.8720 - val_mse: 130.8720 - 38ms/epoch - 8ms/step
# Epoch 304/100000
# 5/5 - 0s - loss: 4331.6367 - mse: 4331.6367 - val_loss: 131.1590 - val_mse: 131.1590 - 25ms/epoch - 5ms/step
# Epoch 305/100000
# 5/5 - 0s - loss: 4330.1831 - mse: 4330.1831 - val_loss: 132.0084 - val_mse: 132.0084 - 26ms/epoch - 5ms/step
# Epoch 306/100000
# 5/5 - 0s - loss: 4328.8037 - mse: 4328.8037 - val_loss: 131.1965 - val_mse: 131.1965 - 26ms/epoch - 5ms/step
# Epoch 307/100000
# 5/5 - 0s - loss: 4326.3633 - mse: 4326.3633 - val_loss: 130.4291 - val_mse: 130.4291 - 37ms/epoch - 7ms/step
# Epoch 308/100000
# 5/5 - 0s - loss: 4327.6528 - mse: 4327.6528 - val_loss: 130.6087 - val_mse: 130.6087 - 24ms/epoch - 5ms/step
# Epoch 309/100000
# 5/5 - 0s - loss: 4325.3584 - mse: 4325.3584 - val_loss: 132.9903 - val_mse: 132.9903 - 25ms/epoch - 5ms/step
# Epoch 310/100000
# 5/5 - 0s - loss: 4328.1543 - mse: 4328.1543 - val_loss: 130.4868 - val_mse: 130.4868 - 29ms/epoch - 6ms/step
# Epoch 311/100000
# 5/5 - 0s - loss: 4323.9028 - mse: 4323.9028 - val_loss: 131.6871 - val_mse: 131.6871 - 26ms/epoch - 5ms/step
# Epoch 312/100000
# 5/5 - 0s - loss: 4333.6445 - mse: 4333.6445 - val_loss: 129.0504 - val_mse: 129.0504 - 37ms/epoch - 7ms/step
# Epoch 313/100000
# 5/5 - 0s - loss: 4323.6284 - mse: 4323.6289 - val_loss: 128.9566 - val_mse: 128.9566 - 34ms/epoch - 7ms/step
# Epoch 314/100000
# 5/5 - 0s - loss: 4322.4575 - mse: 4322.4575 - val_loss: 129.0338 - val_mse: 129.0338 - 25ms/epoch - 5ms/step
# Epoch 315/100000
# 5/5 - 0s - loss: 4321.6987 - mse: 4321.6987 - val_loss: 129.1499 - val_mse: 129.1499 - 24ms/epoch - 5ms/step
# Epoch 316/100000
# 5/5 - 0s - loss: 4320.4795 - mse: 4320.4800 - val_loss: 128.9003 - val_mse: 128.9003 - 36ms/epoch - 7ms/step
# Epoch 317/100000
# 5/5 - 0s - loss: 4320.6997 - mse: 4320.6997 - val_loss: 130.3999 - val_mse: 130.3999 - 26ms/epoch - 5ms/step
# Epoch 318/100000
# 5/5 - 0s - loss: 4320.3428 - mse: 4320.3428 - val_loss: 128.8246 - val_mse: 128.8246 - 34ms/epoch - 7ms/step
# Epoch 319/100000
# 5/5 - 0s - loss: 4318.3735 - mse: 4318.3735 - val_loss: 129.4310 - val_mse: 129.4310 - 23ms/epoch - 5ms/step
# Epoch 320/100000
# 5/5 - 0s - loss: 4318.6650 - mse: 4318.6650 - val_loss: 131.4072 - val_mse: 131.4072 - 24ms/epoch - 5ms/step
# Epoch 321/100000
# 5/5 - 0s - loss: 4319.4951 - mse: 4319.4951 - val_loss: 129.8566 - val_mse: 129.8566 - 23ms/epoch - 5ms/step
# Epoch 322/100000
# 5/5 - 0s - loss: 4316.6191 - mse: 4316.6191 - val_loss: 129.6518 - val_mse: 129.6518 - 25ms/epoch - 5ms/step
# Epoch 323/100000
# 5/5 - 0s - loss: 4315.8545 - mse: 4315.8545 - val_loss: 129.9083 - val_mse: 129.9083 - 28ms/epoch - 6ms/step
# Epoch 324/100000
# 5/5 - 0s - loss: 4316.2759 - mse: 4316.2759 - val_loss: 128.1520 - val_mse: 128.1520 - 37ms/epoch - 7ms/step
# Epoch 325/100000
# 5/5 - 0s - loss: 4317.6548 - mse: 4317.6553 - val_loss: 127.8721 - val_mse: 127.8721 - 39ms/epoch - 8ms/step
# Epoch 326/100000
# 5/5 - 0s - loss: 4313.2246 - mse: 4313.2246 - val_loss: 128.8401 - val_mse: 128.8401 - 23ms/epoch - 5ms/step
# Epoch 327/100000
# 5/5 - 0s - loss: 4312.9668 - mse: 4312.9668 - val_loss: 131.5011 - val_mse: 131.5011 - 24ms/epoch - 5ms/step
# Epoch 328/100000
# 5/5 - 0s - loss: 4316.3159 - mse: 4316.3159 - val_loss: 127.4591 - val_mse: 127.4591 - 35ms/epoch - 7ms/step
# Epoch 329/100000
# 5/5 - 0s - loss: 4314.0171 - mse: 4314.0171 - val_loss: 127.9187 - val_mse: 127.9187 - 25ms/epoch - 5ms/step
# Epoch 330/100000
# 5/5 - 0s - loss: 4310.1592 - mse: 4310.1587 - val_loss: 127.4300 - val_mse: 127.4300 - 34ms/epoch - 7ms/step
# Epoch 331/100000
# 5/5 - 0s - loss: 4309.3418 - mse: 4309.3418 - val_loss: 127.0065 - val_mse: 127.0065 - 34ms/epoch - 7ms/step
# Epoch 332/100000
# 5/5 - 0s - loss: 4308.9233 - mse: 4308.9233 - val_loss: 126.7767 - val_mse: 126.7767 - 34ms/epoch - 7ms/step
# Epoch 333/100000
# 5/5 - 0s - loss: 4310.0942 - mse: 4310.0942 - val_loss: 128.6250 - val_mse: 128.6250 - 27ms/epoch - 5ms/step
# Epoch 334/100000
# 5/5 - 0s - loss: 4306.2651 - mse: 4306.2651 - val_loss: 129.6395 - val_mse: 129.6395 - 26ms/epoch - 5ms/step
# Epoch 335/100000
# 5/5 - 0s - loss: 4305.8975 - mse: 4305.8975 - val_loss: 128.8065 - val_mse: 128.8065 - 24ms/epoch - 5ms/step
# Epoch 336/100000
# 5/5 - 0s - loss: 4305.0425 - mse: 4305.0425 - val_loss: 133.2469 - val_mse: 133.2469 - 22ms/epoch - 4ms/step
# Epoch 337/100000
# 5/5 - 0s - loss: 4308.8062 - mse: 4308.8066 - val_loss: 130.6648 - val_mse: 130.6648 - 23ms/epoch - 5ms/step
# Epoch 338/100000
# 5/5 - 0s - loss: 4304.7700 - mse: 4304.7710 - val_loss: 128.0996 - val_mse: 128.0996 - 24ms/epoch - 5ms/step
# Epoch 339/100000
# 5/5 - 0s - loss: 4304.0469 - mse: 4304.0469 - val_loss: 129.1149 - val_mse: 129.1149 - 24ms/epoch - 5ms/step
# Epoch 340/100000
# 5/5 - 0s - loss: 4302.7202 - mse: 4302.7202 - val_loss: 128.8986 - val_mse: 128.8986 - 23ms/epoch - 5ms/step
# Epoch 341/100000
# 5/5 - 0s - loss: 4302.8838 - mse: 4302.8833 - val_loss: 128.9941 - val_mse: 128.9941 - 28ms/epoch - 6ms/step
# Epoch 342/100000
# 5/5 - 0s - loss: 4299.9224 - mse: 4299.9224 - val_loss: 129.8184 - val_mse: 129.8184 - 27ms/epoch - 5ms/step
# Epoch 343/100000
# 5/5 - 0s - loss: 4298.7964 - mse: 4298.7969 - val_loss: 131.6151 - val_mse: 131.6151 - 26ms/epoch - 5ms/step
# Epoch 344/100000
# 5/5 - 0s - loss: 4299.1382 - mse: 4299.1382 - val_loss: 129.9982 - val_mse: 129.9982 - 25ms/epoch - 5ms/step
# Epoch 345/100000
# 5/5 - 0s - loss: 4299.3257 - mse: 4299.3262 - val_loss: 130.1644 - val_mse: 130.1644 - 24ms/epoch - 5ms/step
# Epoch 346/100000
# 5/5 - 0s - loss: 4296.3853 - mse: 4296.3853 - val_loss: 129.2201 - val_mse: 129.2201 - 24ms/epoch - 5ms/step
# Epoch 347/100000
# 5/5 - 0s - loss: 4297.8589 - mse: 4297.8589 - val_loss: 128.2047 - val_mse: 128.2047 - 28ms/epoch - 6ms/step
# Epoch 348/100000
# 5/5 - 0s - loss: 4295.2070 - mse: 4295.2070 - val_loss: 129.5727 - val_mse: 129.5727 - 25ms/epoch - 5ms/step
# Epoch 349/100000
# 5/5 - 0s - loss: 4294.5942 - mse: 4294.5942 - val_loss: 129.4001 - val_mse: 129.4001 - 25ms/epoch - 5ms/step
# Epoch 350/100000
# 5/5 - 0s - loss: 4294.3604 - mse: 4294.3604 - val_loss: 128.7047 - val_mse: 128.7047 - 23ms/epoch - 5ms/step
# Epoch 351/100000
# 5/5 - 0s - loss: 4293.1172 - mse: 4293.1172 - val_loss: 128.5287 - val_mse: 128.5287 - 22ms/epoch - 4ms/step
# Epoch 352/100000
# 5/5 - 0s - loss: 4292.8789 - mse: 4292.8789 - val_loss: 129.7501 - val_mse: 129.7501 - 23ms/epoch - 5ms/step
# Epoch 353/100000
# 5/5 - 0s - loss: 4291.1201 - mse: 4291.1201 - val_loss: 129.6915 - val_mse: 129.6915 - 23ms/epoch - 5ms/step
# Epoch 354/100000
# 5/5 - 0s - loss: 4298.4521 - mse: 4298.4521 - val_loss: 128.7859 - val_mse: 128.7859 - 24ms/epoch - 5ms/step
# Epoch 355/100000
# 5/5 - 0s - loss: 4290.1694 - mse: 4290.1694 - val_loss: 128.1952 - val_mse: 128.1952 - 24ms/epoch - 5ms/step
# Epoch 356/100000
# 5/5 - 0s - loss: 4288.5537 - mse: 4288.5537 - val_loss: 128.3316 - val_mse: 128.3316 - 23ms/epoch - 5ms/step
# Epoch 357/100000
# 5/5 - 0s - loss: 4288.2129 - mse: 4288.2129 - val_loss: 128.3007 - val_mse: 128.3007 - 24ms/epoch - 5ms/step
# Epoch 358/100000
# 5/5 - 0s - loss: 4288.4248 - mse: 4288.4248 - val_loss: 128.1449 - val_mse: 128.1449 - 22ms/epoch - 4ms/step
# Epoch 359/100000
# 5/5 - 0s - loss: 4286.3618 - mse: 4286.3613 - val_loss: 127.5556 - val_mse: 127.5556 - 23ms/epoch - 5ms/step
# Epoch 360/100000
# 5/5 - 0s - loss: 4286.7207 - mse: 4286.7207 - val_loss: 127.1041 - val_mse: 127.1041 - 23ms/epoch - 5ms/step
# Epoch 361/100000
# 5/5 - 0s - loss: 4285.6567 - mse: 4285.6567 - val_loss: 127.3460 - val_mse: 127.3460 - 24ms/epoch - 5ms/step
# Epoch 362/100000
# 5/5 - 0s - loss: 4286.1943 - mse: 4286.1943 - val_loss: 127.3993 - val_mse: 127.3993 - 25ms/epoch - 5ms/step
# Epoch 363/100000
# 5/5 - 0s - loss: 4283.7114 - mse: 4283.7114 - val_loss: 127.4920 - val_mse: 127.4920 - 24ms/epoch - 5ms/step
# Epoch 364/100000
# 5/5 - 0s - loss: 4285.6572 - mse: 4285.6572 - val_loss: 127.8044 - val_mse: 127.8044 - 29ms/epoch - 6ms/step
# Epoch 365/100000
# 5/5 - 0s - loss: 4281.8438 - mse: 4281.8438 - val_loss: 126.4126 - val_mse: 126.4126 - 33ms/epoch - 7ms/step
# Epoch 366/100000
# 5/5 - 0s - loss: 4283.9229 - mse: 4283.9229 - val_loss: 129.1563 - val_mse: 129.1563 - 23ms/epoch - 5ms/step
# Epoch 367/100000
# 5/5 - 0s - loss: 4286.6675 - mse: 4286.6675 - val_loss: 126.9827 - val_mse: 126.9827 - 24ms/epoch - 5ms/step
# Epoch 368/100000
# 5/5 - 0s - loss: 4279.6807 - mse: 4279.6807 - val_loss: 130.9218 - val_mse: 130.9218 - 24ms/epoch - 5ms/step
# Epoch 369/100000
# 5/5 - 0s - loss: 4286.4185 - mse: 4286.4185 - val_loss: 127.2572 - val_mse: 127.2572 - 24ms/epoch - 5ms/step
# Epoch 370/100000
# 5/5 - 0s - loss: 4279.0825 - mse: 4279.0825 - val_loss: 127.4182 - val_mse: 127.4182 - 24ms/epoch - 5ms/step
# Epoch 371/100000
# 5/5 - 0s - loss: 4277.7734 - mse: 4277.7734 - val_loss: 127.1020 - val_mse: 127.1020 - 22ms/epoch - 4ms/step
# Epoch 372/100000
# 5/5 - 0s - loss: 4277.2861 - mse: 4277.2866 - val_loss: 127.1837 - val_mse: 127.1837 - 25ms/epoch - 5ms/step
# Epoch 373/100000
# 5/5 - 0s - loss: 4276.3540 - mse: 4276.3540 - val_loss: 126.5050 - val_mse: 126.5050 - 23ms/epoch - 5ms/step
# Epoch 374/100000
# 5/5 - 0s - loss: 4275.8574 - mse: 4275.8574 - val_loss: 126.6048 - val_mse: 126.6048 - 24ms/epoch - 5ms/step
# Epoch 375/100000
# 5/5 - 0s - loss: 4275.7925 - mse: 4275.7920 - val_loss: 126.8673 - val_mse: 126.8673 - 24ms/epoch - 5ms/step
# Epoch 376/100000
# 5/5 - 0s - loss: 4274.2622 - mse: 4274.2622 - val_loss: 128.5837 - val_mse: 128.5837 - 28ms/epoch - 6ms/step
# Epoch 377/100000
# 5/5 - 0s - loss: 4291.9302 - mse: 4291.9302 - val_loss: 124.7911 - val_mse: 124.7911 - 33ms/epoch - 7ms/step
# Epoch 378/100000
# 5/5 - 0s - loss: 4274.7129 - mse: 4274.7129 - val_loss: 125.9760 - val_mse: 125.9760 - 22ms/epoch - 4ms/step
# Epoch 379/100000
# 5/5 - 0s - loss: 4272.0044 - mse: 4272.0049 - val_loss: 126.2049 - val_mse: 126.2049 - 22ms/epoch - 4ms/step
# Epoch 380/100000
# 5/5 - 0s - loss: 4271.7012 - mse: 4271.7012 - val_loss: 125.6571 - val_mse: 125.6571 - 23ms/epoch - 5ms/step
# Epoch 381/100000
# 5/5 - 0s - loss: 4270.3813 - mse: 4270.3813 - val_loss: 125.9548 - val_mse: 125.9548 - 22ms/epoch - 4ms/step
# Epoch 382/100000
# ...
# Epoch 24866/100000
# 5/5 - 0s - loss: 926.9072 - mse: 926.9072 - val_loss: 66.5652 - val_mse: 66.5652 - 32ms/epoch - 6ms/step
# Epoch 24867/100000
# 5/5 - 0s - loss: 922.2179 - mse: 922.2179 - val_loss: 66.9324 - val_mse: 66.9324 - 30ms/epoch - 6ms/step
# Epoch 24868/100000
# 5/5 - 0s - loss: 923.7404 - mse: 923.7404 - val_loss: 67.5588 - val_mse: 67.5588 - 23ms/epoch - 5ms/step
# Epoch 24869/100000
# 5/5 - 0s - loss: 923.9606 - mse: 923.9606 - val_loss: 67.1632 - val_mse: 67.1632 - 29ms/epoch - 6ms/step
# Epoch 24870/100000
# 5/5 - 0s - loss: 923.9825 - mse: 923.9825 - val_loss: 67.6550 - val_mse: 67.6550 - 31ms/epoch - 6ms/step
# Epoch 24871/100000
# 5/5 - 0s - loss: 921.7249 - mse: 921.7249 - val_loss: 67.7602 - val_mse: 67.7602 - 28ms/epoch - 6ms/step
# Epoch 24872/100000
# 5/5 - 0s - loss: 926.9105 - mse: 926.9105 - val_loss: 66.8635 - val_mse: 66.8635 - 31ms/epoch - 6ms/step
# Epoch 24873/100000
# 5/5 - 0s - loss: 925.5810 - mse: 925.5810 - val_loss: 77.4302 - val_mse: 77.4302 - 28ms/epoch - 6ms/step
# Epoch 24874/100000
# 5/5 - 0s - loss: 998.3781 - mse: 998.3781 - val_loss: 68.9438 - val_mse: 68.9438 - 34ms/epoch - 7ms/step
# Epoch 24875/100000
# 5/5 - 0s - loss: 923.3363 - mse: 923.3363 - val_loss: 69.2351 - val_mse: 69.2351 - 30ms/epoch - 6ms/step
# Epoch 24876/100000
# 5/5 - 0s - loss: 928.3279 - mse: 928.3279 - val_loss: 68.4794 - val_mse: 68.4794 - 27ms/epoch - 5ms/step
# Epoch 24877/100000
# 5/5 - 0s - loss: 923.0378 - mse: 923.0378 - val_loss: 68.4137 - val_mse: 68.4137 - 28ms/epoch - 6ms/step
# Epoch 24878/100000
# 5/5 - 0s - loss: 921.0052 - mse: 921.0052 - val_loss: 69.1498 - val_mse: 69.1498 - 34ms/epoch - 7ms/step
# Epoch 24879/100000
# 5/5 - 0s - loss: 930.3651 - mse: 930.3651 - val_loss: 66.6671 - val_mse: 66.6671 - 26ms/epoch - 5ms/step
# Epoch 24880/100000
# 5/5 - 0s - loss: 924.3702 - mse: 924.3702 - val_loss: 67.8625 - val_mse: 67.8625 - 27ms/epoch - 5ms/step
# Epoch 24881/100000
# 5/5 - 0s - loss: 979.5103 - mse: 979.5103 - val_loss: 67.4911 - val_mse: 67.4911 - 30ms/epoch - 6ms/step
# Epoch 24882/100000
# 5/5 - 0s - loss: 1064.0339 - mse: 1064.0339 - val_loss: 68.3407 - val_mse: 68.3407 - 30ms/epoch - 6ms/step
# Epoch 24883/100000
# 5/5 - 0s - loss: 944.4362 - mse: 944.4362 - val_loss: 68.1555 - val_mse: 68.1555 - 27ms/epoch - 5ms/step
# Epoch 24884/100000
# 5/5 - 0s - loss: 925.3167 - mse: 925.3167 - val_loss: 69.4267 - val_mse: 69.4267 - 28ms/epoch - 6ms/step
# Epoch 24885/100000
# 5/5 - 0s - loss: 935.3170 - mse: 935.3170 - val_loss: 69.5287 - val_mse: 69.5287 - 26ms/epoch - 5ms/step
# Epoch 24886/100000
# 5/5 - 0s - loss: 924.6614 - mse: 924.6615 - val_loss: 69.5321 - val_mse: 69.5321 - 30ms/epoch - 6ms/step
# Epoch 24887/100000
# 5/5 - 0s - loss: 929.3889 - mse: 929.3889 - val_loss: 66.2815 - val_mse: 66.2815 - 31ms/epoch - 6ms/step
# Epoch 24888/100000
# 5/5 - 0s - loss: 923.1128 - mse: 923.1128 - val_loss: 66.6689 - val_mse: 66.6689 - 47ms/epoch - 9ms/step
# Epoch 24889/100000
# 5/5 - 0s - loss: 925.0141 - mse: 925.0141 - val_loss: 70.4720 - val_mse: 70.4720 - 42ms/epoch - 8ms/step
# Epoch 24890/100000
# 5/5 - 0s - loss: 989.3664 - mse: 989.3664 - val_loss: 70.2908 - val_mse: 70.2908 - 30ms/epoch - 6ms/step
# Epoch 24891/100000
# 5/5 - 0s - loss: 959.4046 - mse: 959.4046 - val_loss: 68.5463 - val_mse: 68.5463 - 33ms/epoch - 7ms/step
# Epoch 24892/100000
# 5/5 - 0s - loss: 921.5128 - mse: 921.5128 - val_loss: 68.2581 - val_mse: 68.2581 - 35ms/epoch - 7ms/step
# Epoch 24893/100000
# 5/5 - 0s - loss: 919.7106 - mse: 919.7106 - val_loss: 67.4633 - val_mse: 67.4633 - 24ms/epoch - 5ms/step
# Epoch 24894/100000
# 5/5 - 0s - loss: 917.8926 - mse: 917.8926 - val_loss: 71.7055 - val_mse: 71.7055 - 33ms/epoch - 7ms/step
# Epoch 24895/100000
# 5/5 - 0s - loss: 919.3186 - mse: 919.3186 - val_loss: 67.3867 - val_mse: 67.3867 - 28ms/epoch - 6ms/step
# Epoch 24896/100000
# 5/5 - 0s - loss: 917.4476 - mse: 917.4476 - val_loss: 72.6278 - val_mse: 72.6278 - 28ms/epoch - 6ms/step
# Epoch 24897/100000
# 5/5 - 0s - loss: 935.0388 - mse: 935.0388 - val_loss: 67.1466 - val_mse: 67.1466 - 28ms/epoch - 6ms/step
# Epoch 24898/100000
# 5/5 - 0s - loss: 924.6839 - mse: 924.6839 - val_loss: 67.0591 - val_mse: 67.0591 - 33ms/epoch - 7ms/step
# Epoch 24899/100000
# 5/5 - 0s - loss: 925.6429 - mse: 925.6429 - val_loss: 73.0154 - val_mse: 73.0154 - 29ms/epoch - 6ms/step
# Epoch 24900/100000
# 5/5 - 0s - loss: 933.3802 - mse: 933.3802 - val_loss: 68.4753 - val_mse: 68.4753 - 30ms/epoch - 6ms/step
# Epoch 24901/100000
# 5/5 - 0s - loss: 919.7079 - mse: 919.7079 - val_loss: 66.9450 - val_mse: 66.9450 - 31ms/epoch - 6ms/step
# Epoch 24902/100000
# 5/5 - 0s - loss: 932.7111 - mse: 932.7111 - val_loss: 67.4393 - val_mse: 67.4393 - 28ms/epoch - 6ms/step
# Epoch 24903/100000
# 5/5 - 0s - loss: 920.2038 - mse: 920.2038 - val_loss: 67.8000 - val_mse: 67.8000 - 36ms/epoch - 7ms/step
# Epoch 24904/100000
# 5/5 - 0s - loss: 996.7826 - mse: 996.7826 - val_loss: 66.6606 - val_mse: 66.6606 - 30ms/epoch - 6ms/step
# Epoch 24905/100000
# 5/5 - 0s - loss: 933.7103 - mse: 933.7103 - val_loss: 68.9948 - val_mse: 68.9948 - 33ms/epoch - 7ms/step
# Epoch 24906/100000
# 5/5 - 0s - loss: 929.0923 - mse: 929.0923 - val_loss: 68.1384 - val_mse: 68.1384 - 31ms/epoch - 6ms/step
# Epoch 24907/100000
# 5/5 - 0s - loss: 921.0996 - mse: 921.0996 - val_loss: 68.3906 - val_mse: 68.3906 - 37ms/epoch - 7ms/step
# Epoch 24908/100000
# 5/5 - 0s - loss: 919.3744 - mse: 919.3744 - val_loss: 68.0707 - val_mse: 68.0707 - 27ms/epoch - 5ms/step
# Epoch 24909/100000
# 5/5 - 0s - loss: 932.6146 - mse: 932.6146 - val_loss: 66.0074 - val_mse: 66.0074 - 29ms/epoch - 6ms/step
# Epoch 24910/100000
# 5/5 - 0s - loss: 930.1555 - mse: 930.1555 - val_loss: 65.8410 - val_mse: 65.8410 - 31ms/epoch - 6ms/step
# Epoch 24911/100000
# 5/5 - 0s - loss: 917.3505 - mse: 917.3503 - val_loss: 65.0736 - val_mse: 65.0736 - 41ms/epoch - 8ms/step
# Epoch 24912/100000
# 5/5 - 0s - loss: 937.3673 - mse: 937.3673 - val_loss: 69.6565 - val_mse: 69.6565 - 28ms/epoch - 6ms/step
# Epoch 24913/100000
# 5/5 - 0s - loss: 1121.0327 - mse: 1121.0327 - val_loss: 67.9724 - val_mse: 67.9724 - 30ms/epoch - 6ms/step
# Epoch 24914/100000
# 5/5 - 0s - loss: 1087.9435 - mse: 1087.9435 - val_loss: 68.4035 - val_mse: 68.4035 - 33ms/epoch - 7ms/step
# Epoch 24915/100000
# 5/5 - 0s - loss: 923.6493 - mse: 923.6493 - val_loss: 67.0572 - val_mse: 67.0572 - 28ms/epoch - 6ms/step
# Epoch 24916/100000
# 5/5 - 0s - loss: 918.5195 - mse: 918.5195 - val_loss: 66.3694 - val_mse: 66.3694 - 34ms/epoch - 7ms/step
# Epoch 24917/100000
# 5/5 - 0s - loss: 917.7694 - mse: 917.7694 - val_loss: 66.2752 - val_mse: 66.2752 - 30ms/epoch - 6ms/step
# Epoch 24918/100000
# 5/5 - 0s - loss: 935.5178 - mse: 935.5178 - val_loss: 68.4891 - val_mse: 68.4891 - 28ms/epoch - 6ms/step
# Epoch 24919/100000
# 5/5 - 0s - loss: 927.5821 - mse: 927.5820 - val_loss: 68.1344 - val_mse: 68.1344 - 31ms/epoch - 6ms/step
# Epoch 24920/100000
# 5/5 - 0s - loss: 920.5789 - mse: 920.5789 - val_loss: 65.5324 - val_mse: 65.5324 - 27ms/epoch - 5ms/step
# Epoch 24921/100000
# 5/5 - 0s - loss: 920.9435 - mse: 920.9435 - val_loss: 65.7572 - val_mse: 65.7572 - 30ms/epoch - 6ms/step
# Epoch 24922/100000
# 5/5 - 0s - loss: 920.8718 - mse: 920.8718 - val_loss: 67.2150 - val_mse: 67.2150 - 28ms/epoch - 6ms/step
# Epoch 24923/100000
# 5/5 - 0s - loss: 919.4555 - mse: 919.4556 - val_loss: 65.9225 - val_mse: 65.9225 - 28ms/epoch - 6ms/step
# Epoch 24924/100000
# 5/5 - 0s - loss: 915.1797 - mse: 915.1797 - val_loss: 65.1966 - val_mse: 65.1966 - 27ms/epoch - 5ms/step
# Epoch 24925/100000
# 5/5 - 0s - loss: 1095.9078 - mse: 1095.9078 - val_loss: 66.5421 - val_mse: 66.5421 - 36ms/epoch - 7ms/step
# Epoch 24926/100000
# 5/5 - 0s - loss: 934.4576 - mse: 934.4576 - val_loss: 67.0150 - val_mse: 67.0150 - 26ms/epoch - 5ms/step
# Epoch 24927/100000
# 5/5 - 0s - loss: 926.0955 - mse: 926.0955 - val_loss: 68.8604 - val_mse: 68.8604 - 31ms/epoch - 6ms/step
# Epoch 24928/100000
# 5/5 - 0s - loss: 920.8540 - mse: 920.8540 - val_loss: 69.2123 - val_mse: 69.2123 - 33ms/epoch - 7ms/step
# Epoch 24929/100000
# 5/5 - 0s - loss: 956.2704 - mse: 956.2704 - val_loss: 66.9321 - val_mse: 66.9321 - 32ms/epoch - 6ms/step
# Epoch 24930/100000
# 5/5 - 0s - loss: 917.2916 - mse: 917.2916 - val_loss: 68.0229 - val_mse: 68.0229 - 35ms/epoch - 7ms/step
# Epoch 24931/100000
# 5/5 - 0s - loss: 915.2067 - mse: 915.2067 - val_loss: 66.7329 - val_mse: 66.7329 - 26ms/epoch - 5ms/step
# Epoch 24932/100000
# 5/5 - 0s - loss: 916.6469 - mse: 916.6469 - val_loss: 68.3088 - val_mse: 68.3088 - 30ms/epoch - 6ms/step
# Epoch 24933/100000
# 5/5 - 0s - loss: 924.8909 - mse: 924.8909 - val_loss: 65.1317 - val_mse: 65.1317 - 27ms/epoch - 5ms/step
# Epoch 24934/100000
# 5/5 - 0s - loss: 920.2120 - mse: 920.2120 - val_loss: 65.5823 - val_mse: 65.5823 - 29ms/epoch - 6ms/step
# Epoch 24935/100000
# 5/5 - 0s - loss: 959.5687 - mse: 959.5687 - val_loss: 68.9299 - val_mse: 68.9299 - 32ms/epoch - 6ms/step
# Epoch 24936/100000
# 5/5 - 0s - loss: 943.9553 - mse: 943.9553 - val_loss: 67.4792 - val_mse: 67.4792 - 28ms/epoch - 6ms/step
# Epoch 24937/100000
# 5/5 - 0s - loss: 916.9722 - mse: 916.9722 - val_loss: 66.1719 - val_mse: 66.1719 - 32ms/epoch - 6ms/step
# Epoch 24938/100000
# 5/5 - 0s - loss: 914.0714 - mse: 914.0714 - val_loss: 66.0930 - val_mse: 66.0930 - 29ms/epoch - 6ms/step
# Epoch 24939/100000
# 5/5 - 0s - loss: 942.4652 - mse: 942.4652 - val_loss: 67.0573 - val_mse: 67.0573 - 27ms/epoch - 5ms/step
# Epoch 24940/100000
# 5/5 - 0s - loss: 915.2966 - mse: 915.2966 - val_loss: 67.1126 - val_mse: 67.1126 - 30ms/epoch - 6ms/step
# Epoch 24941/100000
# 5/5 - 0s - loss: 915.1227 - mse: 915.1227 - val_loss: 66.8199 - val_mse: 66.8199 - 25ms/epoch - 5ms/step
# Epoch 24942/100000
# 5/5 - 0s - loss: 912.4584 - mse: 912.4584 - val_loss: 67.9526 - val_mse: 67.9526 - 27ms/epoch - 5ms/step
# Epoch 24943/100000
# 5/5 - 0s - loss: 914.7371 - mse: 914.7371 - val_loss: 71.5993 - val_mse: 71.5993 - 31ms/epoch - 6ms/step
# Epoch 24944/100000
# 5/5 - 0s - loss: 966.0374 - mse: 966.0374 - val_loss: 67.2872 - val_mse: 67.2872 - 28ms/epoch - 6ms/step
# Epoch 24945/100000
# 5/5 - 0s - loss: 917.5274 - mse: 917.5274 - val_loss: 67.3446 - val_mse: 67.3446 - 25ms/epoch - 5ms/step
# Epoch 24946/100000
# 5/5 - 0s - loss: 914.0594 - mse: 914.0595 - val_loss: 64.6083 - val_mse: 64.6083 - 39ms/epoch - 8ms/step
# Epoch 24947/100000
# 5/5 - 0s - loss: 1017.4877 - mse: 1017.4877 - val_loss: 70.0533 - val_mse: 70.0533 - 28ms/epoch - 6ms/step
# Epoch 24948/100000
# 5/5 - 0s - loss: 926.3858 - mse: 926.3858 - val_loss: 69.8763 - val_mse: 69.8763 - 37ms/epoch - 7ms/step
# Epoch 24949/100000
# 5/5 - 0s - loss: 912.7708 - mse: 912.7707 - val_loss: 67.3215 - val_mse: 67.3215 - 32ms/epoch - 6ms/step
# Epoch 24950/100000
# 5/5 - 0s - loss: 914.4703 - mse: 914.4703 - val_loss: 67.4237 - val_mse: 67.4237 - 25ms/epoch - 5ms/step
# Epoch 24951/100000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 28
#      26 # neural network traning
#      27 start_time = time.time()
# ---> 28 history = network.fit(dataXtrain, dataYtrain, epochs=100000, batch_size=20000, callbacks=callbacks_list, validation_data = (dataXval, dataYval), verbose = 2)
#      29 end_time = time.time()
#      30 print('Training time %f'%(end_time-start_time))
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1606, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1591 if getattr(self, "_eval_data_handler", None) is None:
#    1592     self._eval_data_handler = data_adapter.get_data_handler(
#    1593         x=val_x,
#    1594         y=val_y,
#    (...)
#    1604         steps_per_execution=self._steps_per_execution,
#    1605     )
# -> 1606 val_logs = self.evaluate(
#    1607     x=val_x,
#    1608     y=val_y,
#    1609     sample_weight=val_sample_weight,
#    1610     batch_size=validation_batch_size or batch_size,
#    1611     steps=validation_steps,
#    1612     callbacks=callbacks,
#    1613     max_queue_size=max_queue_size,
#    1614     workers=workers,
#    1615     use_multiprocessing=use_multiprocessing,
#    1616     return_dict=True,
#    1617     _use_cached_eval_dataset=True,
#    1618 )
#    1619 val_logs = {
#    1620     "val_" + name: val for name, val in val_logs.items()
#    1621 }
#    1622 epoch_logs.update(val_logs)
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\keras\engine\training.py:1954, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1952                 end_step = step + data_handler.step_increment
#    1953                 callbacks.on_test_batch_end(end_step, logs)
# -> 1954 logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1955 callbacks.on_test_end(logs=logs)
#    1957 if return_dict:
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\hengr\miniconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
###############################################################################
#                    Plot the history    
###############################################################################
     
loss=history.history['loss']
val_loss=history.history['val_loss']
epochs=range(1,len(loss)+1)
plt.figure()
plt.plot(epochs, loss,'b', label='Training loss')
plt.plot(epochs, val_loss,'r', label='Validation loss')
plt.title('Training and validation losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.savefig('loss_curves4.png')
plt.show()

# %%
###############################################################################
#                   test the model prediction performance
###############################################################################
# load the best model we get from training
network.load_weights(filepath)


dataYtrain_prediction = network.predict(dataXtrain)
dataYval_prediction = network.predict(dataXval)

# generate the prediction output to make comparison
dataYtest_prediction = network.predict(dataXtest)

# x1real_test, x1imag_test, x2real_test, x2imag_test

# extract the data
# x1real_test[i,0] = np.real(x1real_test)
# x1imag_test[i,0] = np.imag(x1imag_test)
# x2real_test[i,0] = np.real(x2real_test)
# x2imag_test[i,0] = np.imag(x2imag_test)

leng = int(sample_number * 0.15)

x1real_test_prediction = np.zeros(shape=(leng,1))
x1imag_test_prediction = np.zeros(shape=(leng,1))
x2real_test_prediction = np.zeros(shape=(leng,1))
x2imag_test_prediction = np.zeros(shape=(leng,1))

# leng = sample_number * 0.15
for i in range(leng):
    x1real_test_prediction[i,0] = dataYtest_prediction[i,0]
    x1imag_test_prediction[i,0] = dataYtest_prediction[i,1]
    x2real_test_prediction[i,0] = dataYtest_prediction[i,2]
    x2imag_test_prediction[i,0] = dataYtest_prediction[i,3]
     
plt.plot(x1real_test, x1imag_test, 'bo', markersize=7, label='True solution')    
plt.plot(x2real_test, x2imag_test, 'bo', markersize=7) 
plt.plot(x1real_test_prediction, x1imag_test_prediction, 'rx', markersize=7, label='Predicted solution')    
plt.plot(x2real_test_prediction, x2imag_test_prediction, 'rx', markersize=7)    
plt.xlabel('Real part')
plt.ylabel('Imaginary part')
plt.xlim(-100, 10)
plt.ylim(-15, 15)
plt.legend()
plt.savefig('identified4.png')
plt.show()
# Out:
# 2524/2524 [==============================] - 2s 605us/step
# 133/133 [==============================] - 0s 616us/step
# 469/469 [==============================] - 0s 581us/step
